# %%
import pandas as pd
from fuzzywuzzy import fuzz
import pickle

# %%
df1 = pd.read_csv('mn_1850/S/not so confident-mn1850-v7-s.csv')

# %%
with open('/Users/prajwal/Desktop/Columbia/C4SR/mn_1850/not so confident-mn1850-v7.pkl', 'rb') as f:
  d = pickle.load(f)

# %%
len(d)
# Out:
# 2607

# %%
df1_original = pd.read_excel('mn_1850/not so confident-mn1850-v7.xlsx')

# %%
len(df1)-len(df1_original)
# Out:
# 0

# %%
df1_final_1 = df1_original.loc[df1_original['filter11']==0][['n_street1','n_street2','c_street1','c_street2']]

# %%
len(df1_final_1)
# Out:
# 1853

# %%
df1_filter_11 = df1_original.loc[df1_original['filter11']==1]
add_from_df1 = pd.DataFrame()
missed_i_vals = []
for i in df1_filter_11.index:
    try:
        add_from_df1 = pd.concat([add_from_df1, pd.DataFrame(df1.iloc[i][['Full Address','H House Number','H Street Name','new h house number','new h street name','new h city']]).T])
    except:
        missed_i_vals.append(i)
        print(i)

# %%
missed_i_vals
# Out:
# []

# %%
df1_final_1 = pd.concat([df1_final_1, add_from_df1])
# Out:
# /Users/prajwal/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
df1_final_1 = df1_final_1.sort_index()

# %%
df1_final_1
# Out:
#                            Full Address H House Number H Street Name  \
# 0                    h. Cincinnati  , O            NaN           NaN
# 1                                   NaN            NaN           NaN
# 2                             h. Harlem            NaN           NaN
# 3     h. Staten Island Ã¢ÂÂCONTINUED.            NaN           NaN
# 4                                   NaN            NaN           NaN
# 5                              h B'klyn            NaN           NaN
# 6                         h Astor House            NaN           NaN
# 7                                   NaN            NaN           NaN
# 8                h. Greenpoint  , L. I.            NaN           NaN
# 9                                   NaN            NaN           NaN
# 10                                  NaN            NaN           NaN
# 11                         h City Hotel            NaN           NaN
# 12                                  NaN            NaN           NaN
# ...

# %%
df1_original
# Out:
#       Unnamed: 0  Unnamed: 0.1                    Full Name  First Name  \
# 0              0            90              Carlisle George      George
# 1              1            94                  Case George      George
# 2              2           209                  Foster S. R          S.
# 3              3           212            Fountain Henry' K      Henry'
# 4              4           220               Germer Ludolph     Ludolph
# 5              5           233               Hickok William     William
# 6              6           245              Jenings Chester     Chester
# 7              7           296                Abbe Joshua G      Joshua
# 8              8           299              Abberley Thomas      Thomas
# 9              9           328  Abbott Sarah M. wid. Samuel         NaN
# 10            10           336               Abbott William     William
# 11            11           346               Abel Charles H     Charles
# ...

# %%
df1
# Out:
#       Unnamed: 0          Address 2     Address 2 City  \
# 0              0                NaN                NaN
# 1              1      W 25 n Av h 8                NaN
# 2              2                NaN                NaN
# 3              3                NaN                NaN
# 4              4                NaN                NaN
# 5              5                NaN                NaN
# 6              6                NaN                NaN
# 7              7                NaN                NaN
# 8              8                NaN                NaN
# 9              9                NaN                NaN
# 10            10                NaN                NaN
# 11            11                NaN                NaN
# 12            12         429 Av h 6                NaN
# 13            13                NaN                NaN
# 14            14                NaN                NaN
# 15            15                NaN                NaN
# ...

# %%
df1_final_1.to_csv('mn_1850/combine-not so confident.csv')

# %% [markdown]
# ## Column descriptions:
#
# #### Full Address
# contains the cleaned entry for the address from the input file
# #### H House Number
# contains the house number if present in Full Address
# #### H Street Name
# contains the street name if present in Full Address
# #### c_street1
# contains the first street name in case the address was located at a corner
# #### c_street2
# contains the second street name in case the address was located at a corner
# #### n_street1
# contains the first street name in case the address was located near another street
# #### n_street2
# contains the second street name in case the address was located near another street
# #### new h city
# contains the city name (if present) in Full Address
# #### new h house number
# contains the house number if present in Full Address for some additional entries that are not in 'H House Number'
# #### new h street name
# contains the street name if present in Full Address for some additional entries that are not in 'H Street Name'
