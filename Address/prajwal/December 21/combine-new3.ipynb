# %%
import pandas as pd
#from fuzzywuzzy import fuzz
import pickle

# %%
mn_or_bk = 'bk'
year = str(1850)
doubttype = 'not so confident' #doubt or not so confident

# %%
df1 = pd.read_csv(mn_or_bk + '_' + year + '/S/' + doubttype + '-' + mn_or_bk + year + '-v7-s.csv')

# %%
with open('/Users/prajwal/Desktop/Columbia/C4SR/' + mn_or_bk + '_' + year + '/' + doubttype + '-' + mn_or_bk + year + '-v7.pkl', 'rb') as f:
  d = pickle.load(f)

# %%
df1_original = pd.read_excel(mn_or_bk + '_' + year + '/' + doubttype + '-' + mn_or_bk + year + '-v7.xlsx')

# %%
len(df1)-len(df1_original)
# Out:
# 0

# %%
#df1_final_1 = df1_original.loc[df1_original['filter11']==0][['n_street1','n_street2','c_street1','c_street2']]
df1_final_1 = df1_original[['n_street1','n_street2','c_street1','c_street2']]

# %%
len(df1_final_1)
# Out:
# 58

# %%
#df1_original

# %%
#df1_final_1

# %%
#df1

# %%
df1_final_1['Full Address'] = df1['Full Address']
df1_final_1['H House Number'] = df1['H House Number']
df1_final_1['H Street Name'] = df1['H Street Name']
df1_final_1['new h house number'] = df1['new h house number']
df1_final_1['new h street name'] = df1['new h street name']
df1_final_1['new h city'] = df1['new h city']
df1_final_1['unidentified h info'] = df1['unidentified h info']
# Out:
# /Users/prajwal/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /Users/prajwal/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/prajwal/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/prajwal/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /Users/prajwal/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /Users/prajwal/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/prajwal/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
df1_final_1
# Out:
#                n_street1     n_street2 c_street1  \
# 0                    NaN           NaN       NaN
# 1                    NaN           NaN       NaN
# 2                    NaN           NaN       NaN
# 3                    NaN           NaN       NaN
# 4                    NaN           NaN       NaN
# 5                    NaN           NaN       NaN
# 6                    NaN           NaN       NaN
# 7                    NaN           NaN       NaN
# 8                    NaN           NaN      3 av
# 9                    NaN           NaN       NaN
# 10                   NaN           NaN       NaN
# 11                   NaN           NaN       NaN
# 12               Classon   Flushing av       NaN
# 13                   NaN           NaN       NaN
# 14            61 Carlton     Myrtle av       NaN
# 15                   NaN           NaN       NaN
# 16                   NaN           NaN       NaN
# 17               Classon     Myrtle av       NaN
# 18                   NaN           NaN       NaN
# 19           Flushing av   Nostrand av       NaN
# 20                   NaN           NaN       NaN
# 21                   NaN           NaN       NaN
# 22                   NaN           NaN       NaN
# 23                  5 av  9 st Gowanus       NaN
# 24                   NaN           NaN       NaN
# 25                   NaN           NaN       NaN
# 26                   NaN           NaN       NaN
# 27                   NaN           NaN       NaN
# 28                   NaN           NaN       NaN
# 29                   NaN           NaN       NaN
# 30                   NaN           NaN       NaN
# 31                   NaN           NaN       NaN
# 32                   NaN           NaN       NaN
# 33                   NaN           NaN       NaN
# 34                   NaN           NaN       NaN
# 35                   NaN           NaN       NaN
# 36                 22 st  3 av Gowanus       NaN
# 37              Clermont     Myrtle av       NaN
# 38                Baltic         Henry       NaN
# 39                   NaN           NaN       NaN
# 40                   NaN           NaN       NaN
# 41                   NaN           NaN       NaN
# 42                   NaN           NaN       NaN
# 43                   NaN           NaN       NaN
# 44                   NaN           NaN       NaN
# 45                   NaN           NaN       NaN
# 46                   NaN           NaN       NaN
# 47                   NaN           NaN       NaN
# 48                   NaN           NaN       NaN
# 49                   NaN           NaN       NaN
# 50                   NaN           NaN       NaN
# 51                   NaN           NaN       NaN
# 52                   NaN           NaN       NaN
# 53                   NaN           NaN       NaN
# 54                   NaN           NaN       NaN
# 55  3 av c 27 st h 21 st  3 av Gowanus      3 av
# 56            63 Carlton     Myrtle av       NaN
# 57                   NaN           NaN       NaN
#
#                        c_street2  \
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# 5                            NaN
# 6                            NaN
# 7                            NaN
# 8                  16 st Gowanus
# 9                            NaN
# 10                           NaN
# 11                           NaN
# 12                           NaN
# 13                           NaN
# 14                           NaN
# 15                           NaN
# 16                           NaN
# 17                           NaN
# 18                           NaN
# 19                           NaN
# 20                           NaN
# 21                           NaN
# 22                           NaN
# 23                           NaN
# 24                           NaN
# 25                           NaN
# 26        3 av and 16 st Gowanus
# 27                           NaN
# 28                           NaN
# 29                           NaN
# 30                           NaN
# 31                           NaN
# 32                           NaN
# 33                           NaN
# 34                           NaN
# 35                           NaN
# 36                           NaN
# 37                           NaN
# 38                           NaN
# 39                           NaN
# 40                           NaN
# 41                           NaN
# 42                           NaN
# 43                           NaN
# 44                           NaN
# 45                           NaN
# 46                           NaN
# 47                           NaN
# 48                           NaN
# 49                           NaN
# 50                           NaN
# 51                           NaN
# 52                           NaN
# 53                           NaN
# 54                           NaN
# 55  27 st h 21 st n 3 av Gowanus
# 56                           NaN
# 57                           NaN
#
#                                          Full Address  H House Number  \
# 0                                                 NaN             NaN
# 1                                          38 Concord            38.0
# 2                           34 Beaver N Y h Joralemon            34.0
# 3                                      N Y h 66 Court             NaN
# 4                      113 Maiden Lane N Y h 42 Court           113.0
# 5                stove man'r Fulton h 103 YVilloughby             NaN
# 6               Columbia c Congress h 14 Sydney Place             NaN
# 7                           John n Bridge h 61 Bridgc             NaN
# 8                         N Y' h 3 av c 16 st Gowanus             NaN
# 9                                     N Y h Myrtle av             NaN
# 10              yard 19 st c 3 av h Middle st Gowanus            19.0
# 11      watchman fulton market  , N Y h 24 Carlton av             NaN
# 12         Graham n Myrtle av h Classon n Flushing av             NaN
# 13                              N Y h 16 Sydney place             NaN
# 14          Raymond n Myrtle h 61 Carlton n Myrtle av             NaN
# 15                  Myrtle av c Carll h 159 Myrtle av             NaN
# 16      Insurance agent office 3 Front N Y h 94 Coint             NaN
# 17                       Fulton h Classon n Myrtle av             NaN
# 18               copperplate maker 120 W'illiam N Y h             NaN
# 19  morocco man'r Bedford av n Flushing av h Flush...             NaN
# 20          Carlton n Fulton av h 22 stn 3 av Gowanus             NaN
# 21     Davine Thomas tailor 89 Fulton h 246 Myrtle av             NaN
# 22  VanBrunt and Hamilton av h 1 Boardman Place Co...             NaN
# 23                          N Y h 5 av n 9 st Gowanus             NaN
# 24          Main c York and 138 Fulton h Fleets alley             NaN
# 25                                   N Y h 69 YVillow             NaN
# 26            27 st n 5 av h c 3 av and 16 st Gowanus            27.0
# 27                Plymouth c Adams h 32 C'harlton N Y             NaN
# 28          3 av n 19 st h 20 st b 3 & Sth av Gowanus             3.0
# 29                      14Water N Y h 10 Sydney place             NaN
# 30                      Fulton c Court h 19 Myrtle av             NaN
# 31                                                NaN             NaN
# 32                               N Y h 59 W'illoughby             NaN
# 33                        NY h 7 Boardman pl Court st             NaN
# 34                 Greenwich & Dey N Y h 32 Myrtle av             NaN
# 35                            Dean n Hoyt h 103 Iloyt             NaN
# 36                         N Y h 22 st n 3 av Gowanus             NaN
# 37                         N Y h Clermont n Myrtle av             NaN
# 38                            Baltic h Baltic n Henry             NaN
# 39                   Wood and ware agency 46 Fulton h             NaN
# 40  wine mer. Ill Front N Y h Pacific stn Clove rd...             NaN
# 41  lawyer and police justice,office 6 Montague Ha...             NaN
# 42        3 av c 21 st h 22nd st b 3 and 4 av Gowanus             3.0
# 43                      153 South N Y h 127 Myrtle av           153.0
# 44                              N Y h 14 Sydney place             NaN
# 45           Flushing c Ryerson av Aiderman 7 ward) h             NaN
# 46  Brooklyn Independent c Orange and Fulton st h ...             NaN
# 47                 Custom house N Y h 39 Sydney place             NaN
# 48                  Fulton market N Y h 24 Carlton av             NaN
# 49                        Furman n Everitt h 43 Sauds             NaN
# 50                  Columbia n Fulton h 128 Myrtle ax             NaN
# 51                                    N Y h Craubcrry             NaN
# 52                                 N Y h 97 Myrtle av             NaN
# 53                                     NY h 70Remseit             NaN
# 54                                 8 ward h 3 av & 16             8.0
# 55  Greenwood Cemetery monumental works Aiderman 8...             NaN
# 56                       N Y h 63 Carlton n Myrtle av             NaN
# 57  attorney & counsellor at law and commissioner ...             NaN
#
#                                 H Street Name  new h house number  \
# 0                                         NaN                 NaN
# 1                                     CONCORD                 NaN
# 2                      BEAVER N Y H JORALEMON                 NaN
# 3                                         NaN                 NaN
# 4                  MAIDEN LANE N Y H 42 COURT                 NaN
# 5                                         NaN                 NaN
# 6                                         NaN                 NaN
# 7                                         NaN                 NaN
# 8                                         NaN                 3.0
# 9                                         NaN                 NaN
# 10              ST C 3 AV H MIDDLE ST GOWANUS                 NaN
# 11                                        NaN                 NaN
# 12                                        NaN                 NaN
# 13                                        NaN                 NaN
# 14                                        NaN                 NaN
# 15                                        NaN                 NaN
# 16                                        NaN                 NaN
# 17                                        NaN                 NaN
# 18                                        NaN                 NaN
# 19                                        NaN                 NaN
# 20                                        NaN                22.0
# 21                                        NaN                 NaN
# 22                                        NaN                 NaN
# 23                                        NaN                 5.0
# 24                                        NaN                 NaN
# 25                                        NaN                 NaN
# 26       ST N 5 AV H C 3 AV AND 16 ST GOWANUS                 3.0
# 27                                        NaN                 NaN
# 28    AV N 19 ST H 20 ST B 3 & STH AV GOWANUS                20.0
# 29                                        NaN                 NaN
# 30                                        NaN                 NaN
# 31                                        NaN                 NaN
# 32                                        NaN                 NaN
# 33                                        NaN                 NaN
# 34                                        NaN                 NaN
# 35                                        NaN                 NaN
# 36                                        NaN                22.0
# 37                                        NaN                 NaN
# 38                                        NaN                 NaN
# 39                                        NaN                 NaN
# 40                                        NaN                 NaN
# 41                                        NaN                 5.0
# 42  AV C 21 ST H 22ND ST B 3 AND 4 AV GOWANUS                 NaN
# 43                  SOUTH N Y H 127 MYRTLE AV                 NaN
# 44                                        NaN                 NaN
# 45                                        NaN                 NaN
# 46                                        NaN                 NaN
# 47                                        NaN                 NaN
# 48                                        NaN                 NaN
# 49                                        NaN                 NaN
# 50                                        NaN                 NaN
# 51                                        NaN                 NaN
# 52                                        NaN                 NaN
# 53                                        NaN                 NaN
# 54                           WARD H 3 AV & 16                 3.0
# 55                                        NaN                 3.0
# 56                                        NaN                 NaN
# 57                                        NaN                 NaN
#
#    new h street name new h city         unidentified h info
# 0                NaN        NaN                         NaN
# 1                NaN        NaN                         NaN
# 2          JORALEMON        NaN                           H
# 3                 66        NaN                       COURT
# 4                 42        NaN                       COURT
# 5                103        NaN                 YVILLOUGHBY
# 6                 14        NaN                SYDNEY PLACE
# 7                 61        NaN                      BRIDGC
# 8               AV C        NaN               16 ST GOWANUS
# 9                NaN        NaN                   MYRTLE AV
# 10               NaN        NaN           MIDDLE ST GOWANUS
# 11                24        NaN                  CARLTON AV
# 12               NaN   FLUSHING               CLASSON N  AV
# 13                16        NaN                SYDNEY PLACE
# 14                61        NaN         CARLTON N MYRTLE AV
# 15               159        NaN                   MYRTLE AV
# 16                94        NaN                       COINT
# 17               NaN        NaN         CLASSON N MYRTLE AV
# 18               NaN        NaN                           H
# 19               NaN   FLUSHING            AV N NOSTRAND AV
# 20              AV G        NaN                STN 3 OWANUS
# 21               246        NaN                   MYRTLE AV
# 22                 1        NaN     BOARDMAN PLACE COURT ST
# 23               N 9        NaN              AV  ST GOWANUS
# 24               NaN        LEE                   FTS ALLEY
# 25                69        NaN                     YVILLOW
# 26              AV A        NaN         C  ND 16 ST GOWANUS
# 27                32        NaN               C'HARLTON N Y
# 28              AV G        NaN           ST B 3 & STOWANUS
# 29                10        NaN                SYDNEY PLACE
# 30                19        NaN                   MYRTLE AV
# 31               NaN        NaN                         NaN
# 32                59        NaN                 W'ILLOUGHBY
# 33                 7        NaN        BOARDMAN PL COURT ST
# 34                32        NaN                   MYRTLE AV
# 35               103        NaN                       ILOYT
# 36              AV G        NaN               ST N 3 OWANUS
# 37               NaN   CLERMONT                 N MYRTLE AV
# 38           N HENRY        NaN                      BALTIC
# 39               NaN        NaN                           H
# 40          CLOVE RD        NaN        PACIFIC STN  BEDFORD
# 41              AV G        NaN                      OWANUS
# 42              AV G        NaN    22ND ST B 3 AND 4 OWANUS
# 43               127        NaN                   MYRTLE AV
# 44                14        NaN                SYDNEY PLACE
# 45               NaN        NaN                           H
# 46              AV B        NaN            ST 13 AND 14 STS
# 47                39        NaN                SYDNEY PLACE
# 48                24        NaN                  CARLTON AV
# 49                43        NaN                       SAUDS
# 50               128        NaN                   MYRTLE AX
# 51               NaN        NaN                   CRAUBCRRY
# 52                97        NaN                   MYRTLE AV
# 53                70        NaN                     REMSEIT
# 54                16        NaN                        AV &
# 55              AV G        NaN  AV C 27 ST 21 ST N  OWANUS
# 56                63        NaN         CARLTON N MYRTLE AV
# 57               NaN        NaN                           H

# %%
#df1_original[['Full Address','H House Number','H Street Name','new h house number','new h street name','new h city']]
#df1[['unidentified h info']]

# %%
df1_final_1.columns
# Out:
# Index(['n_street1', 'n_street2', 'c_street1', 'c_street2', 'Full Address',
#        'H House Number', 'H Street Name', 'new h house number',
#        'new h street name', 'new h city', 'unidentified h info'],
#       dtype='object')

# %%
df1_final_1.to_csv(mn_or_bk + '_' + year + '/combine-not so confident2.csv')

# %% [markdown]
# ## Column descriptions:
#
# #### Full Address
# contains the cleaned entry for the address from the input file
# #### H House Number
# contains the house number if present in Full Address
# #### H Street Name
# contains the street name if present in Full Address
# #### c_street1
# contains the first street name in case the address was located at a corner
# #### c_street2
# contains the second street name in case the address was located at a corner
# #### n_street1
# contains the first street name in case the address was located near another street
# #### n_street2
# contains the second street name in case the address was located near another street
# #### new h city
# contains the city name (if present) in Full Address
# #### new h house number
# contains the house number if present in Full Address for some additional entries that are not in 'H House Number'
# #### new h street name
# contains the street name if present in Full Address for some additional entries that are not in 'H Street Name'
