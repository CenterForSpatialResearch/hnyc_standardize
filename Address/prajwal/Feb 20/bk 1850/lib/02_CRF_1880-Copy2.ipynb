# %%
# !pip install sklearn-crfsuite
# Out:
# Requirement already satisfied: sklearn-crfsuite in /usr/local/lib/python3.6/dist-packages (0.3.6)
# Requirement already satisfied: tqdm>=2.0 in /usr/local/lib/python3.6/dist-packages (from sklearn-crfsuite) (4.41.1)
# Requirement already satisfied: python-crfsuite>=0.8.3 in /usr/local/lib/python3.6/dist-packages (from sklearn-crfsuite) (0.9.7)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.6/dist-packages (from sklearn-crfsuite) (0.8.7)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from sklearn-crfsuite) (1.15.0)

# %%
#get authorization from google drive
#from google.colab import drive
#drive.mount('/content/drive')

# %%
import sklearn_crfsuite
from sklearn_crfsuite import metrics
from sklearn.metrics import make_scorer
from sklearn.model_selection import RandomizedSearchCV
import pandas as pd
import pickle
import json

# %% [markdown]
# #Prepare data and features

# %%
#prepare training and test data
def prepare_data(path):
  df = pd.read_csv(path, engine = "python")
  sents = []
  record = []
  cur = df['number'][0]
  for index,row in df.iterrows():
    if row['number'] != cur:
      sents.append(record)
      record = [(row['pos'], row['tag'])]
    else:
      record.append((row['pos'], row['tag']))
    cur = row['number']
  sents.append(record)

  return sents

# %%
train_sents = prepare_data("1880_train.csv")
validation_sents = prepare_data("1880_validation.csv")

# %% [markdown]
# An example of training data

# %%
train_sents[0]
# Out:
# [('START', 'START'),
#  ('Otersen', 'NC'),
#  ('Casten', 'NC'),
#  (',', 'D'),
#  ('produce', 'OC'),
#  (',', 'D'),
#  ('h', 'PA'),
#  ('149', 'AC'),
#  ('Franklin', 'AC'),
#  ('END', 'END')]

# %% [markdown]
# #Define CRF features

# %% [markdown]
# Feature Explanation
#
# is_junior_token: does it equal "jr"?
#
# is_widow_token: does it equal "widow"?
#
# contains_digit: does it contain any number?
#
# is_delimiter: is it a delimiter?
#
# is_start: start of record?
#
# is_end: end of record?
#
# is_lower: all lowercase letters?
#
# is_upper: all uppercase letters?

# %%
def is_junior_token(input):
        dc = input.lower()
        if dc == "jr":
            return True
        return False

def is_widow_token(input):
        dc = input.lower()
        if dc == "wid" or dc == "widow":
            return True
        return False

def contains_digit(input):
        for c in input:
            if c.isdigit():
                return True
        return False

def is_delimiter(input):
        for c in input:
            if c == '.' or c == ',':
                return True
        return False

def is_start(input):
        if input == "START":
            return True
        return False

def is_end(input):
        if input == "END":
            return True
        return False

# %% [markdown]
# Notice that features are not only generated on the current word, but also previous and next word.

# %%
def word2features(sent, i):
    word = sent[i][0]

    features = {
        'bias': 1.0,
        'is_junior_token': is_junior_token(word),
        'is_widow_token': is_widow_token(word),
        'contains_digit': contains_digit(word),
        'is_delimiter': is_delimiter(word),
        'is_start': is_start(word),
        'is_end': is_end(word),
        'is_lower': word.islower(),
        'is_title': word.istitle(),
        'is_upper': word.isupper(),
        'substr[-2:]': word[-2:],
        'substr[-1:]': word[-1:]
    }

    if i == 0:
      features.update({'BOS':True})
    elif i == len(sent) - 1:
      features.update({'EOS':True})
    else:
      word_prev = sent[i-1][0]
      word_next = sent[i+1][0]
      features.update({'prev_is_lower': word_prev.islower(), 
                       'prev_is_title': word_prev.istitle(),
                       'prev_is_upper': word_prev.isupper(),
                       'prev_is_delimiter': is_delimiter(word_prev),
                       'next_is_lower': word_next.islower(),
                       'next_is_title': word_next.istitle(),
                       'next_is_upper': word_next.isupper(),
                       'next_contains_digit': contains_digit(word_next),
                       'next_is_end': is_end(word_next)})
    
    return features

# %%
def sent2features(sent):
    return [word2features(sent, i) for i in range(len(sent))]

def sent2labels(sent):
    return [label for word, label in sent]

# %%
#extract features from data
X_train = [sent2features(s) for s in train_sents]
y_train = [sent2labels(s) for s in train_sents]
X_validation = [sent2features(s) for s in validation_sents]
y_validation = [sent2labels(s) for s in validation_sents]

# %% [markdown]
# #Training

# %%
crf = sklearn_crfsuite.CRF(
    algorithm='lbfgs',
    c1=0.1,
    c2=0.1,
    max_iterations=500,
    all_possible_transitions=True
)
crf.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/base.py:197: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
# CRF(algorithm='lbfgs', all_possible_states=None, all_possible_transitions=True,
#     averaging=None, c=None, c1=0.1, c2=0.1, calibration_candidates=None,
#     calibration_eta=None, calibration_max_trials=None, calibration_rate=None,
#     calibration_samples=None, delta=None, epsilon=None, error_sensitive=None,
#     gamma=None, keep_tempfiles=None, linesearch=None, max_iterations=500,
#     max_linesearch=None, min_freq=None, model_filename=None, num_memories=None,
#     pa_type=None, period=None, trainer_cls=None, variance=None, verbose=False)

# %% [markdown]
# #Evaluation

# %% [markdown]
# Precision, recall and f1-score are used as evaluation metrics.
#
# A detailed explanation on metrics: https://medium.com/analytics-vidhya/pos-tagging-using-conditional-random-fields-92077e5eaa31

# %%
labels = list(crf.classes_)
y_pred = crf.predict(X_validation)
metrics.flat_f1_score(y_validation, y_pred,
                      average='weighted', labels=labels)
# Out:
# 0.9906933631825323

# %% [markdown]
# Notice that evaluation metrics are applied to each category (AC, NC, PA etc.)

# %%
#metrics by label
sorted_labels = sorted(
    labels,
    key=lambda name: (name[1:], name[0])
)
print(metrics.flat_classification_report(
    y_validation, y_pred, labels=sorted_labels, digits=3
))
# Out:
#               precision    recall  f1-score   support
#
#            D      1.000     0.963     0.981        54
#           PA      1.000     1.000     1.000        21
#           AC      0.989     1.000     0.995        94
#           NC      0.975     1.000     0.988        79
#           OC      1.000     0.955     0.977        22
#          END      1.000     1.000     1.000        27
#        START      1.000     1.000     1.000        27
#
#     accuracy                          0.991       324
#    macro avg      0.995     0.988     0.991       324
# weighted avg      0.991     0.991     0.991       324

# %% [markdown]
# #Apply model to the whole dataset

# %%
#import glob
#file_path = "/Users/prajwal/Desktop/Columbia/C4SR/hnyc_cd_processing-master/input/1880/nypl_1880_clean_records.txt"
#with open(file_path) as f:
  #data = f.readlines()

# %%
#import glob
#file_path = "/Users/prajwal/Desktop/Columbia/C4SR/doubt/doubt5 filter11.txt"
#with open(file_path) as f:
  #data = f.readlines()

# %%
import pandas as pd
#read_df = pd.read_excel('/Users/prajwal/Desktop/Columbia/C4SR/doubt/doubt6-filter11.xlsx')
#read_df = pd.read_excel('/Users/prajwal/Desktop/Columbia/C4SR/bk_1850/doubt-bk1850-v7.xlsx')
#read_df = pd.read_excel('bk-1850-2.xlsx')
# 15504
# 15505
# 15506
# 15507
# 15508
# 15509
# 15510
# 15511
# 15512
# 15513
# 15514
# 15515
# 15516
# 15517
# 15518
# 15519
# 15520
# 15521
# 15522
# 15523
# 15524
# 15525
# 15526
# 15527
# 15528
# 15529
# 15530
# 15531
# 15532
# 15533
# 15534
# 15535
# 15536
# 15537
# 15538
# 15539
# 15540
# 15541
# 15542
# 15543
# 15544
# 15545
# 15546
# 15547
# 15548
# 15549
# 15550
# 15551
# 15552
# 15553
# 15554
# 15555
# 15556
# 15557
# 15558
# 15559
# 15560
# 15561
# 15562
# 15563
# 15564
# 15565
# 15566
# 15567
# 15568
# 15569
# 15570
# 15571
# 15572
# 15573
# 15574
# 15575
# 15576
# 15577
# 15578
# 15579
# 15580
# 15581
# 15582
# 15583
# 15584
# 15585
# 15586
# 15587
# 15588
# 15589
# 15590
# 15591
# 15592
# 15593
# 15594
# 15595
# 15596
# 15597
# 15598
# 15599
# 15600
# 15601
# 15602
# 15603
# 15604
# 15605
# 15606
# 15607
# 15608
# 15609
# 15610
# 15611
# 15612
# 15613
# 15614
# 15615
# 15616
# 15617
# 15618
# 15619
# 15620
# 15621
# 15622
# 15623
# 15624
# 15625
# 15626
# 15627
# 15628
# 15629
# 15630
# 15631
# 15632
# 15633
# 15634
# 15635
# 15636
# 15637
# 15638
# 15639
# 15640
# 15641
# 15642
# 15643
# 15644
# 15645
# 15646
# 15647
# 15648
# 15649
# 15650
# 15651
# 15652
# 15653
# 15654
# 15655
# 15656
# 15657
# 15658
# 15659
# 15660
# 15661
# 15662
# 15663
# 15664
# 15665
# 15666
# 15667
# 15668
# 15669
# 15670
# 15671
# 15672
# 15673
# 15674
# 15675

# %%
data = read_list

# %%
len(data)
# Out:
# 15676

# %% [markdown]
# Format record to apply model.

# %%
formatted = []

for record in data:
    ls = record.split()
    #if ls:
    #if ls[0][1:] == "***":
    if ls[1:] == "***":
      continue
    else:
      record_split = []
      for word in ls[1:]:
        if word[-1] == "." or word[-1] == ",":
          record_split.append(word[:-1])
          record_split.append(word[-1])
        else:
          record_split.append(word)
    #formatted.append([ls[0], record_split])
    formatted.append([ls, record_split])

# %%
formatted = []
num1=-1
for record in data:
    num1+=1
    ls = record.split()
    if ls:
        if ls[0][1:] == "***":
          continue
        else:
          record_split = []
          for word in ls[1:]:
            if word[-1] == "." or word[-1] == ",":
              record_split.append(word[:-1])
              record_split.append(word[-1])
            else:
              record_split.append(word)
        formatted.append([ls[0], record_split])
    else:
        #print([num1,['']])
        formatted.append([num1,''])

# %%
len(formatted)
# Out:
# 15676

# %%
def predict_label(s):
  sents = [[(word,0) for word in s]]
  sents[0].insert(0, ('START',0))
  sents[0].append(('END', 0))
  X = [sent2features(s) for s in sents]
  y = crf.predict(X)
  return y

# %%
n = len(formatted)
for i in range(n):
  labels = predict_label(formatted[i][1])
  formatted[i].append(labels[0])

# %%
formatted
# Out:
# [[0, '', ['START', 'END']],
#  [1, '', ['START', 'END']],
#  [2, '', ['START', 'END']],
#  [3, '', ['START', 'END']],
#  ['4', ['merchant'], ['START', 'AC', 'END']],
#  [5, '', ['START', 'END']],
#  ['6', ['Court'], ['START', 'AC', 'END']],
#  ['7', ['141', 'Front'], ['START', 'AC', 'AC', 'END']],
#  [8, '', ['START', 'END']],
#  [9, '', ['START', 'END']],
#  ['10', ['2954', 'Pearl'], ['START', 'AC', 'AC', 'END']],
#  [11, '', ['START', 'END']],
#  ['12', ['Myrtle', 'c', 'Jay'], ['START', 'AC', 'AC', 'AC', 'END']],
#  [13, '', ['START', 'END']],
#  [14, '', ['START', 'END']],
#  [15, '', ['START', 'END']],
#  [16, '', ['START', 'END']],
#  [17, '', ['START', 'END']],
#  [18, '', ['START', 'END']],
#  ['19', ['Y'], ['START', 'NC', 'END']],
#  [20, '', ['START', 'END']],
#  [21, '', ['START', 'END']],
#  [22, '', ['START', 'END']],
#  [23, '', ['START', 'END']],
#  ['24', ['73', 'William'], ['START', 'AC', 'AC', 'END']],
#  ['25', ['15', 'Cortlandt'], ['START', 'AC', 'AC', 'END']],
#  [26, '', ['START', 'END']],
#  ['27', ['23', 'Myrtle', 'av'], ['START', 'AC', 'AC', 'AC', 'END']],
#  [28, '', ['START', 'END']],
#  [29, '', ['START', 'END']],
#  [30, '', ['START', 'END']],
#  [31, '', ['START', 'END']],
#  [32, '', ['START', 'END']],
#  [33, '', ['START', 'END']],
#  [34, '', ['START', 'END']],
#  [35, '', ['START', 'END']],
#  [36, '', ['START', 'END']],
#  ['37', ['130', 'Broad'], ['START', 'AC', 'AC', 'END']],
#  [38, '', ['START', 'END']],
#  ['39', ['Green', 'Jane'], ['START', 'AC', 'AC', 'END']],
#  [40, '', ['START', 'END']],
#  [41, '', ['START', 'END']],
#  [42, '', ['START', 'END']],
#  [43, '', ['START', 'END']],
#  [44, '', ['START', 'END']],
#  [45, '', ['START', 'END']],
#  ['46', ['Y'], ['START', 'NC', 'END']],
#  [47, '', ['START', 'END']],
#  ['48', ['15', 'Stone'], ['START', 'AC', 'AC', 'END']],
#  [49, '', ['START', 'END']],
#  [50, '', ['START', 'END']],
#  [51, '', ['START', 'END']],
#  [52, '', ['START', 'END']],
#  [53, '', ['START', 'END']],
#  [54, '', ['START', 'END']],
#  [55, '', ['START', 'END']],
#  [56, '', ['START', 'END']],
#  ['57', ['80', 'Wall'], ['START', 'AC', 'AC', 'END']],
#  [58, '', ['START', 'END']],
#  [59, '', ['START', 'END']],
#  [60, '', ['START', 'END']],
#  [61, '', ['START', 'END']],
#  [62, '', ['START', 'END']],
#  ['63', ['203', 'Broadway'], ['START', 'AC', 'AC', 'END']],
#  [64, '', ['START', 'END']],
#  [65, '', ['START', 'END']],
#  [66, '', ['START', 'END']],
#  [67, '', ['START', 'END']],
#  ['68', ['90', 'Front'], ['START', 'AC', 'AC', 'END']],
#  [69, '', ['START', 'END']],
#  [70, '', ['START', 'END']],
#  [71, '', ['START', 'END']],
#  [72, '', ['START', 'END']],
#  [73, '', ['START', 'END']],
#  [74, '', ['START', 'END']],
#  [75, '', ['START', 'END']],
#  [76, '', ['START', 'END']],
#  [77, '', ['START', 'END']],
#  [78, '', ['START', 'END']],
#  ['79', ['104', 'Wall'], ['START', 'AC', 'AC', 'END']],
#  [80, '', ['START', 'END']],
#  [81, '', ['START', 'END']],
#  ['82', ['udson', 'av'], ['START', 'AC', 'AC', 'END']],
#  [83, '', ['START', 'END']],
#  [84, '', ['START', 'END']],
#  [85, '', ['START', 'END']],
#  [86, '', ['START', 'END']],
#  [87, '', ['START', 'END']],
#  [88, '', ['START', 'END']],
#  [89, '', ['START', 'END']],
#  [90, '', ['START', 'END']],
#  [91, '', ['START', 'END']],
#  [92, '', ['START', 'END']],
#  ['93', ['137', 'Front'], ['START', 'AC', 'AC', 'END']],
#  [94, '', ['START', 'END']],
#  [95, '', ['START', 'END']],
#  ['96', ['137', 'Front'], ['START', 'AC', 'AC', 'END']],
#  ['97', ['156', 'Broadway'], ['START', 'AC', 'AC', 'END']],
#  [98, '', ['START', 'END']],
#  ['99', ['58', 'John'], ['START', 'AC', 'AC', 'END']],
#  ['100', ['Plymouth', 'Ch'], ['START', 'NC', 'NC', 'END']],
#  ['101', ['ington'], ['START', 'AC', 'END']],
#  ['102', ['61', 'Liberty'], ['START', 'AC', 'AC', 'END']],
#  [103, '', ['START', 'END']],
#  ['104', ['43', 'Fulton'], ['START', 'AC', 'AC', 'END']],
#  [105, '', ['START', 'END']],
#  ['106', ['26', 'Jobn'], ['START', 'AC', 'AC', 'END']],
#  [107, '', ['START', 'END']],
#  [108, '', ['START', 'END']],
#  ['109', ['45', 'Fulton'], ['START', 'AC', 'AC', 'END']],
#  [110, '', ['START', 'END']],
#  [111, '', ['START', 'END']],
#  [112, '', ['START', 'END']],
#  [113, '', ['START', 'END']],
#  [114, '', ['START', 'END']],
#  [115, '', ['START', 'END']],
#  [116, '', ['START', 'END']],
#  [117, '', ['START', 'END']],
#  [118, '', ['START', 'END']],
#  [119, '', ['START', 'END']],
#  ['120', ['Y'], ['START', 'NC', 'END']],
#  [121, '', ['START', 'END']],
#  [122, '', ['START', 'END']],
#  [123, '', ['START', 'END']],
#  [124, '', ['START', 'END']],
#  [125, '', ['START', 'END']],
#  ['126', ['Amity'], ['START', 'AC', 'END']],
#  [127, '', ['START', 'END']],
#  [128, '', ['START', 'END']],
#  [129, '', ['START', 'END']],
#  [130, '', ['START', 'END']],
#  [131, '', ['START', 'END']],
#  [132, '', ['START', 'END']],
#  ['133', ['257', 'Pearl'], ['START', 'AC', 'AC', 'END']],
#  [134, '', ['START', 'END']],
#  [135, '', ['START', 'END']],
#  ['136', ['63', 'Atlantic'], ['START', 'AC', 'AC', 'END']],
#  ['137', ['63', 'Atlantic'], ['START', 'AC', 'AC', 'END']],
#  [138, '', ['START', 'END']],
#  [139, '', ['START', 'END']],
#  [140, '', ['START', 'END']],
#  ['141', ['s', 'alley'], ['START', 'AC', 'AC', 'END']],
#  ['142', ['Y'], ['START', 'NC', 'END']],
#  [143, '', ['START', 'END']],
#  [144, '', ['START', 'END']],
#  [145, '', ['START', 'END']],
#  [146, '', ['START', 'END']],
#  [147, '', ['START', 'END']],
#  [148, '', ['START', 'END']],
#  ['149', ['Talman'], ['START', 'AC', 'END']],
#  [150, '', ['START', 'END']],
#  ['151', ['275', 'Broadway'], ['START', 'AC', 'AC', 'END']],
#  ['152', ['tionary', '262', 'Fulton'], ['START', 'AC', 'AC', 'AC', 'END']],
#  [153, '', ['START', 'END']],
#  [154, '', ['START', 'END']],
#  [155, '', ['START', 'END']],
#  [156, '', ['START', 'END']],
#  [157, '', ['START', 'END']],
#  [158, '', ['START', 'END']],
#  [159, '', ['START', 'END']],
#  ['160', ['Fulton'], ['START', 'AC', 'END']],
#  [161, '', ['START', 'END']],
#  ['162', ['150', 'Front'], ['START', 'AC', 'AC', 'END']],
#  ['163', ['Fulton', 'av'], ['START', 'AC', 'AC', 'END']],
#  [164, '', ['START', 'END']],
#  ['165', ['10', 'Old', 'Slip'], ['START', 'AC', 'AC', 'AC', 'END']],
#  [166, '', ['START', 'END']],
#  [167, '', ['START', 'END']],
#  [168, '', ['START', 'END']],
#  [169, '', ['START', 'END']],
#  [170, '', ['START', 'END']],
#  [171, '', ['START', 'END']],
#  [172, '', ['START', 'END']],
#  [173, '', ['START', 'END']],
#  [174, '', ['START', 'END']],
#  [175, '', ['START', 'END']],
#  ['176', ['Spruce'], ['START', 'AC', 'END']],
#  [177, '', ['START', 'END']],
#  [178, '', ['START', 'END']],
#  [179, '', ['START', 'END']],
#  [180, '', ['START', 'END']],
#  [181, '', ['START', 'END']],
#  [182, '', ['START', 'END']],
#  [183, '', ['START', 'END']],
#  [184, '', ['START', 'END']],
#  [185, '', ['START', 'END']],
#  [186, '', ['START', 'END']],
#  [187, '', ['START', 'END']],
#  [188, '', ['START', 'END']],
#  [189, '', ['START', 'END']],
#  [190, '', ['START', 'END']],
#  [191, '', ['START', 'END']],
#  ['192', ['tison'], ['START', 'AC', 'END']],
#  ['193', ['31', 'Broad'], ['START', 'AC', 'AC', 'END']],
#  [194, '', ['START', 'END']],
#  [195, '', ['START', 'END']],
#  [196, '', ['START', 'END']],
#  [197, '', ['START', 'END']],
#  ['198', ['Furman', 'n', 'State'], ['START', 'AC', 'AC', 'AC', 'END']],
#  ['199', ['222', 'Pearl'], ['START', 'AC', 'AC', 'END']],
#  ['200', ['29th', 'st', 'Gowanus'], ['START', 'AC', 'AC', 'AC', 'END']],
#  [201, '', ['START', 'END']],
#  [202, '', ['START', 'END']],
#  [203, '', ['START', 'END']],
#  [204, '', ['START', 'END']],
#  ['205', ['195', 'Washington'], ['START', 'AC', 'AC', 'END']],
#  ['206', ['102', 'Front'], ['START', 'AC', 'AC', 'END']],
#  [207, '', ['START', 'END']],
#  ['208', ['81', 'Water'], ['START', 'AC', 'AC', 'END']],
#  [209, '', ['START', 'END']],
#  [210, '', ['START', 'END']],
#  [211, '', ['START', 'END']],
#  [212, '', ['START', 'END']],
#  [213, '', ['START', 'END']],
#  [214, '', ['START', 'END']],
#  [215, '', ['START', 'END']],
#  [216, '', ['START', 'END']],
#  [217, '', ['START', 'END']],
#  [218, '', ['START', 'END']],
#  [219, '', ['START', 'END']],
#  [220, '', ['START', 'END']],
#  [221, '', ['START', 'END']],
#  [222, '', ['START', 'END']],
#  [223, '', ['START', 'END']],
#  [224, '', ['START', 'END']],
#  [225, '', ['START', 'END']],
#  [226, '', ['START', 'END']],
#  [227, '', ['START', 'END']],
#  [228, '', ['START', 'END']],
#  [229, '', ['START', 'END']],
#  [230, '', ['START', 'END']],
#  [231, '', ['START', 'END']],
#  [232, '', ['START', 'END']],
#  [233, '', ['START', 'END']],
#  [234, '', ['START', 'END']],
#  [235, '', ['START', 'END']],
#  [236, '', ['START', 'END']],
#  [237, '', ['START', 'END']],
#  [238, '', ['START', 'END']],
#  [239, '', ['START', 'END']],
#  [240, '', ['START', 'END']],
#  ['241', ['62', 'State'], ['START', 'AC', 'AC', 'END']],
#  [242, '', ['START', 'END']],
#  [243, '', ['START', 'END']],
#  [244, '', ['START', 'END']],
#  [245, '', ['START', 'END']],
#  [246, '', ['START', 'END']],
#  ['247', ['11', 'Water'], ['START', 'AC', 'AC', 'END']],
#  [248, '', ['START', 'END']],
#  [249, '', ['START', 'END']],
#  [250, '', ['START', 'END']],
#  [251, '', ['START', 'END']],
#  ['252', ['Court'], ['START', 'AC', 'END']],
#  ['253', ['32', 'Front'], ['START', 'AC', 'AC', 'END']],
#  [254, '', ['START', 'END']],
#  [255, '', ['START', 'END']],
#  [256, '', ['START', 'END']],
#  [257, '', ['START', 'END']],
#  [258, '', ['START', 'END']],
#  ['259', ['26', 'Fulton'], ['START', 'AC', 'AC', 'END']],
#  [260, '', ['START', 'END']],
#  [261, '', ['START', 'END']],
#  [262, '', ['START', 'END']],
#  [263, '', ['START', 'END']],
#  [264, '', ['START', 'END']],
#  [265, '', ['START', 'END']],
#  [266, '', ['START', 'END']],
#  [267, '', ['START', 'END']],
#  [268, '', ['START', 'END']],
#  [269, '', ['START', 'END']],
#  [270, '', ['START', 'END']],
#  [271, '', ['START', 'END']],
#  [272, '', ['START', 'END']],
#  ['273', ['Poplar'], ['START', 'AC', 'END']],
#  [274, '', ['START', 'END']],
#  [275, '', ['START', 'END']],
#  [276, '', ['START', 'END']],
#  [277, '', ['START', 'END']],
#  [278, '', ['START', 'END']],
#  [279, '', ['START', 'END']],
#  ['280',
#   ['Flushing', '&', 'c', 'Kent', 'av'],
#   ['START', 'AC', 'AC', 'AC', 'AC', 'AC', 'END']],
#  [281, '', ['START', 'END']],
#  [282, '', ['START', 'END']],
#  [283, '', ['START', 'END']],
#  [284, '', ['START', 'END']],
#  [285, '', ['START', 'END']],
#  [286, '', ['START', 'END']],
#  [287, '', ['START', 'END']],
#  [288, '', ['START', 'END']],
#  [289, '', ['START', 'END']],
#  [290, '', ['START', 'END']],
#  [291, '', ['START', 'END']],
#  ['292',
#   ['1', 'St', 'Johns', 'Lane'],
#   ['START', 'AC', 'AC', 'AC', 'AC', 'END']],
#  [293, '', ['START', 'END']],
#  [294, '', ['START', 'END']],
#  [295, '', ['START', 'END']],
#  [296, '', ['START', 'END']],
#  [297, '', ['START', 'END']],
#  [298, '', ['START', 'END']],
#  [299, '', ['START', 'END']],
#  [300, '', ['START', 'END']],
#  [301, '', ['START', 'END']],
#  [302, '', ['START', 'END']],
#  [303, '', ['START', 'END']],
#  ['304', ['123', 'Atlantic'], ['START', 'AC', 'AC', 'END']],
#  [305, '', ['START', 'END']],
#  [306, '', ['START', 'END']],
#  [307, '', ['START', 'END']],
#  [308, '', ['START', 'END']],
#  [309, '', ['START', 'END']],
#  ['310', ['Columbia'], ['START', 'AC', 'END']],
#  [311, '', ['START', 'END']],
#  [312, '', ['START', 'END']],
#  [313, '', ['START', 'END']],
#  [314, '', ['START', 'END']],
#  [315, '', ['START', 'END']],
#  ['316', ['274', 'Pearl'], ['START', 'AC', 'AC', 'END']],
#  [317, '', ['START', 'END']],
#  [318, '', ['START', 'END']],
#  [319, '', ['START', 'END']],
#  [320, '', ['START', 'END']],
#  [321, '', ['START', 'END']],
#  [322, '', ['START', 'END']],
#  [323, '', ['START', 'END']],
#  [324, '', ['START', 'END']],
#  [325, '', ['START', 'END']],
#  [326, '', ['START', 'END']],
#  [327, '', ['START', 'END']],
#  [328, '', ['START', 'END']],
#  [329, '', ['START', 'END']],
#  [330, '', ['START', 'END']],
#  [331, '', ['START', 'END']],
#  [332, '', ['START', 'END']],
#  ['333', ['Kent', 'ay'], ['START', 'AC', 'AC', 'END']],
#  [334, '', ['START', 'END']],
#  [335, '', ['START', 'END']],
#  [336, '', ['START', 'END']],
#  [337, '', ['START', 'END']],
#  [338, '', ['START', 'END']],
#  [339, '', ['START', 'END']],
#  [340, '', ['START', 'END']],
#  ['341', ['Columbia', 'c', 'Congress'], ['START', 'AC', 'AC', 'AC', 'END']],
#  [342, '', ['START', 'END']],
#  [343, '', ['START', 'END']],
#  [344, '', ['START', 'END']],
#  ['345', ['36', 'Ferry'], ['START', 'AC', 'AC', 'END']],
#  [346, '', ['START', 'END']],
#  [347, '', ['START', 'END']],
#  [348, '', ['START', 'END']],
#  [349, '', ['START', 'END']],
#  [350, '', ['START', 'END']],
#  [351, '', ['START', 'END']],
#  [352, '', ['START', 'END']],
#  [353, '', ['START', 'END']],
#  [354, '', ['START', 'END']],
#  ['355', ['40', 'New'], ['START', 'AC', 'AC', 'END']],
#  ['356', ['merchant'], ['START', 'AC', 'END']],
#  [357, '', ['START', 'END']],
#  [358, '', ['START', 'END']],
#  ['359',
#   ['hat', 'and', 'fur', 'store', '199', 'Fulton'],
#   ['START', 'AC', 'AC', 'AC', 'AC', 'AC', 'AC', 'END']],
#  ['360', ['Cranberry'], ['START', 'AC', 'END']],
#  ['361', ['Y'], ['START', 'NC', 'END']],
#  ['362', ['Orange'], ['START', 'AC', 'END']],
#  [363, '', ['START', 'END']],
#  [364, '', ['START', 'END']],
#  [365, '', ['START', 'END']],
#  [366, '', ['START', 'END']],
#  [367, '', ['START', 'END']],
#  [368, '', ['START', 'END']],
#  [369, '', ['START', 'END']],
#  [370, '', ['START', 'END']],
#  [371, '', ['START', 'END']],
#  [372, '', ['START', 'END']],
#  [373, '', ['START', 'END']],
#  [374, '', ['START', 'END']],
#  [375, '', ['START', 'END']],
#  [376, '', ['START', 'END']],
#  [377, '', ['START', 'END']],
#  [378, '', ['START', 'END']],
#  [379, '', ['START', 'END']],
#  [380, '', ['START', 'END']],
#  [381, '', ['START', 'END']],
#  [382, '', ['START', 'END']],
#  ['383', ['232', 'Fulton'], ['START', 'AC', 'AC', 'END']],
#  [384, '', ['START', 'END']],
#  ['385', ['79', 'Pearl'], ['START', 'AC', 'AC', 'END']],
#  [386, '', ['START', 'END']],
#  ['387', ['Prince'], ['START', 'AC', 'END']],
#  ['388', ['Water', 'n', 'Fulton'], ['START', 'AC', 'AC', 'AC', 'END']],
#  [389, '', ['START', 'END']],
#  ['390', ['Fulton', 'ferry'], ['START', 'AC', 'AC', 'END']],
#  [391, '', ['START', 'END']],
#  [392, '', ['START', 'END']],
#  [393, '', ['START', 'END']],
#  [394, '', ['START', 'END']],
#  [395, '', ['START', 'END']],
#  [396, '', ['START', 'END']],
#  [397, '', ['START', 'END']],
#  [398, '', ['START', 'END']],
#  ['399', ['60', 'Cherry'], ['START', 'AC', 'AC', 'END']],
#  [400, '', ['START', 'END']],
#  [401, '', ['START', 'END']],
#  [402, '', ['START', 'END']],
#  [403, '', ['START', 'END']],
#  [404, '', ['START', 'END']],
#  [405, '', ['START', 'END']],
#  [406, '', ['START', 'END']],
#  [407, '', ['START', 'END']],
#  [408, '', ['START', 'END']],
#  [409, '', ['START', 'END']],
#  [410, '', ['START', 'END']],
#  [411, '', ['START', 'END']],
#  [412, '', ['START', 'END']],
#  [413, '', ['START', 'END']],
#  [414, '', ['START', 'END']],
#  ['415', ['Sands', '&', 'Pearl'], ['START', 'NC', 'NC', 'NC', 'END']],
#  ['416', ['Phoenix', 'Bank'], ['START', 'NC', 'NC', 'END']],
#  ['417', ['Doughty', 'st'], ['START', 'AC', 'AC', 'END']],
#  ['418', ['106', 'Murray'], ['START', 'AC', 'AC', 'END']],
#  [419, '', ['START', 'END']],
#  [420, '', ['START', 'END']],
#  [421, '', ['START', 'END']],
#  [422, '', ['START', 'END']],
#  [423, '', ['START', 'END']],
#  [424, '', ['START', 'END']],
#  [425, '', ['START', 'END']],
#  ['426', ['42', 'Fulton', 'N'], ['START', 'AC', 'AC', 'AC', 'END']],
#  [427, '', ['START', 'END']],
#  [428, '', ['START', 'END']],
#  [429, '', ['START', 'END']],
#  [430, '', ['START', 'END']],
#  [431, '', ['START', 'END']],
#  [432, '', ['START', 'END']],
#  [433, '', ['START', 'END']],
#  [434, '', ['START', 'END']],
#  ['435', ['Degraw'], ['START', 'NC', 'END']],
#  [436, '', ['START', 'END']],
#  [437, '', ['START', 'END']],
#  [438, '', ['START', 'END']],
#  [439, '', ['START', 'END']],
#  [440, '', ['START', 'END']],
#  ['441', ['59', 'Pearl'], ['START', 'AC', 'AC', 'END']],
#  [442, '', ['START', 'END']],
#  [443, '', ['START', 'END']],
#  [444, '', ['START', 'END']],
#  [445, '', ['START', 'END']],
#  [446, '', ['START', 'END']],
#  [447, '', ['START', 'END']],
#  [448, '', ['START', 'END']],
#  [449, '', ['START', 'END']],
#  [450, '', ['START', 'END']],
#  ['451', ['Hoyt', 'n', 'Atlantic'], ['START', 'AC', 'AC', 'AC', 'END']],
#  [452, '', ['START', 'END']],
#  [453, '', ['START', 'END']],
#  [454, '', ['START', 'END']],
#  ['455', ['150', 'Nassau'], ['START', 'AC', 'AC', 'END']],
#  ['456', ['71', 'Nassau'], ['START', 'AC', 'AC', 'END']],
#  ['457', ['76', 'Broad', 'N', 'VY'], ['START', 'AC', 'AC', 'AC', 'AC', 'END']],
#  [458, '', ['START', 'END']],
#  ['459', ['Little', 'Dock'], ['START', 'NC', 'NC', 'END']],
#  [460, '', ['START', 'END']],
#  [461, '', ['START', 'END']],
#  [462, '', ['START', 'END']],
#  [463, '', ['START', 'END']],
#  ['464', ['32', 'Pearl'], ['START', 'AC', 'AC', 'END']],
#  [465, '', ['START', 'END']],
#  [466, '', ['START', 'END']],
#  [467, '', ['START', 'END']],
#  [468, '', ['START', 'END']],
#  ['469', ['18', 'South'], ['START', 'AC', 'AC', 'END']],
#  [470, '', ['START', 'END']],
#  [471, '', ['START', 'END']],
#  [472, '', ['START', 'END']],
#  [473, '', ['START', 'END']],
#  ['474',
#   ['merch', '&', 't116', 'WallN'],
#   ['START', 'PA', 'AC', 'AC', 'AC', 'END']],
#  [475, '', ['START', 'END']],
#  ['476', ['71', 'Wall'], ['START', 'AC', 'AC', 'END']],
#  [477, '', ['START', 'END']],
#  [478, '', ['START', 'END']],
#  [479, '', ['START', 'END']],
#  ['480', ['179', 'Broadway'], ['START', 'AC', 'AC', 'END']],
#  [481, '', ['START', 'END']],
#  [482, '', ['START', 'END']],
#  [483, '', ['START', 'END']],
#  [484, '', ['START', 'END']],
#  [485, '', ['START', 'END']],
#  [486, '', ['START', 'END']],
#  [487, '', ['START', 'END']],
#  [488, '', ['START', 'END']],
#  [489, '', ['START', 'END']],
#  [490, '', ['START', 'END']],
#  [491, '', ['START', 'END']],
#  [492, '', ['START', 'END']],
#  [493, '', ['START', 'END']],
#  [494, '', ['START', 'END']],
#  ['495', ['100', 'William'], ['START', 'AC', 'AC', 'END']],
#  [496, '', ['START', 'END']],
#  ['497', ['Buildings', 'Court', 'st'], ['START', 'NC', 'AC', 'AC', 'END']],
#  [498, '', ['START', 'END']],
#  [499, '', ['START', 'END']],
#  [500, '', ['START', 'END']],
#  [501, '', ['START', 'END']],
#  [502, '', ['START', 'END']],
#  ['503', ['Hicks'], ['START', 'NC', 'END']],
#  ['504', ['26', 'Broad'], ['START', 'AC', 'AC', 'END']],
#  [505, '', ['START', 'END']],
#  [506, '', ['START', 'END']],
#  [507, '', ['START', 'END']],
#  [508, '', ['START', 'END']],
#  [509, '', ['START', 'END']],
#  [510, '', ['START', 'END']],
#  ['511', ['VY'], ['START', 'AC', 'END']],
#  [512, '', ['START', 'END']],
#  [513, '', ['START', 'END']],
#  [514, '', ['START', 'END']],
#  [515, '', ['START', 'END']],
#  [516, '', ['START', 'END']],
#  [517, '', ['START', 'END']],
#  [518, '', ['START', 'END']],
#  [519, '', ['START', 'END']],
#  [520, '', ['START', 'END']],
#  [521, '', ['START', 'END']],
#  ['522', ['wanus'], ['START', 'AC', 'END']],
#  [523, '', ['START', 'END']],
#  [524, '', ['START', 'END']],
#  [525, '', ['START', 'END']],
#  [526, '', ['START', 'END']],
#  [527, '', ['START', 'END']],
#  [528, '', ['START', 'END']],
#  [529, '', ['START', 'END']],
#  [530, '', ['START', 'END']],
#  [531, '', ['START', 'END']],
#  [532, '', ['START', 'END']],
#  [533, '', ['START', 'END']],
#  [534, '', ['START', 'END']],
#  ['535', ['Warren'], ['START', 'AC', 'END']],
#  ['536', ['12', 'Broadway'], ['START', 'AC', 'AC', 'END']],
#  [537, '', ['START', 'END']],
#  [538, '', ['START', 'END']],
#  ['539', ['11', 'Wall'], ['START', 'AC', 'AC', 'END']],
#  [540, '', ['START', 'END']],
#  ['541', ['4', 'Cortlandt'], ['START', 'AC', 'AC', 'END']],
#  ['542', ['67', 'William'], ['START', 'AC', 'AC', 'END']],
#  ['543', ['52', 'Cedar'], ['START', 'AC', 'AC', 'END']],
#  ['544', ['1836', 'Nassaa'], ['START', 'AC', 'AC', 'END']],
#  ['545', ['42', 'Fulton'], ['START', 'AC', 'AC', 'END']],
#  [546, '', ['START', 'END']],
#  [547, '', ['START', 'END']],
#  [548, '', ['START', 'END']],
#  [549, '', ['START', 'END']],
#  [550, '', ['START', 'END']],
#  ['551', ['Court'], ['START', 'AC', 'END']],
#  [552, '', ['START', 'END']],
#  [553, '', ['START', 'END']],
#  [554, '', ['START', 'END']],
#  [555, '', ['START', 'END']],
#  [556, '', ['START', 'END']],
#  [557, '', ['START', 'END']],
#  [558, '', ['START', 'END']],
#  [559, '', ['START', 'END']],
#  [560, '', ['START', 'END']],
#  [561, '', ['START', 'END']],
#  ['562', ['John', 'n', 'Bridge'], ['START', 'AC', 'AC', 'AC', 'END']],
#  [563, '', ['START', 'END']],
#  [564, '', ['START', 'END']],
#  [565, '', ['START', 'END']],
#  [566, '', ['START', 'END']],
#  [567, '', ['START', 'END']],
#  [568, '', ['START', 'END']],
#  ['569', ['179', 'Water'], ['START', 'AC', 'AC', 'END']],
#  ['570', ['Remsen', 'u', 'Henry'], ['START', 'AC', 'AC', 'AC', 'END']],
#  [571, '', ['START', 'END']],
#  ['572', ['45', 'South'], ['START', 'AC', 'AC', 'END']],
#  [573, '', ['START', 'END']],
#  [574, '', ['START', 'END']],
#  ['575', ['Hamilton', 'ay'], ['START', 'AC', 'AC', 'END']],
#  [576, '', ['START', 'END']],
#  [577, '', ['START', 'END']],
#  [578, '', ['START', 'END']],
#  [579, '', ['START', 'END']],
#  [580, '', ['START', 'END']],
#  ['581', ['60', 'Catherine'], ['START', 'AC', 'AC', 'END']],
#  [582, '', ['START', 'END']],
#  [583, '', ['START', 'END']],
#  [584, '', ['START', 'END']],
#  [585, '', ['START', 'END']],
#  ['586', ['17', 'Atlantic'], ['START', 'AC', 'AC', 'END']],
#  [587, '', ['START', 'END']],
#  [588, '', ['START', 'END']],
#  [589, '', ['START', 'END']],
#  [590, '', ['START', 'END']],
#  [591, '', ['START', 'END']],
#  [592, '', ['START', 'END']],
#  [593, '', ['START', 'END']],
#  [594, '', ['START', 'END']],
#  [595, '', ['START', 'END']],
#  [596, '', ['START', 'END']],
#  [597, '', ['START', 'END']],
#  [598, '', ['START', 'END']],
#  [599, '', ['START', 'END']],
#  [600, '', ['START', 'END']],
#  [601, '', ['START', 'END']],
#  [602, '', ['START', 'END']],
#  [603, '', ['START', 'END']],
#  [604, '', ['START', 'END']],
#  [605, '', ['START', 'END']],
#  [606, '', ['START', 'END']],
#  [607, '', ['START', 'END']],
#  [608, '', ['START', 'END']],
#  [609, '', ['START', 'END']],
#  [610, '', ['START', 'END']],
#  [611, '', ['START', 'END']],
#  [612, '', ['START', 'END']],
#  ['613', ['Henry'], ['START', 'AC', 'END']],
#  ['614', ['63', 'Water'], ['START', 'AC', 'AC', 'END']],
#  [615, '', ['START', 'END']],
#  [616, '', ['START', 'END']],
#  [617, '', ['START', 'END']],
#  [618, '', ['START', 'END']],
#  [619, '', ['START', 'END']],
#  [620, '', ['START', 'END']],
#  [621, '', ['START', 'END']],
#  [622, '', ['START', 'END']],
#  [623, '', ['START', 'END']],
#  ['624', ['123', 'Pearl', 'NW'], ['START', 'AC', 'AC', 'AC', 'END']],
#  [625, '', ['START', 'END']],
#  ['626', ['121', 'Greenwich'], ['START', 'AC', 'AC', 'END']],
#  [627, '', ['START', 'END']],
#  [628, '', ['START', 'END']],
#  [629, '', ['START', 'END']],
#  [630, '', ['START', 'END']],
#  [631, '', ['START', 'END']],
#  [632, '', ['START', 'END']],
#  [633, '', ['START', 'END']],
#  [634, '', ['START', 'END']],
#  [635, '', ['START', 'END']],
#  [636, '', ['START', 'END']],
#  [637, '', ['START', 'END']],
#  [638, '', ['START', 'END']],
#  [639, '', ['START', 'END']],
#  [640, '', ['START', 'END']],
#  [641, '', ['START', 'END']],
#  [642, '', ['START', 'END']],
#  [643, '', ['START', 'END']],
#  ['644', ['27th', 'st', 'Gowanus'], ['START', 'AC', 'AC', 'AC', 'END']],
#  [645, '', ['START', 'END']],
#  [646, '', ['START', 'END']],
#  [647, '', ['START', 'END']],
#  ['648', ['351', 'Broadway'], ['START', 'AC', 'AC', 'END']],
#  [649, '', ['START', 'END']],
#  ['650', ['Water', 'n', 'Fulton'], ['START', 'AC', 'AC', 'AC', 'END']],
#  [651, '', ['START', 'END']],
#  [652, '', ['START', 'END']],
#  [653, '', ['START', 'END']],
#  [654, '', ['START', 'END']],
#  [655, '', ['START', 'END']],
#  [656, '', ['START', 'END']],
#  [657, '', ['START', 'END']],
#  [658, '', ['START', 'END']],
#  [659, '', ['START', 'END']],
#  [660, '', ['START', 'END']],
#  [661, '', ['START', 'END']],
#  [662, '', ['START', 'END']],
#  [663, '', ['START', 'END']],
#  [664, '', ['START', 'END']],
#  [665, '', ['START', 'END']],
#  ['666', ['Myrtle', 'ay'], ['START', 'AC', 'AC', 'END']],
#  [667, '', ['START', 'END']],
#  [668, '', ['START', 'END']],
#  [669, '', ['START', 'END']],
#  [670, '', ['START', 'END']],
#  [671, '', ['START', 'END']],
#  [672, '', ['START', 'END']],
#  [673, '', ['START', 'END']],
#  ['674',
#   ['Myrtle', 'n', 'Classon', 'av'],
#   ['START', 'AC', 'AC', 'AC', 'AC', 'END']],
#  [675, '', ['START', 'END']],
#  [676, '', ['START', 'END']],
#  [677, '', ['START', 'END']],
#  [678, '', ['START', 'END']],
#  ['679', ['Myrtleav'], ['START', 'AC', 'END']],
#  [680, '', ['START', 'END']],
#  [681, '', ['START', 'END']],
#  [682, '', ['START', 'END']],
#  [683, '', ['START', 'END']],
#  ['684', ['8', 'Maiden', 'Lane'], ['START', 'AC', 'AC', 'AC', 'END']],
#  [685, '', ['START', 'END']],
#  [686, '', ['START', 'END']],
#  [687, '', ['START', 'END']],
#  [688, '', ['START', 'END']],
#  [689, '', ['START', 'END']],
#  [690, '', ['START', 'END']],
#  [691, '', ['START', 'END']],
#  ['692', ['31', 'Henry'], ['START', 'AC', 'AC', 'END']],
#  [693, '', ['START', 'END']],
#  [694, '', ['START', 'END']],
#  [695, '', ['START', 'END']],
#  ['696', ['Gowanus'], ['START', 'NC', 'END']],
#  [697, '', ['START', 'END']],
#  [698, '', ['START', 'END']],
#  [699, '', ['START', 'END']],
#  [700, '', ['START', 'END']],
#  [701, '', ['START', 'END']],
#  [702, '', ['START', 'END']],
#  [703, '', ['START', 'END']],
#  ['704', ['Boerum', 'n', 'Schermerhorn'], ['START', 'AC', 'AC', 'AC', 'END']],
#  [705, '', ['START', 'END']],
#  [706, '', ['START', 'END']],
#  [707, '', ['START', 'END']],
#  ['708', ['58', 'Myrile', 'av'], ['START', 'AC', 'AC', 'AC', 'END']],
#  [709, '', ['START', 'END']],
#  ['710', ['58', 'Myrtle', 'av'], ['START', 'AC', 'AC', 'AC', 'END']],
#  [711, '', ['START', 'END']],
#  [712, '', ['START', 'END']],
#  ['713', ['115', 'Fulton'], ['START', 'AC', 'AC', 'END']],
#  [714, '', ['START', 'END']],
#  ['715', ['Pacific'], ['START', 'AC', 'END']],
#  ['716', ['merchant', '70', 'Cortlandt'], ['START', 'AC', 'AC', 'AC', 'END']],
#  [717, '', ['START', 'END']],
#  [718, '', ['START', 'END']],
#  [719, '', ['START', 'END']],
#  [720, '', ['START', 'END']],
#  [721, '', ['START', 'END']],
#  [722, '', ['START', 'END']],
#  [723, '', ['START', 'END']],
#  [724, '', ['START', 'END']],
#  [725, '', ['START', 'END']],
#  [726, '', ['START', 'END']],
#  [727, '', ['START', 'END']],
#  ['728', ['Court', 'Main', 'st'], ['START', 'AC', 'AC', 'AC', 'END']],
#  [729, '', ['START', 'END']],
#  ['730', ['Pearl'], ['START', 'AC', 'END']],
#  [731, '', ['START', 'END']],
#  [732, '', ['START', 'END']],
#  [733, '', ['START', 'END']],
#  [734, '', ['START', 'END']],
#  [735, '', ['START', 'END']],
#  [736, '', ['START', 'END']],
#  [737, '', ['START', 'END']],
#  [738, '', ['START', 'END']],
#  [739, '', ['START', 'END']],
#  [740, '', ['START', 'END']],
#  [741, '', ['START', 'END']],
#  ['742', ['Y'], ['START', 'NC', 'END']],
#  [743, '', ['START', 'END']],
#  [744, '', ['START', 'END']],
#  ['745', ['33', 'Fulton'], ['START', 'AC', 'AC', 'END']],
#  [746, '', ['START', 'END']],
#  [747, '', ['START', 'END']],
#  [748, '', ['START', 'END']],
#  [749, '', ['START', 'END']],
#  [750, '', ['START', 'END']],
#  [751, '', ['START', 'END']],
#  [752, '', ['START', 'END']],
#  ['753', ['Buildings', 'Court', 'st'], ['START', 'NC', 'AC', 'AC', 'END']],
#  [754, '', ['START', 'END']],
#  [755, '', ['START', 'END']],
#  ['756', ['Express', 'office'], ['START', 'AC', 'AC', 'END']],
#  [757, '', ['START', 'END']],
#  [758, '', ['START', 'END']],
#  [759, '', ['START', 'END']],
#  [760, '', ['START', 'END']],
#  [761, '', ['START', 'END']],
#  [762, '', ['START', 'END']],
#  [763, '', ['START', 'END']],
#  [764, '', ['START', 'END']],
#  [765, '', ['START', 'END']],
#  [766, '', ['START', 'END']],
#  [767, '', ['START', 'END']],
#  [768, '', ['START', 'END']],
#  [769, '', ['START', 'END']],
#  [770, '', ['START', 'END']],
#  [771, '', ['START', 'END']],
#  [772, '', ['START', 'END']],
#  [773, '', ['START', 'END']],
#  [774, '', ['START', 'END']],
#  [775, '', ['START', 'END']],
#  [776, '', ['START', 'END']],
#  [777, '', ['START', 'END']],
#  [778, '', ['START', 'END']],
#  [779, '', ['START', 'END']],
#  [780, '', ['START', 'END']],
#  ['781', ['234', 'Fulton'], ['START', 'AC', 'AC', 'END']],
#  [782, '', ['START', 'END']],
#  [783, '', ['START', 'END']],
#  [784, '', ['START', 'END']],
#  [785, '', ['START', 'END']],
#  [786, '', ['START', 'END']],
#  [787, '', ['START', 'END']],
#  [788, '', ['START', 'END']],
#  [789, '', ['START', 'END']],
#  [790, '', ['START', 'END']],
#  [791, '', ['START', 'END']],
#  [792, '', ['START', 'END']],
#  [793, '', ['START', 'END']],
#  [794, '', ['START', 'END']],
#  [795, '', ['START', 'END']],
#  [796, '', ['START', 'END']],
#  [797, '', ['START', 'END']],
#  [798, '', ['START', 'END']],
#  [799, '', ['START', 'END']],
#  [800, '', ['START', 'END']],
#  [801, '', ['START', 'END']],
#  ['802', ['Nassau'], ['START', 'AC', 'END']],
#  ['803', ['17', 'Park', 'Placa'], ['START', 'AC', 'AC', 'AC', 'END']],
#  [804, '', ['START', 'END']],
#  [805, '', ['START', 'END']],
#  [806, '', ['START', 'END']],
#  [807, '', ['START', 'END']],
#  ['808', ['Water'], ['START', 'AC', 'END']],
#  [809, '', ['START', 'END']],
#  [810, '', ['START', 'END']],
#  ['811', ['72', 'Pine'], ['START', 'AC', 'AC', 'END']],
#  [812, '', ['START', 'END']],
#  [813, '', ['START', 'END']],
#  [814, '', ['START', 'END']],
#  ['815', ['Nassau'], ['START', 'AC', 'END']],
#  [816, '', ['START', 'END']],
#  [817, '', ['START', 'END']],
#  ['818', ['Schermerhorn'], ['START', 'AC', 'END']],
#  ['819', ['Columbia', '&', 'Pacific'], ['START', 'NC', 'NC', 'NC', 'END']],
#  [820, '', ['START', 'END']],
#  ['821', ['ston'], ['START', 'AC', 'END']],
#  [822, '', ['START', 'END']],
#  [823, '', ['START', 'END']],
#  [824, '', ['START', 'END']],
#  [825, '', ['START', 'END']],
#  [826, '', ['START', 'END']],
#  [827, '', ['START', 'END']],
#  [828, '', ['START', 'END']],
#  ['829', ['59', 'Broadway'], ['START', 'AC', 'AC', 'END']],
#  [830, '', ['START', 'END']],
#  [831, '', ['START', 'END']],
#  [832, '', ['START', 'END']],
#  [833, '', ['START', 'END']],
#  [834, '', ['START', 'END']],
#  ['835', ['62', 'Pine'], ['START', 'AC', 'AC', 'END']],
#  [836, '', ['START', 'END']],
#  [837, '', ['START', 'END']],
#  [838, '', ['START', 'END']],
#  [839, '', ['START', 'END']],
#  ['840', ['Adams', '&', 'York'], ['START', 'NC', 'NC', 'NC', 'END']],
#  [841, '', ['START', 'END']],
#  ['842', ['24', 'Cedar'], ['START', 'AC', 'AC', 'END']],
#  ['843',
#   ['western', 'insurance', 'office'],
#   ['START', 'AC', 'AC', 'AC', 'END']],
#  [844, '', ['START', 'END']],
#  [845, '', ['START', 'END']],
#  [846, '', ['START', 'END']],
#  [847, '', ['START', 'END']],
#  [848, '', ['START', 'END']],
#  [849, '', ['START', 'END']],
#  [850, '', ['START', 'END']],
#  [851, '', ['START', 'END']],
#  [852, '', ['START', 'END']],
#  [853, '', ['START', 'END']],
#  [854, '', ['START', 'END']],
#  [855, '', ['START', 'END']],
#  [856, '', ['START', 'END']],
#  [857, '', ['START', 'END']],
#  [858, '', ['START', 'END']],
#  ['859', ['Adams'], ['START', 'NC', 'END']],
#  [860, '', ['START', 'END']],
#  ['861', ['Fulton', 'market'], ['START', 'AC', 'AC', 'END']],
#  [862, '', ['START', 'END']],
#  [863, '', ['START', 'END']],
#  [864, '', ['START', 'END']],
#  ['865', ['159', 'Pearl'], ['START', 'AC', 'AC', 'END']],
#  [866, '', ['START', 'END']],
#  [867, '', ['START', 'END']],
#  [868, '', ['START', 'END']],
#  [869, '', ['START', 'END']],
#  ['870', ['181', 'Broadway'], ['START', 'AC', 'AC', 'END']],
#  [871, '', ['START', 'END']],
#  [872, '', ['START', 'END']],
#  [873, '', ['START', 'END']],
#  [874, '', ['START', 'END']],
#  [875, '', ['START', 'END']],
#  ['876', ['Prince'], ['START', 'AC', 'END']],
#  ['877', ['60', 'Pine'], ['START', 'AC', 'AC', 'END']],
#  ['878', ['mercht19', 'Cortlandt'], ['START', 'AC', 'AC', 'END']],
#  ['879', ['34', 'Beaver'], ['START', 'AC', 'AC', 'END']],
#  [880, '', ['START', 'END']],
#  ['881', ['147', 'Broadway'], ['START', 'AC', 'AC', 'END']],
#  [882, '', ['START', 'END']],
#  [883, '', ['START', 'END']],
#  [884, '', ['START', 'END']],
#  [885, '', ['START', 'END']],
#  [886, '', ['START', 'END']],
#  ['887', ['145', 'Broad'], ['START', 'AC', 'AC', 'END']],
#  [888, '', ['START', 'END']],
#  [889, '', ['START', 'END']],
#  [890, '', ['START', 'END']],
#  [891, '', ['START', 'END']],
#  [892, '', ['START', 'END']],
#  [893, '', ['START', 'END']],
#  [894, '', ['START', 'END']],
#  [895, '', ['START', 'END']],
#  [896, '', ['START', 'END']],
#  [897, '', ['START', 'END']],
#  [898, '', ['START', 'END']],
#  [899, '', ['START', 'END']],
#  [900, '', ['START', 'END']],
#  ['901', ['5', 'South'], ['START', 'AC', 'AC', 'END']],
#  [902, '', ['START', 'END']],
#  [903, '', ['START', 'END']],
#  ['904',
#   ['6', 'Linden', 'row', 'Fulton'],
#   ['START', 'AC', 'AC', 'AC', 'AC', 'END']],
#  [905, '', ['START', 'END']],
#  [906, '', ['START', 'END']],
#  ['907', ['225', 'Atlantic'], ['START', 'AC', 'AC', 'END']],
#  [908, '', ['START', 'END']],
#  [909, '', ['START', 'END']],
#  ['910', ['111', 'Beekman'], ['START', 'AC', 'AC', 'END']],
#  [911, '', ['START', 'END']],
#  ['912', ['Pacifie', 'n', 'Court'], ['START', 'AC', 'AC', 'AC', 'END']],
#  [913, '', ['START', 'END']],
#  ['914', ['145', 'Nassau'], ['START', 'AC', 'AC', 'END']],
#  [915, '', ['START', 'END']],
#  [916, '', ['START', 'END']],
#  ['917', ['Willoughby', 'c', 'Pear'], ['START', 'AC', 'AC', 'AC', 'END']],
#  ['918',
#   ['6', 'Linden', 'row', 'Fulton'],
#   ['START', 'AC', 'AC', 'AC', 'AC', 'END']],
#  ['919', ['159', 'Myrtle'], ['START', 'AC', 'AC', 'END']],
#  [920, '', ['START', 'END']],
#  ['921', ['Concord'], ['START', 'AC', 'END']],
#  [922, '', ['START', 'END']],
#  ['923', ['s', 'alley'], ['START', 'AC', 'AC', 'END']],
#  [924, '', ['START', 'END']],
#  [925, '', ['START', 'END']],
#  [926, '', ['START', 'END']],
#  [927, '', ['START', 'END']],
#  [928, '', ['START', 'END']],
#  [929, '', ['START', 'END']],
#  [930, '', ['START', 'END']],
#  [931, '', ['START', 'END']],
#  [932, '', ['START', 'END']],
#  [933, '', ['START', 'END']],
#  ['934',
#   ['165', 'Maiden', 'Lane', 'Y'],
#   ['START', 'AC', 'AC', 'AC', 'AC', 'END']],
#  [935, '', ['START', 'END']],
#  [936, '', ['START', 'END']],
#  [937, '', ['START', 'END']],
#  [938, '', ['START', 'END']],
#  [939, '', ['START', 'END']],
#  [940, '', ['START', 'END']],
#  [941, '', ['START', 'END']],
#  [942, '', ['START', 'END']],
#  [943, '', ['START', 'END']],
#  [944, '', ['START', 'END']],
#  [945, '', ['START', 'END']],
#  ['946',
#   ['Park', 'c', 'Franklin', 'ay'],
#   ['START', 'AC', 'AC', 'AC', 'AC', 'END']],
#  ['947', ['42', 'Water'], ['START', 'AC', 'AC', 'END']],
#  [948, '', ['START', 'END']],
#  ['949', ['38', 'South'], ['START', 'AC', 'AC', 'END']],
#  [950, '', ['START', 'END']],
#  [951, '', ['START', 'END']],
#  [952, '', ['START', 'END']],
#  ['953', ['38', 'South'], ['START', 'AC', 'AC', 'END']],
#  [954, '', ['START', 'END']],
#  [955, '', ['START', 'END']],
#  [956, '', ['START', 'END']],
#  ['957', ['Hoyt'], ['START', 'AC', 'END']],
#  ['958', ['105', 'Wall'], ['START', 'AC', 'AC', 'END']],
#  [959, '', ['START', 'END']],
#  [960, '', ['START', 'END']],
#  [961, '', ['START', 'END']],
#  [962, '', ['START', 'END']],
#  [963, '', ['START', 'END']],
#  [964, '', ['START', 'END']],
#  [965, '', ['START', 'END']],
#  [966, '', ['START', 'END']],
#  [967, '', ['START', 'END']],
#  [968, '', ['START', 'END']],
#  [969, '', ['START', 'END']],
#  [970, '', ['START', 'END']],
#  [971, '', ['START', 'END']],
#  ['972', ['57', 'Water'], ['START', 'AC', 'AC', 'END']],
#  ['973', ['Fulton', 'c', 'Furman'], ['START', 'AC', 'AC', 'AC', 'END']],
#  [974, '', ['START', 'END']],
#  [975, '', ['START', 'END']],
#  [976, '', ['START', 'END']],
#  [977, '', ['START', 'END']],
#  [978, '', ['START', 'END']],
#  [979, '', ['START', 'END']],
#  [980, '', ['START', 'END']],
#  [981, '', ['START', 'END']],
#  [982, '', ['START', 'END']],
#  ['983', ['y', '&', 's', 'alley'], ['START', 'AC', 'AC', 'AC', 'AC', 'END']],
#  ['984', ['Atlautic'], ['START', 'AC', 'END']],
#  ['985', ['182', 'Jay'], ['START', 'AC', 'AC', 'END']],
#  ['986', ['Washington', 'market'], ['START', 'AC', 'AC', 'END']],
#  [987, '', ['START', 'END']],
#  [988, '', ['START', 'END']],
#  [989, '', ['START', 'END']],
#  [990, '', ['START', 'END']],
#  [991, '', ['START', 'END']],
#  [992, '', ['START', 'END']],
#  ['993', ['50', 'South'], ['START', 'AC', 'AC', 'END']],
#  [994, '', ['START', 'END']],
#  [995, '', ['START', 'END']],
#  [996, '', ['START', 'END']],
#  ['997', ['Henry'], ['START', 'AC', 'END']],
#  [998, '', ['START', 'END']],
#  ['999', ['46', 'Front'], ['START', 'AC', 'AC', 'END']],
#  ...]

# %%
#pickle the list to save preliminary result
#with open("/Users/prajwal/Desktop/Columbia/C4SR/doubt/doubt6-filter11.pkl", "wb") as f:


#with open('/Users/prajwal/Desktop/Columbia/C4SR/mn_1880/not so confident-mn1880-v7.pkl', "wb") as f:
  #pickle.dump(formatted,f)
    
    
with open('bk-1850-3-address2.pkl', "wb") as f:
  pickle.dump(formatted,f)

# %%
#pickle the list to save preliminary result
#with open("/Users/prajwal/Desktop/Columbia/C4SR/hnyc_cd_processing-master/input/1880/prediction.pkl", "wb") as f:
  #pickle.dump(formatted,f)
