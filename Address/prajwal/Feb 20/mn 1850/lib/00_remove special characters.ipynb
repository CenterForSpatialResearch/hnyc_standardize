# %%
import pandas as pd
import re
import collections

# %%
df = pd.read_csv('/Users/prajwal/Desktop/Columbia/C4SR/tesseract lib/mn 1850/data/MN_1850_final_output_tesseract.csv')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Full Name', 'First Name', 'Last Name', 'Middle Name',
#        'Widow-flag', 'Widow Of', 'Title', 'Occupation', 'Full Address',
#        'H Status-flag', 'H Address', 'H House Number', 'H Street Name',
#        'H City', 'Address 2', 'Address 2 House Number',
#        'Address 2 Street Name', 'Address 2 City'],
#       dtype='object')

# %%
#df['Full Address']

# %%
"""
for a in range(0, len(df)):
    print(a)
    #df['Full Address'][a] = str(df['Full Address'][a]).replace('Ç','C')
    #df['Full Address'][a] = str(df['Full Address'][a]).replace('√','Y')
    df['Full Address'][a] = str(df['Full Address'][a]).replace('¬',' ')
    df['Full Address'][a] = str(df['Full Address'][a]).replace('•',' ')
    df['Full Address'][a] = str(df['Full Address'][a]).replace('¢','c')
    
    
    # bottom part also commented out
    
    for i in range(0, 10):
        df['Full Address'][a] = str(df['Full Address'][a]).replace('&&','&')
    """
# Out:
# "\nfor a in range(0, len(df)):\n    print(a)\n    #df['Full Address'][a] = str(df['Full Address'][a]).replace('Ç','C')\n    #df['Full Address'][a] = str(df['Full Address'][a]).replace('√','Y')\n    df['Full Address'][a] = str(df['Full Address'][a]).replace('¬',' ')\n    df['Full Address'][a] = str(df['Full Address'][a]).replace('•',' ')\n    df['Full Address'][a] = str(df['Full Address'][a]).replace('¢','c')\n    \n    \n    # bottom part also commented out\n    \n    for i in range(0, 10):\n        df['Full Address'][a] = str(df['Full Address'][a]).replace('&&','&')\n    "

# %%
for a in range(0, len(df)):
    if '.5' in str(df['Full Address'][a]):
        print(a)
        df.at[a, 'Full Address'] = df['Full Address'][a].replace('.5','')
    if ',' in str(df['Full Address'][a]):
        df.at[a, 'Full Address'] = df['Full Address'][a].replace(',','')
    if '.' in str(df['Full Address'][a]):
        df.at[a, 'Full Address'] = df['Full Address'][a].replace('.','')
    if '  ' in str(df['Full Address'][a]):
        df.at[a, 'Full Address'] = df['Full Address'][a].replace('  ',' ')

# %%
temp_replace_specials = {}
for a in range(0, len(df)):
    temp_str = re.sub('[^A-Za-z0-9]', ' ', str(df['Full Address'][a]))
    temp_str = temp_str.replace('&  &', '&x', 100).replace(' & ', ' ', 100).replace('&x', '&', 100).replace('&  &', '&', 100).replace('  ', ' & ').replace('&  &', '&', 100).replace('  ', ' ', 100)
    temp_str = temp_str.replace('Yh', 'Y h', 100)
    temp_str = temp_str.replace('NYh', 'NY h', 100)
    temp_str = temp_str.replace(' b ', ' h ', 100)
    temp_str = temp_str.replace('YV', 'W', 100)
    temp_str = temp_str.replace('Ayn', ' Av n ', 100)
    temp_str = temp_str.replace('avn', ' Av n ', 100)
    temp_str = temp_str.replace('Avy', ' Av ', 100)
    temp_str = temp_str.replace('.', '', 100)
    #temp_str = temp_str.replace(',', '', 100)
    temp_str = temp_str.replace(',', '', 100)
    temp_str = temp_str.replace('  ', ' ', 100)
    
    for i in range(0, 10):
        try:
            if temp_str.index('h'+str(i))>=0:
                #print(a,i,'yes')
                temp_str = temp_str.replace('h'+str(i), 'h '+str(i), 100)
        except:
            pass
    temp_replace_specials[a] = temp_str

# %%
temp_replace_specials[6]
# Out:
# '586 E 4th'

# %%
temp_replace_specials[451].split()
# Out:
# ['h', '646', 'Hudson']

# %%
#temp_replace_specials[435].split().index('&')

# %%
def hasNumbers(inputString):
    return any(char.isdigit() for char in inputString)

# %%
part_after_h = {}
part_before_h = {}
part_before_and = {}
part_after_and = {}

for a in range(0, len(df)):
    loc_of_h = -1
    loc_of_and = -1
    try:
        loc_of_h = temp_replace_specials[a].split().index('h')
    except:
        pass
    try:
        loc_of_and = temp_replace_specials[a].split().index('&')
    except:
        pass
    if loc_of_h >= 0:
        part_after_h[a] = ' '.join(temp_replace_specials[a].split()[loc_of_h+1:])
        part_before_h[a] = ' '.join(temp_replace_specials[a].split()[0:loc_of_h-1])
    
    if loc_of_h < 0 and loc_of_and >= 0:
        temp_part_before_and = ' '.join(temp_replace_specials[a].split()[0:loc_of_and])
        if hasNumbers(temp_part_before_and):
            part_before_and[a] = ' '.join(temp_replace_specials[a].split()[0:loc_of_and])
            part_after_and[a] = ' '.join(temp_replace_specials[a].split()[loc_of_and:])

# %%
part_before_and
# Out:
# {66: '116',
#  91: '165 Pearl',
#  93: '400 Broadway',
#  336: '190 South',
#  362: '98 First',
#  370: '185 Rivington',
#  447: '260',
#  623: '6 Bowery',
#  624: '311 Broadway',
#  658: '105 Henry',
#  664: '95 Canal',
#  682: '15 Forsyth',
#  737: 'W 30th n Av 7 bh W 30th n Av 7',
#  743: '141 Pearl',
#  849: '72',
#  901: '422 Grand',
#  1061: '169 W 21st',
#  1076: '30 Av 8',
#  1156: '567 Broadway',
#  1181: '550 Fourth',
#  1251: '66',
#  1315: '260 DIncy',
#  1429: '33 Greene',
#  1569: '175 W 22d',
#  1612: '22 Av',
#  1763: '175 Av',
#  1800: 'KE 32d',
#  1805: '277 W',
#  1816: '48 Broad',
#  1914: '27 Water',
#  1932: '4',
#  1951: '43',
#  1995: '76 Wall',
#  2041: '18 Jam',
#  2121: '27 Greene',
#  2133: '17 Jay',
#  2208: '43 Fulton',
#  2240: '8',
#  2289: '44',
#  2346: '204 Broome',
#  2400: '122 Columbia',
#  2467: 'Av 4',
#  2500: '344',
#  2600: '30 Wall',
#  2622: '246 Broome',
#  2802: '343 Broadway Charles',
#  2805: '71',
#  2906: '51',
#  2907: '44 Maidenla',
#  2952: '118 W 24th',
#  3036: '137 Broadway',
#  3158: '106 West',
#  3233: '72 Twelfth',
#  3351: '133 W 18th',
#  3357: '313 West 146 Charles',
#  3365: '58 Elm 26 Elizabeth Chambers',
#  3389: '280',
#  3392: '47 Division',
#  3431: '130 Broad',
#  3489: '52',
#  3584: '156 B way',
#  3591: '205 W 17th',
#  3633: '34 B 63 St Mark s pl',
#  3853: '417',
#  3886: '120 William',
#  3957: '81 Pearl',
#  3959: '248 Houston',
#  3968: '272',
#  4001: '562',
#  4029: '13 Barclay',
#  4038: '4 Rivington',
#  4114: '110',
#  4123: '119',
#  4167: '128 E 26th',
#  4251: '109',
#  4327: '240',
#  4354: '46 Delancy',
#  4415: '209 Fourth',
#  4427: 'Av 3c E 36th',
#  4433: '49',
#  4477: '434 Pearl',
#  4586: '330 Monroe',
#  4594: '32 Whitehall',
#  4605: '126',
#  4618: '10 N',
#  4637: '1364 G wich',
#  4639: '136',
#  4697: 'E 25th c',
#  4705: '205 Av 8',
#  4742: '31',
#  4784: 'Av 7c W 3lst',
#  4882: '52 Howard',
#  4925: '443 Broadway',
#  4927: '59',
#  5037: 'E 29th',
#  5058: '34',
#  5185: '106 West',
#  5297: '151 Grand',
#  5299: '15 8 William',
#  5312: '422',
#  5340: '13 John',
#  5394: '14 Goerck',
#  5411: '334 Tenth',
#  5420: '56 Frankfort',
#  5424: '309 Av 8',
#  5435: 'Av 9b W 29th',
#  5442: 'Av 9 n',
#  5447: '3 in front of title',
#  5480: '83',
#  5512: '492 Hu',
#  5531: '90',
#  5549: '9',
#  5591: '13 Bond',
#  5611: '89 Gold',
#  5643: '277 W',
#  5674: '55 Mott',
#  5686: 'Av 11 bet 27th',
#  5694: '75 Cherry',
#  5714: '468',
#  5735: '85 Attorney',
#  5736: '42 Amos',
#  5792: '519',
#  5883: '239 E tith se vt',
#  6046: '185 Ma',
#  6064: '90 Beaver',
#  6151: '73',
#  6152: '69 Wall',
#  6161: '216 lifth',
#  6175: '476 Hudson',
#  6182: '121 Third',
#  6259: '4 Beach',
#  6410: 'E 28th c Ay 4',
#  6714: '312 Stanton',
#  6751: '8',
#  6762: '8',
#  6772: '86 Dey',
#  6778: '92',
#  6781: '315 Broadway',
#  6825: '1',
#  6831: '9 Old slip',
#  6847: '68 Washington',
#  6862: '359',
#  6929: '69 Forsyth',
#  6968: '114 John and 67',
#  6984: '112 Sullivan',
#  7013: '11 Wall',
#  7171: '32',
#  7346: '105',
#  7363: '134 Av',
#  7382: '70',
#  7384: '149',
#  7401: '5 Od Charles',
#  7414: '1',
#  7415: '1',
#  7416: '1',
#  7423: '41 Wall',
#  7438: '23 S William',
#  7439: '96 Catharine',
#  7442: '304 Broadway',
#  7443: '255 Monroe',
#  7444: '586 Broome',
#  7533: '74 Union pl',
#  7675: '29',
#  7970: '194 Av 6',
#  8160: '63 W 21st',
#  8269: '14',
#  8289: '86 Dey',
#  8290: '12 Allen',
#  8291: 'W 22d',
#  8312: '39',
#  8340: '224 Av',
#  8366: '51',
#  8515: '107',
#  8516: '6',
#  8622: '81',
#  8652: '70',
#  8679: '144 Hester',
#  8735: '102 Bowery Ct',
#  8757: '244 Mott',
#  8837: '73 Wil',
#  9033: '75 Broad',
#  9055: '236',
#  9090: '28 Exchange pl',
#  9151: '30 Rector',
#  9163: '171 W 19th',
#  9175: '91 South Br klyn',
#  9197: '414 Tenth FARRINGTON',
#  9198: '76 W B way',
#  9217: '24E 26th',
#  9292: '18 Murray',
#  9330: '436 Pearl',
#  9396: '6',
#  9416: '11 Lewis',
#  9490: '107 Mott',
#  9552: '267 Spring',
#  9576: '150',
#  9724: '375',
#  9734: '11 Cliff',
#  9752: '20 Nassau New York Hotel',
#  9813: '17',
#  9886: '195 W 24th',
#  9916: '8 Fifth',
#  9923: 'Av 3',
#  9936: '119 Grand',
#  9958: '32 Cherry',
#  10006: '404',
#  10010: '18 Park pl',
#  10160: '43 New',
#  10233: '10',
#  10492: '84',
#  10493: '238',
#  10518: '34',
#  10522: '232 Fifth',
#  10525: '20 Roosevelt',
#  10538: '429 Broadway',
#  10547: '34 Hammond',
#  10555: 'W 27th n Av 7',
#  10557: '120 Sheriff',
#  10573: '29 Troy',
#  10620: '37',
#  10729: '142 Centre',
#  10750: '6 Av 8',
#  10768: '56 Liberty',
#  10828: '30 Lewis',
#  10851: '63 Cortlandt',
#  10857: '48 Delancy',
#  10900: '15 S William',
#  11105: '250',
#  11281: '77 Maiden',
#  11312: '161 Clinton',
#  11366: '264',
#  11392: '207 Thompson',
#  11398: '176 W 17th rg te ee RRL ey TT A EL',
#  11402: '86 Pearl',
#  11405: '187 W 13th',
#  11408: 'Av 9c W 33d',
#  11432: '126 Macdougal',
#  11434: '11 Eldridge',
#  11446: '1',
#  11448: '172',
#  11502: '18 Centre',
#  11574: '157 Suffolk',
#  11636: '819 Bway',
#  11688: '39 W Broadway ce enenae yp',
#  11702: '52 Av A',
#  11703: '43 Anthony',
#  11732: '64 Broad',
#  11823: '87 Allen mann',
#  11840: '73 Spring',
#  11850: '155 Perry',
#  11879: '10',
#  11954: '373 Tenth',
#  11981: '151',
#  12005: '53 Ludlow',
#  12026: '9 Vandam',
#  12037: '248 Fifth',
#  12039: '247 W 16th',
#  12146: '129',
#  12212: '232 Mulberry',
#  12253: '634 Broadway',
#  12291: '4 Mechanics',
#  12297: '452Grand',
#  12363: '118 Av 1',
#  12441: '34',
#  12525: '158',
#  12530: '125',
#  12552: '67 Union pl',
#  12597: '9 Cedar',
#  12642: '142 Walker',
#  12647: '96 Essex',
#  12710: '105',
#  12741: '172',
#  12770: '131 W 19th',
#  12954: '141 Spring',
#  12971: '225 W 28th',
#  13074: 'W 3lstn Ay 8',
#  13147: '10 Vandewater',
#  13207: '127',
#  13267: '281',
#  13358: 'Av 1',
#  13376: '491 Washington',
#  13379: '69 Mott',
#  13427: '72 Stanton',
#  13444: '293 Delancy',
#  13491: '79 Mott',
#  13596: '91 Market',
#  13608: '14',
#  13643: '10',
#  13677: '90 Divison',
#  13679: '90 Division',
#  13726: '192 Second',
#  13728: '157',
#  13751: '86',
#  13781: '45 W 13th',
#  13790: '295 Av',
#  13799: '257 Delancy',
#  13847: 'Av 3',
#  13923: '7 Vandam',
#  13985: '137',
#  14008: '128',
#  14018: '494 Pearl',
#  14049: '187 Av',
#  14083: 'Av 4b 131st',
#  14231: '9',
#  14340: '310',
#  14384: '52 Ferry',
#  14564: '109',
#  14579: 'Av 1',
#  14642: '294 Seventh',
#  14644: '35',
#  14662: '166 Pearl and 79',
#  14668: '94',
#  14679: '169 E 1 th',
#  14723: 'W 30th n Av 6 W 30th n v 6',
#  14906: '175 Reade',
#  14924: '30 Houston',
#  14930: '65 Merchants',
#  15079: '30 Maiden la Throg',
#  15080: '30 Maiden la 6 St',
#  15145: '87 BLA',
#  15151: '77 William',
#  15155: '66 Gouverneur',
#  15179: '339 Av 3n Twenty sixth',
#  15213: '109 Thompso',
#  15214: '176 W 19th',
#  15251: '122 Twelth',
#  15254: '122 Grand',
#  15439: '218',
#  15482: '84 Mulberry',
#  15511: '18',
#  15512: '18',
#  15517: '9 Washington mkt',
#  15522: '9',
#  15593: '69 John 107 Willow Brooklyn',
#  15608: '95 Perry',
#  15677: '130 Elizabeth',
#  15689: 'W 26th n',
#  15724: '230',
#  15771: '80 Nassau',
#  15788: '110 Attorney',
#  15792: 'W 29th',
#  15806: '305 Delancy',
#  15837: '125',
#  15851: '88 Cannon Hall David 29 Cannon',
#  15866: '40 Madison',
#  15871: '20 Merchants',
#  15960: '55 Exch 250 W 20th',
#  15968: '239 Broadway',
#  15983: '86',
#  15988: '844 Bowery',
#  15993: '22 Morris',
#  16013: '73 Eifth',
#  16065: '2',
#  16108: '104 Laureng',
#  16191: 'Av 1',
#  16244: '519',
#  16277: '8 Battery pl',
#  16309: '65',
#  16315: '42 Pitt',
#  16326: '388',
#  16464: '10 Anthony',
#  16476: '243',
#  16556: '125 Monroe',
#  16571: '63 Ludlow',
#  16580: '118',
#  16589: '242 W 28th',
#  16610: '360 Tenth',
#  16778: '37th n Av 10',
#  16782: '208 Elm',
#  16813: '8 Rose',
#  16865: '56 Dey',
#  16868: '195 Walker',
#  16875: '75',
#  16876: '125 Grand',
#  16881: '6 Wall',
#  16930: '119',
#  16943: '61',
#  16996: '300',
#  17003: '1',
#  17027: '40',
#  17032: '92 Chrystie',
#  17088: '4 Vestry',
#  17174: '44 Hamilton',
#  17195: '9 Pelham',
#  17238: '182 Av 1 Av 3c Ninth',
#  17277: '69 University place',
#  17287: '3014 Fourth',
#  17305: '554 Fourth',
#  17313: '80',
#  17392: '146 Varick',
#  17433: '29 Av A',
#  17475: '133',
#  17476: '59 Eldridge',
#  17487: '118 Pearl',
#  17488: '56 Liberty',
#  17519: '48 Merchants',
#  17548: '164 Broadway',
#  17571: 'E 13th',
#  17577: 'E 24th n Av 2',
#  17589: '481 Broome',
#  17598: '341 Magison',
#  17604: '148 Third',
#  17615: '36 Rose',
#  17631: '85 Vandam',
#  17632: '3 Vandam',
#  17635: '85 Vandam',
#  17642: '96 Front',
#  17650: '89 Merchants',
#  17669: '45 Aun',
#  17670: '45 Ann',
#  17671: '45 Ann',
#  17697: '94 W',
#  17719: '136 Greenwich',
#  17720: '176',
#  17761: '419',
#  17839: '3 Gauverneur s',
#  17895: '83 Lewis',
#  17903: '165 Stanton',
#  17931: '599',
#  17998: '456',
#  18010: '227',
#  18127: '111 W Broadway 483 Pear',
#  18131: '201 Cherry 483 Pearl 78 W Broadway',
#  18140: '234',
#  18157: '32',
#  18205: '40 Gold',
#  18218: '109',
#  18253: '44 Chatham',
#  18278: '82 W Broadway',
#  18292: '131',
#  18359: '224 KE Broadway',
#  18367: '110',
#  18425: '7',
#  18544: 'W 30th',
#  18566: '49 John',
#  18578: 'W 22d',
#  18613: '2l Leonard',
#  18618: '149 Spring 8 Laurens',
#  18621: '1',
#  18632: '83 W B way',
#  18633: '83 W B way',
#  18735: '209 Av B',
#  18760: '47 Centre',
#  18785: '76 Beaver',
#  18805: '118',
#  18859: '137',
#  18861: '742 744',
#  18869: '155',
#  18915: '28 Coenties slip',
#  18930: '28 Coenties sl',
#  18932: '28 Coenties sl',
#  18996: '8',
#  19081: '387 W',
#  19091: '379 Grand',
#  19142: '8 Sixth',
#  19305: '77 Broad',
#  19336: '193',
#  19430: '45 Pearl',
#  19515: '307 Third',
#  19575: '84',
#  19643: '17',
#  19669: '229',
#  19769: '92 Ludlow',
#  19819: '103 Perry',
#  19844: '150 Amos',
#  19868: '25',
#  19994: '603 Fourth',
#  20032: '262 Division 72',
#  20069: '124',
#  20135: '220',
#  20157: '89 West',
#  20171: '77 W 29th',
#  20285: '7 8 William',
#  20299: '439',
#  20324: '66 Clinton',
#  20368: '166',
#  20396: 'Av 8c W 26th',
#  20429: '89',
#  20449: '40 Rose',
#  20474: '8',
#  20491: '333',
#  20499: '333 Pearl',
#  20504: '1 William',
#  20511: '376',
#  20574: '9',
#  20673: '24 Reade',
#  20728: '81',
#  20745: '280',
#  20751: '194',
#  20813: '2 Pine Butts',
#  20818: 'E 29th n Av',
#  20824: '214',
#  20843: '2 Clif',
#  20853: '275 Bleecker',
#  20966: 'W 17th c Av 8 211',
#  20992: '206 Front',
#  21050: '6',
#  21115: '280 Av',
#  21136: 'W 26 n Av 9',
#  21155: '59 Water 229 Lewis',
#  21162: '18 E 28th Hudson',
#  21164: '146 W 25th Hudson',
#  21166: '45 Liberty 163',
#  21180: '37 Peck slip 189',
#  21186: '104 Nassau',
#  21191: '12 Lewis Huestis',
#  21193: '89 Pearl',
#  21200: '89',
#  21201: '136',
#  21229: '220 Delancy Hughes Edward 76 Essex',
#  21253: '13 Av B',
#  21409: '263 W 16th',
#  21513: '112 Cliff',
#  21619: '169',
#  21628: '194 Clinton',
#  21640: '9 Jauncey court 7 Varick',
#  21653: '142 Fulton',
#  21659: 'Av 2c E 23d',
#  21682: '257',
#  21702: 'Av 2',
#  21718: '160',
#  21765: '253',
#  21792: '253',
#  21810: '240 Delancy',
#  21851: '143',
#  21855: '103 Division',
#  21864: '311 Sixth',
#  21865: '60 Robinson',
#  21868: '164 Suffolk',
#  21924: '26th c Ay 8',
#  21938: '47',
#  21973: '164 Pear',
#  22141: 'W 22d Av 7',
#  22170: '218 Pearl',
#  22191: '340 Ninth',
#  22218: '248',
#  22229: '144 Broadway',
#  22240: 'W 29th Av 7',
#  22297: '434 Greenwich',
#  22369: '143 Christopher',
#  22398: '54 Nassau',
#  22422: '162 Houston',
#  22468: '346 Av 3',
#  22560: '136 Mercer',
#  22569: 'E 13th Av 5',
#  22582: '209 Av B',
#  22623: '159 Front Brooklyn',
#  22881: '170 Crosby',
#  22889: '85 Bedford',
#  22900: '3 Washington market',
#  22904: '7 Fulton market',
#  22940: '425 Av 6',
#  22964: '95 Front',
#  22965: '27 Cortlandt',
#  22969: '309 Spring',
#  22971: '309 Spring',
#  23054: '196 Forsyth',
#  23088: '76 Leonard',
#  23116: '146 Troy',
#  23122: '19 John',
#  23216: '115',
#  23253: '91 Lewis',
#  23280: '59 Pitt',
#  23305: '247 West Johnson Bradish 268 W 16th',
#  23329: '76 Cherry',
#  23334: '420 Water and 320 De',
#  23340: '40 Watts Johnson Edward A 19 Norfolk',
#  23342: '131 Greenwich Johnson Edwin A 268 W 16th',
#  23378: '160 Christopher',
#  23386: '8',
#  23390: '79',
#  23419: '35 Depeyster',
#  23433: '35 Depeyster',
#  23437: '35 Depeyster',
#  23455: '390 Hudson',
#  23464: '246 Washington',
#  23510: '120 Av 7',
#  23524: '28 Thompson',
#  23590: '268 W 16th',
#  23601: '102 Maiden la',
#  23633: 'E 24th n',
#  23705: '330 Grand 8 Attorney',
#  23722: '157 Laurens',
#  23772: '156 Av 6',
#  23790: '143 F orsyth',
#  23991: '53 Beaver',
#  24000: '3 Water',
#  24022: '106 Broadway',
#  24110: '189 Front',
#  24113: '40 E 28th',
#  24130: '91 Cannon',
#  24200: 'Av 10 c',
#  24267: '235',
#  24277: '1',
#  24307: '145 Cherry',
#  24370: '293 W 16th',
#  24429: '70 Wall',
#  24465: '198 Av 6 W 13th',
#  24487: '144 Carmine',
#  24497: '162 Essex',
#  24513: 'W 25th bet Avs 7',
#  24514: '172',
#  24555: '44 Orchard Keator German 51 Stanton',
#  24563: 'W 17th',
#  24581: '28 Centre',
#  24583: '139 F 24th',
#  24594: 'Av 8c W 29th 330',
#  24641: '304 Fourth',
#  24716: '2 Jones',
#  24732: '4',
#  24734: '4',
#  24859: '241 Mulberry',
#  24887: '142',
#  24888: '24th',
#  24914: '32 Trinity place',
#  24932: '23 Maiden lane',
#  24988: '21 Laurens 21 L',
#  24989: '626 Washington',
#  25053: '48 Water',
#  25060: '153',
#  25112: '171 Reade',
#  25133: '51 Washington',
#  25134: 'W 28th n Ay 9',
#  25159: '124 Av 7',
#  25176: 'E 24th n Av 2 and West c Barclay',
#  25206: '350 Av 6',
#  25223: '21 Duane',
#  25242: '52 Downing Kerigan Dani',
#  25249: '73 Av D Kerler Mathias',
#  25250: '739 Washington Kerley Bernard',
#  25272: '91 Horatio Kerne',
#  25329: '1754 Chatham',
#  25350: 'W 87th n Av 9',
#  25455: '70 Av 6',
#  25457: '263 Av 3',
#  25461: '3 Rivington place',
#  25463: '237 W 16th',
#  25468: '192 Fourth Kiggins',
#  25473: '552 Fourth',
#  25474: 'W 3lst mn Ay 9',
#  25478: '16',
#  25480: '5 Commerce',
#  25483: '80 W 17th',
#  25499: '161 Av 8',
#  25500: '10 Watts',
#  25501: '297 Division',
#  25508: 'W 20th mn Av 11',
#  25511: '54 Eldridge',
#  25513: '311 Bowery',
#  25514: '93 Church',
#  25516: '250 WW 16th',
#  25518: '42 W 13th',
#  25521: '342 Sixth',
#  25525: '95 Roosevelt',
#  25554: 'Av 9 c W',
#  25596: 'S41',
#  25611: '11',
#  25687: '78 Third',
#  25703: '169 W 15th',
#  25739: '29',
#  25765: '271 Pearl',
#  25830: '51',
#  26006: 'W 26th c Av 9',
#  26013: '26th c Av 9',
#  26029: '42 Cedar',
#  26109: '19 Merchants',
#  26119: 'W 30th n Av 7',
#  26175: '14 Av A',
#  26176: '101 Broome',
#  26253: '271',
#  26284: '215 W 17th',
#  26312: 'E 24th',
#  26329: '176 Forsyth',
#  26335: '190 West',
#  26342: '139 Front',
#  26393: '28 Pitt',
#  26450: '177',
#  26494: '146 Third',
#  26523: '396 Water',
#  26557: '33',
#  26574: '13 Av 1',
#  26595: '49 W Broadway',
#  26613: '73 Jackson',
#  26724: '65 Houston',
#  26729: 'Av 7 c',
#  26809: '163 Broome',
#  26810: '89 Clinton',
#  26898: '96 Wall',
#  26905: '30 Old slip',
#  26906: '30 Old slip',
#  26947: '190 Washington',
#  27082: '228 V',
#  27133: '99 Pearl',
#  27136: '197 W 27th',
#  27159: '552 Grand',
#  27171: '111 King',
#  27180: '13',
#  27200: '19',
#  27210: '22 Norfolk',
#  27281: '92',
#  27283: '138 Nassau',
#  27316: '29',
#  27361: '395',
#  27372: '93 Canal',
#  27403: '245 Spring',
#  27435: '7 Orange',
#  27530: '85 BE 15th',
#  27574: '874 Forsyth',
#  27669: '12 Dey',
#  27674: '59 John',
#  27746: '74 Broadway',
#  27791: '22 Fulton',
#  27840: '14Jones',
#  27847: '163 Rivington',
#  27856: '142 Front',
#  27885: '125 Duane',
#  27892: '20 Grand',
#  27908: '26 Grand',
#  28016: '207 W 13th',
#  28032: '444',
#  28100: 'Av 8 c W 25th hb Av 8',
#  28107: '3 4',
#  28143: '178 Franklin',
#  28173: '132 Chrystie',
#  28217: '131 Anthony',
#  28219: '244 EF 20th',
#  28221: '274',
#  28223: 'W 27th n Av 7',
#  28225: '283 Jay Brooklyn',
#  28229: '216 Elizabeth',
#  28282: '63 Ridge',
#  28388: '2',
#  28473: '515 Broadway',
#  28495: '26 Madison',
#  28509: '133 Spring',
#  28515: '83 Duane 261 Broome',
#  28583: '3 Whitehall',
#  28620: '185 E 11th',
#  28630: '23',
#  28667: '19',
#  28728: '64',
#  28782: 'Av 7',
#  28786: '20',
#  28824: '42 Warren a',
#  28916: '115',
#  28939: '301 Henry',
#  28965: '325 Broome',
#  28979: '217',
#  28985: '10 W',
#  29082: '12 Gold',
#  29132: '251 Water 202',
#  29136: '4 Washington market',
#  29163: '55 Pearl',
#  29167: '68',
#  29177: '170',
#  29186: '56 Liberty',
#  29209: '27 Desbrosses',
#  29211: '179',
#  29321: '216 Front',
#  29340: '126 Walker',
#  29367: '376 West',
#  29391: '56',
#  29409: '208 Church',
#  29494: '6',
#  29570: '143 Washington',
#  29584: '152 Wooster',
#  29611: '9 Goerck',
#  29615: '1 Hanover 12',
#  29690: '736 Greenwich',
#  29829: '171 West',
#  29882: '164 Water hb E 19th bet Broadway',
#  29890: '99 Maiden la',
#  29900: '99 Maiden lane',
#  29903: '44',
#  29910: '42 Chatham',
#  29927: '45',
#  29954: '140 Prince',
#  29978: '273 Bleecker',
#  30019: '239',
#  30087: '192',
#  30097: '40 Vandam',
#  30147: '507 Washington',
#  30184: 'Av 2',
#  30190: '2 Minetta',
#  30217: '37 Beekman',
#  30232: '42 Av D',
#  30262: 'W 32d n',
#  30339: '285 Av 1',
#  30511: '47',
#  30541: '105 Broome Lynch Sophia 13 Gay',
#  30546: '40 Trinity pl 132 Beekman',
#  30563: '134 W 13th Lynch',
#  30589: '78 Mercer',
#  30595: '361 Grand',
#  30598: '167 Mulberry',
#  30612: '144 Elm Lyon Ephraim 472 Grand',
#  30699: '26 Christopher',
#  30702: 'Av 3',
#  30748: '93',
#  30765: '202 Elm',
#  30867: '37 Chrystie',
#  30884: '146 Av',
#  30918: '53 Cross 1',
#  31061: '10',
#  31103: '211 Elm',
#  31132: '101 Washgtn',
#  31182: '370 Broadway',
#  31207: '167 W 13th',
#  31246: '175 Chatham',
#  31265: '219 Av 1 Twenty second n Av 3',
#  31274: '274 Madison',
#  31289: '69 Factory',
#  31373: '331',
#  31422: '185 Orchard',
#  31423: '34',
#  31525: '246 Mott',
#  31557: '198 Mercer',
#  31701: 'Av 7',
#  31779: '16',
#  31793: '59 King',
#  31810: '128 Av 8',
#  31811: '50 Monroe',
#  31827: '11 Cedar 10',
#  31837: '2 Tryon row',
#  31927: '4',
#  32028: '17',
#  32055: '343 Suffolk',
#  32186: '24 Elizabeth',
#  32236: '18 Vandewater',
#  32244: '353',
#  32266: '327 Bowery',
#  32296: '9',
#  32302: '163 Bowery',
#  32315: '1 Beaver',
#  32316: '162 W 20th',
#  32377: '86 W 16th',
#  32432: '199 Duane',
#  32454: 'W 3lst n Av 9',
#  32460: 'W 32d n Av 9 M',
#  32467: 'W 29th n Ay 10 M',
#  32472: '104 Orange',
#  32486: '10 Hammond M',
#  32496: '265 Madison M',
#  32507: 'W 32d n Av 10 Broome A',
#  32508: '358 Sixth M Keever John A',
#  32576: '76 Canal',
#  32661: 'gh MRED OEY NANA BRAM AD 2h Vo AV She FF',
#  32685: '450 Broadway',
#  32730: 'Av 11th',
#  32791: '253 Mulberry',
#  32796: '25 Goerck',
#  32798: '4S William',
#  32819: '116 Bleecker',
#  32822: '33 Leonard',
#  32823: '170 B way',
#  32827: '170 Broadway',
#  32829: '170 B way',
#  32874: 'E 19th 4',
#  32891: '78 Fifth',
#  32892: 'Av 10 c W 20th',
#  32897: '83 Forsyth',
#  32899: '248 FE 13th',
#  32960: 'W 25th n Av 10 M',
#  32968: '153 Chatham',
#  33000: '69 Eighteenth Av 6',
#  33003: '181',
#  33016: '187 Lewis',
#  33017: '31 Charles Roosevelt',
#  33018: '8 Cortlandy',
#  33019: 'W 41st 19',
#  33020: '68 Gansevoor',
#  33037: '203 Chambers M',
#  33056: '106 Av',
#  33064: '210 Chatham sq',
#  33088: '28 Wooster',
#  33090: '28 Wooster',
#  33142: '235 Av',
#  33242: '430',
#  33312: '6',
#  33385: '240 Washgtn',
#  33473: '96 Av 9 Macpherson Margaret Av 11',
#  33592: '14U V',
#  33596: '50 Perry Spring',
#  33601: '262 Fifth 262 Fifth',
#  33610: '210 Chatham sq',
#  33614: '7 Dey Maguire Richard Tompkins',
#  33628: '354 Grand 90 Chat',
#  33660: 'Av 2 a Maher Thomas 632 Washgtn he i',
#  33664: '312 Broadway',
#  33666: '212 Broadway and 88 Broad Mahler Gustavus 365',
#  33667: '312 Broadway',
#  33728: '60 Beaver',
#  33733: 'E 29th n Lex ton Av',
#  33740: '194 Washington MALLABY',
#  33741: '259 Division Mallan Henry 9 W 27th dneee etn F mo',
#  33913: '126 E Broadway 83 Monroe',
#  33943: '634 Clarkson',
#  33999: '356 Madison',
#  34049: '98',
#  34063: '383',
#  34140: '19 Coenties slip',
#  34153: '309 Av',
#  34165: '83',
#  34179: '277 W',
#  34182: '91 Greenwich',
#  34204: '76 Catharine',
#  34209: '73',
#  34210: '69 Wall',
#  34216: '216 lifth',
#  34220: '45',
#  34230: '175 B way',
#  34250: '23d',
#  34264: '270 E Broadway',
#  34273: '220 Washington',
#  34276: '2 Cortlandt',
#  34285: '9 Old slip',
#  34292: '68 Washington',
#  34299: '23d n Av 6 Duffy Mary 359',
#  34333: '73 W 15th Dugan Cornelius 69 Forsyth',
#  34334: 'W 30th n Av 7',
#  34353: '200',
#  34383: '51',
#  34386: 'W 28th n Av 9',
#  34398: '70',
#  34404: '5',
#  34408: 'Av 2n T wenty eighth',
#  34422: '73 Wil',
#  34431: '140 Centre',
#  34441: '144 Varick Fairclough',
#  34451: '124 Orchard',
#  34466: '64 Cedar',
#  34498: '30 Rector',
#  34503: '171 W 19th',
#  34526: '24E 26th',
#  34533: '24th',
#  34581: '167',
#  34588: '92 Beckman',
#  34602: '93',
#  34611: '93',
#  34622: '93',
#  34642: '65',
#  34655: '209 Varick',
#  34659: '3914 Broadway',
#  34717: 'E 25th bet Avs 1',
#  34794: '251 Av',
#  34807: '3 Fulton market',
#  34813: '3 Fulton market',
#  34828: '143 E Broadway',
#  34863: '26 City Hall pl',
#  34868: '152 Franklin',
#  34871: '308',
#  34891: 'co 8 Merch Ex',
#  34900: '195 Canal',
#  34922: 'FE 22d',
#  34924: '64',
#  35058: '34 J',
#  35124: '151 Tenth',
#  35155: '139 Bowery',
#  35159: '28 Attorney 1',
#  35199: '107 Thompson',
#  35216: '130 Leonard',
#  35221: '156 Fulton 276 Housto',
#  35251: '4',
#  35306: 'W 27th n Av 8',
#  35320: '75 Av C bh 75 Av',
#  35343: '17',
#  35356: '26',
#  35370: '33 Pearl GOTFRYD straw hat manufacturer',
#  35372: '438',
#  35429: '294',
#  35432: '46',
#  35437: '260 Stanton',
#  35446: '74 Wall',
#  35449: '96 Norfolk',
#  35453: '208 Spring',
#  35459: '51 Leonard',
#  35462: '214 W 26th',
#  35470: '108 Church',
#  35472: '13 E 11th',
#  35479: '75 Crosby',
#  35482: '36',
#  35492: '11 Carmine',
#  35506: '29 Goerck',
#  35511: '132 Barrow',
#  35512: '13 E 11th',
#  35532: '1 Ann',
#  35536: '140 Lewis',
#  35539: '260',
#  35574: '105 William',
#  35598: 'W 25th n Ay li 110 Spring',
#  35609: '43',
#  35637: '259 Bowery 695 B',
#  35649: '119 Broad',
#  35669: '86',
#  35714: '44 Av B',
#  35721: '122 Washington',
#  35745: '20 Cliff',
#  35752: '53 Nassau',
#  35812: '41 Hester',
#  35873: '157 Duane',
#  ...}

# %%
df = df.rename({'Full Address': 'Full Address old'}, axis=1)

# %%
#part_after_h[4]

# %%
new_full_address = {}
for a in range(0, len(df)):
    try:
        new_full_address[a] = part_after_h[a]
    except:
        try:
            new_full_address[a] = part_before_and[a]
        except:
            new_full_address[a] = temp_replace_specials[a]

# %%
for a in range(0, len(df)):
    split_list_from_address = new_full_address[a].split()
    try:
        if split_list_from_address[-1] == '&':
            split_list_from_address = split_list_from_address[:-1:]
    except:
        pass
    try:
        if split_list_from_address[-1] == 'n':
            split_list_from_address = split_list_from_address[:-1:]
    except:
        pass
    try:
        if split_list_from_address[0] == '&':
            split_list_from_address = split_list_from_address[1::]
    except:
        pass
    new_full_address[a] = ' '.join(split_list_from_address)

# %%
def firstUpperCaseLetter(str) : 
    for i in range(0, len(str)) : 
        if (str[i].istitle()) : 
            return i
    return 0

# %%
for a in range(0, len(df)):
    test_string1 = new_full_address[a]
    if hasNumbers(test_string1)==False:
        loc_of_first_uppercase_letter = firstUpperCaseLetter(test_string1)
        new_full_address[a] = test_string1[loc_of_first_uppercase_letter:]

# %%
new_full_address[996]
# Out:
# '267 Av 3'

# %%
for a in range(0, len(df)):
    try:
        if new_full_address[a].index(' and ')>=0:
            print(a, new_full_address[a])
    except:
        pass
# Out:
# 465 130 Troy and 170 Hammond
# 735 240 William and 10 Duane 240 William
# 848 156 Bowery and 256 Grand
# 989 Co 189 and 191 Water
# 1151 443 B way and 20
# 1160 59 and 61 Maiden lane
# 1224 Broadway h 27th and 28th
# 1258 Av 7 and 8
# 1334 106 Broady and 4 Thames
# 2104 70 Broadway and 15 New
# 3025 318 Front and 100 Wall
# 3692 21 S William and 47 Stone
# 6302 W 27th and 28th
# 6589 1 Hamy and 79 Greenwich Av
# 6968 114 John and 67
# 7068 4 Liberty pl and r 55 De
# 7109 W 34th c Av 11 and 100 North Moore
# 7597 68 and 70 Washington
# 7599 95 and 97 Front
# 7669 99 Clinton and 90 Attorney
# 7933 University pi and Eighth 5
# 7998 166 South and 267 Front
# 8362 40 Fulton and Pearl
# 8839 186 W 23d FAIRBANKS & CO platform and counter
# 10328 W 29th h Av 8 and 9
# 11144 76 Vesey and 409 Grand
# 11145 129 and 131 Nassau
# 11146 129 and 131 Nassau
# 11218 187 Cherry and Twelfth Av C
# 11335 5 and Broadwa
# 11355 128 Pearl and 89
# 11443 368 Bowery and B way
# 12079 Av 1 and 2
# 13918 Avs 7 and 8
# 14662 166 Pearl and 79
# 14689 199 Chambers and 191
# 14691 199 Chambers and 191
# 15279 431 Water and 95 Mar
# 15309 Av 8 and 9
# 15617 93 Perry and 554 Hudson
# 16041 99 Pearl and 62
# 16171 130 William and pres
# 16710 7 and 9 Platt
# 17043 2 Catharine slip and 186
# 17087 191 and 193 Chrystie
# 17207 32 Roosevelt and 74
# 17495 carpeting and house
# 17784 10 Ridge and 20 Greenwich 20 Greenwich
# 17957 63 Delancy and 23 Cham
# 19143 241 and 257 Bowery
# 19463 72 Maiden lane and 7 Liberty
# 19974 29 Gold and 8 Liberty place and 31
# 20682 126 Nassau The first and only
# 21170 123 and 10
# 21721 80 and 82 William
# 21826 20 and 21 Washington market 305 Greenwich
# 22217 396 and 493 pendix
# 22292 27 New and Washington
# 22503 199 and 201 Centre
# 22733 226 Houston and 6 Av C
# 23002 135 Broadway and 192
# 23334 420 Water and 320 De
# 23373 165 William and 248
# 23941 26th and 97th
# 23976 27th and 28th
# 23984 Ay 4 h 27th and 28th
# 23989 137 Broad way 391 Grand and 242 W 16th
# 23990 44 West and 257 South
# 23999 263 and 609 Broadway
# 24008 26th and 97th
# 24029 20 Orange and 126 Nassau 20 Orange
# 24160 21 S William and 47 Stone
# 25061 47 Christopher and 366 Bow
# 25089 251 Washington and li
# 25176 E 24th n Av 2 and West c Barclay
# 25507 3 Jay & 7 Wall and 1 New
# 25615 97 Canal and importer 173
# 25871 6 City Hall pl and 18
# 26237 127 Mulberry and 1
# 27906 142 Front and presi
# 28814 6 Jersey LEVY JOHN J importer stationery and manufac
# 28841 141 Maiden lane Coenties slip and 24
# 28897 78 Charlton slip and 24
# 29179 136 West and 218
# 29275 170 W 1 & th and 174 Ay 8
# 30204 6 Spring and grocer
# 31925 27 Maiden la and 59 Nassau Williamsburgh
# 32436 47 Av 9 and 154 100 W 2ist au
# 32972 19 Stanton M Nally John 195 Front and 187 Water
# 33285 10 Broadway and 1 Beaver
# 33666 212 Broadway and 88 Broad Mahler Gustavus 365
# 34208 CO commission and ship
# 34361 95 Front and 331 Wi
# 34378 Metal sashes and street
# 34975 332 Bowery and 60
# 36180 393 Grand 147 Gree wich and 43 Av B
# 37171 lace and em
# 37173 193 Reade and 29
# 37479 121 Prince and 156 Fulton
# 38049 104 Canal and 92 Bowery
# 38387 650 and 845 Broadway
# 38411 Av 6 and 7 & D134 W 13th
# 40128 99 and 101 John
# 40675 23 Maiden la and 26
# 40924 W 30th and Broadway
# 42274 5374 Pearl and 113 W Broad
# 42693 20 Murray and 23 Park pl
# 42747 Av 3 h E 35th and 36th
# 43210 12 James sl and oil
# 43833 56 Division and restaurant
# 45026 102 Nassau and museum
# 45081 40 Orchard and 24th c Av
# 45305 Stuyvesant c Ninth and 350 Eighth 18 St Mark s pl
# 46079 173 Av 8 and grocer W 30th n Av 8
# 46379 W 32d bet Av 6 and Broadway
# 47302 406 Broome Reynolds & Brother 85 Liberty and 11
# 47416 130 Chatham Chatham and 18 ich James A h 61 Vest
# 47418 62 Robinson ashington and mil
# 47441 130 Chatham and 18 Bowery
# 47734 41 and 43 Exchange pl
# 48576 135 Pearl and 83 Beaver
# 48580 Madison Av E 27th and E 28th
# 49035 8 Washington and 102
# 49071 101 Wall and under
# 49128 99 Murray and 11
# 49500 171 Houston and grocer
# 49651 6 City Hall place and 18 Centre
# 51055 158 184 and 186 Third Third
# 52813 W 25th and 26th h 824 Greenwich
# 53437 76 Thompson and 9 Chris
# 53450 25 Chatham and 19
# 53452 135 Thompson and 9 Chris
# 53455 76 Thompson and 9 Chris
# 53572 47 Christopher and 366
# 53577 47 Christopher and 366
# 53704 74 Wall and Av 4c E 13th
# 54232 South n Gouverneur and 168 371 Greenwich
# 54462 104 Pearl and 7 Old
# 56083 343 Broadway and 15
# 57337 66 Barclay and 886
# 57352 3 John and 60 Vesey
# 57358 3 John and 60
# 57397 185 Reade and 193
# 57407 185 Reade and 193
# 57466 18 Murray and 49 Broad
# 57510 2034 Division and butcher
# 57770 123 125 and 127 Front
# 59315 tabs and rucheg
# 60878 1 Benson and 51 Mercer
# 60884 200 Cherry and 126 Grand Williamsburg
# 60890 126 Grand and 200 Cherry
# 60952 22 Front and 122 Broad
# 60970 69 West and 104 Washington Newburgh
# 62277 316 Hudson and grate
# 62314 oak and pine
# 62329 42 Mercer and 475
# 62664 41 Av B and t
# 63849 92 Av 9 and 707 Greenwich
# 64146 127 Pearl and 80 Beaver
# 64508 1 Bowery and physician 410
# 64977 16 South and 127 Broad
# 65175 207 W 26th Front and 193 Cherr
# 65374 480 Broadway and 927
# 65397 134 Washington and 300
# 65594 75 77 79 and 81 Vesey
# 65597 73 and 74 South
# 65732 CO importers and W 19th n Av 5
# 66439 163 Church and 71 Duane
# 66501 3124 Grand and 84 Catharine
# 67064 141 Spring and 245 Greenwich
# 67245 718 Broadway and 88
# 68374 44 Front and 14 Coenties slip
# 68659 84 EF Broadway and 96
# 68714 21 Ann and 170 Av
# 69786 33d and 34th
# 69799 82 Water and 118 Pearl
# 69802 77 and 79 68 70 and 72 Robinson change stables
# 69803 sale and ex
# 69807 77 and 79 Robinson
# 69845 351 Broadway and 61 Lewis
# 70002 92 Liberty and ald 5th
# 70785 176 West and 15 Park row bh 87 Warren
# 70898 161 Pearl and paper
# 71237 142 Liberty and 42 Laurens Commercial hotel
# 72016 Clinton and Remsen Brooklyn
# 72102 111 and 113 William
# 72159 21st and 22d
# 72279 66 Market and 9 An
# 72892 5th Avenue and after November
# 72969 Balconies and yerand
# 73202 121 Pearl and 8 Hanover
# 73239 W 26th h Av 6 and 7
# 73265 579 G wich and 27 John
# 74042 1 Maiden lane 176 Broadway and 2 Mott
# 74846 33 Beaver New Orleans and Mobile
# 75826 254 Wall and 87
# 76688 8 Liberty place and 31
# 77116 slip and 24
# 77118 Coenties slip and 24
# 77996 8 Liberty place and 31
# 78424 slip and 24
# 78426 Coenties slip and 24
# 79595 baths and refrigerators
# 80346 68 70 and 72 Robinson change stables
# 80523 85 and 87 Broad

# %%
new_full_address
# Out:
# {0: '39 Pearl',
#  1: '170 Clinton Brooklyn',
#  2: '601 Washington',
#  3: '328 Bowery',
#  4: '42 Orange',
#  5: '77 Barrow',
#  6: '586 E 4th',
#  7: '34 Av C',
#  8: '34 Av C',
#  9: '40 Av C',
#  10: '175 Canal',
#  11: '137 Norfolk',
#  12: '53 Av D',
#  13: '5 Ludlow',
#  14: '1 Av D',
#  15: 'Morrisania',
#  16: '7 Murray',
#  17: '192 Fulton',
#  18: '91 Henry Brooklyn',
#  19: '181 inventor',
#  20: '79 Av B',
#  21: '66 Mangin',
#  22: '304 Ninth',
#  23: 'E 18th n Av A',
#  24: '605 Fourth',
#  25: '24th c Av 3',
#  26: '294 Eleventh',
#  27: '60 Av C',
#  28: 'Brooklyn',
#  29: '22 Vesey',
#  30: '105 Av D',
#  31: '89 E 11th',
#  32: 'Av C n Eleventh',
#  33: '350 Tenth',
#  34: 'W 24th n Ay 10',
#  35: '77 Third',
#  36: '27 Av A',
#  37: '400 Tenth',
#  38: '131 Av C',
#  39: '245 E 13th',
#  40: '18 Av C',
#  41: '306 Av 1',
#  42: '89 Pitt',
#  43: '45 Norfolk',
#  44: '46 Amos',
#  45: 'W 26th n Av 7',
#  46: '107 Av B',
#  47: '5 Av B',
#  48: '299 Av A',
#  49: '48 Av 1',
#  50: '51 Norfolk',
#  51: '268 EF 13th',
#  52: '92 Madison',
#  53: 'W 25th n Av 10',
#  54: '31 W 15th',
#  55: '217 E 13th',
#  56: '319 Ninth',
#  57: '101 Henry Brooklyn',
#  58: 'Ay D c Fourth',
#  59: '464 Cherry',
#  60: '312 Av 1',
#  61: '7 Av D',
#  62: '25 Av A',
#  63: '143 W 28th',
#  64: 'Third n Av A',
#  65: '32 Bond',
#  66: '116',
#  67: '143 Reade',
#  68: '4 Beach',
#  69: '529 Hudson',
#  70: '173 Wooster',
#  71: '95 W 13th',
#  72: '174 Chambers',
#  73: '34 Liberty',
#  74: 'Twelfth c Dry Dock',
#  75: '53 Monroe',
#  76: '72 Lewis',
#  77: '141 Norfolk',
#  78: '166 E 20th',
#  79: '201 Av 3',
#  80: '93 Ridge',
#  81: '433 Tenth',
#  82: '86 Av 2',
#  83: '180 Av C',
#  84: '128 Charlton',
#  85: '180 Grand',
#  86: '7 Broad',
#  87: '14 Clarkson',
#  88: '2 Congress',
#  89: '104 FE 11th',
#  90: 'Cincinnati O',
#  91: '165 Pearl',
#  92: 'Court n Degraw Brooklyn',
#  93: '400 Broadway',
#  94: 'W 2th n Av 8',
#  95: '121 Pearl',
#  96: '746 Washington',
#  97: '88 White',
#  98: '305 Third',
#  99: 'W 28th n Av 7',
#  100: '41 Sheriff',
#  101: '29 Ferry',
#  102: '193 Ninth',
#  103: 'Pearl',
#  104: '160 Church',
#  105: '63 Factory',
#  106: '43 Elm',
#  107: '415 Broome',
#  108: '23 Whitehall',
#  109: '104 Broad',
#  110: '20 Hamersley place',
#  111: '7 Chrystie',
#  112: '650 Fourth',
#  113: '650 Fourth',
#  114: '192 Fulton',
#  115: '609 Broadway',
#  116: '118 William',
#  117: '76 Mott',
#  118: '226 Wooster',
#  119: 'Brookla',
#  120: '465 Fourth',
#  121: '623 Washington',
#  122: '25 Nassau',
#  123: '5 Charlton',
#  124: '2 College pl',
#  125: 'Clinton c Delancy',
#  126: '184 Ludlow',
#  127: '101 Av C',
#  128: '102 Av 2',
#  129: '200 Av 1',
#  130: '30 Bleecker',
#  131: '660 Fourth',
#  132: '110 Av 7',
#  133: '686 Fourth',
#  134: '291 Seventh',
#  135: '105 E lth',
#  136: '156 Av 6',
#  137: '27 Sheriff',
#  138: '67 James',
#  139: 'Williamsburg',
#  140: 'E 16th n Av 1',
#  141: '460 Washington',
#  142: '648 Fourth',
#  143: '6 Goerck',
#  144: '5 City Hall',
#  145: 'New J',
#  146: '727 Washington',
#  147: '154 Sullivan',
#  148: '185 Laurens',
#  149: 'W 29th n Av 11',
#  150: '669 Fourth',
#  151: '658 Fourth',
#  152: '151 Broadway',
#  153: 'Avs 9 & 10',
#  154: '5 Weehawken',
#  155: '16 Christopher',
#  156: '319 Hudson',
#  157: '34 Av C',
#  158: '22 Market',
#  159: '333 Broadway',
#  160: '616 Broadway',
#  161: '100 Sullivan',
#  162: '281 E 13th',
#  163: '398 West',
#  164: '34 Elizabeth',
#  165: '119 Lewis',
#  166: '30 Fifth',
#  167: '457 West 95 Bank',
#  168: '33 Front',
#  169: '129 Charles',
#  170: '159 Chatham',
#  171: '76 Mulberry',
#  172: '391 Broome',
#  173: '45 Broadway 16 State',
#  174: '54 Av C',
#  175: '588 Fourth',
#  176: '2 Bowery',
#  177: 'Ninth c Av C',
#  178: '208 Elm',
#  179: '279 Delancy',
#  180: '35 Clinton place',
#  181: '721 Broadway',
#  182: '25 Av B',
#  183: '49 Av B',
#  184: '529 Greenwich',
#  185: '215 W 18th',
#  186: '62 Sixth',
#  187: '151 W Broadway',
#  188: '367 Sixth',
#  189: '536 Pearl',
#  190: '134 Broome',
#  191: '241 Mott',
#  192: '8 University place',
#  193: '43 New',
#  194: '149 Bowery',
#  195: 'E 22d n Av 3',
#  196: '92 Delancy',
#  197: '346 Sixth',
#  198: '6 Columbia place',
#  199: '153 Goerck',
#  200: '184 Spring',
#  201: '22 Mulberry',
#  202: '27 Columbia',
#  203: '214 E 11th',
#  204: 'Twelfth n Dry dock',
#  205: '75 Varick',
#  206: '203 Mercer',
#  207: 'Harlem',
#  208: '34 Av B',
#  209: '284 E 13th',
#  210: 'Starr',
#  211: '46 Hudson',
#  212: '18 Doyer',
#  213: '19 Pell',
#  214: '5 State',
#  215: '192 Av 1',
#  216: '127 Ridge',
#  217: '115 Delancy',
#  218: '0 Beekman',
#  219: '564 Grand',
#  220: '200 Fulton',
#  221: '113 Clinton Brooklyn',
#  222: '115 Pearl',
#  223: '254 Washington Jersey City',
#  224: '195 Monroe',
#  225: '217 W 18th',
#  226: '161 Madison',
#  227: '65 S Fifth Williamsburg',
#  228: '687 Hudson',
#  229: '675 Fourth',
#  230: '21 Av C',
#  231: 'B klyn',
#  232: '65 Monroe',
#  233: '263 Third',
#  234: '128 Suffolk',
#  235: '12 Washington square',
#  236: '674 Fourth',
#  237: '90 Essex',
#  238: '82 E B way',
#  239: '600 Fourth',
#  240: '58 Cedar',
#  241: '297 Third',
#  242: '121 Water',
#  243: 'Astor House',
#  244: '552 Broadway',
#  245: '302 Third',
#  246: '350 Av 1',
#  247: 'Brooklyn',
#  248: '37 Av D',
#  249: '12 Wall',
#  250: '15 Union pl Hoboken',
#  251: '449 W 29th',
#  252: '650 Fourth',
#  253: '650 Fourth',
#  254: 'EF 23d n Av 4',
#  255: '263 Third',
#  256: '303 Elizabeth',
#  257: '95 Greenwich Ay',
#  258: '238 Wm',
#  259: '205 Third',
#  260: '107 Allen',
#  261: '243 Third',
#  262: '213 Third',
#  263: '592 Fourth',
#  264: '12 Union place S Brooklyn',
#  265: '617 Fourth',
#  266: '241 E 25th',
#  267: '102 Nassau',
#  268: '13 Fifth',
#  269: '629 Fourth',
#  270: '39 Walker',
#  271: '9 Warren pl',
#  272: '55 Cannon',
#  273: 'Brooklyn',
#  274: '39 Broadway',
#  275: '291 Third',
#  276: '114 Varick',
#  277: '65 Sullivan',
#  278: 'Broadway n W 32d',
#  279: '299 W 25th',
#  280: '76 Broad',
#  281: '1 Wall',
#  282: '651 Washington',
#  283: '67 Hamersly',
#  284: '214 Tenth',
#  285: '120 Columbia',
#  286: '260 Grand',
#  287: '260 Grand',
#  288: '129 Third',
#  289: '120',
#  290: '71',
#  291: '72',
#  292: '37 E 20th',
#  293: 'Taylor s hotel',
#  294: '280 Av 3',
#  295: '124E B way',
#  296: 'Green',
#  297: '110 Twelfth',
#  298: 'Brooklyn',
#  299: '100 York Jersey City',
#  300: '4 Tompkins',
#  301: '471 Grand',
#  302: '47 N Moore',
#  303: 'Court c Jora',
#  304: '20 Norfolk',
#  305: 'Brooklyn',
#  306: '100',
#  307: '29534 Pearl',
#  308: '141 Front',
#  309: '790 Washgtn',
#  310: '42 Essex',
#  311: '250 Stanton',
#  312: '84 Ludlow',
#  313: '254E B way',
#  314: 'Abbott s collegiate',
#  315: '543 Laight',
#  316: '260 Greene',
#  317: 'institution for young',
#  318: '170 Attorney',
#  319: '158W 20th',
#  320: '349 Cherry',
#  321: 'E 30th n Av 3',
#  322: 'Philadelphia',
#  323: '75 Montgomery',
#  324: 'W 40th c B way',
#  325: '4 Ludlow',
#  326: '833 Greenwich and',
#  327: '187 Forsyth',
#  328: '117 Cedar',
#  329: 'W 29th n Av 8',
#  330: '117 Cedar',
#  331: '94 Lewis',
#  332: '584 Houston',
#  333: '24 Second',
#  334: '37734 Grand',
#  335: '125 Av 2',
#  336: '190 South',
#  337: '474 Broadway',
#  338: 'City Hotel',
#  339: '152 Norfolk',
#  340: '',
#  341: '32 Clarkson',
#  342: '71 Cannon',
#  343: '37 Wooster',
#  344: '103 Monroe',
#  345: '359 Rivington',
#  346: '1 Hammond',
#  347: '40 Greene',
#  348: '77 Av 4',
#  349: '140 B Rathbun s',
#  350: '47 Cherry',
#  351: 'Portchester',
#  352: 'Portchester',
#  353: 'Portchester',
#  354: 'Ptchester',
#  355: '429 Av 6 136W 28th',
#  356: 'W 27th n Av 6',
#  357: '333 Av 6',
#  358: '90 Ridge',
#  359: '10 E 14th',
#  360: '199 W 24th',
#  361: '96 Charlton',
#  362: '98 First',
#  363: 'Brooklyn',
#  364: '180 Henry BAlyn',
#  365: '73 Broome',
#  366: '2 Lewis',
#  367: '165 Second',
#  368: '124 Stanton',
#  369: '185 Clinton 185 Cla',
#  370: '185 Rivington',
#  371: '102 Columbia',
#  372: '455 Pearl',
#  373: '225 Seventh',
#  374: '64 Crosby',
#  375: '97 Chthm',
#  376: 'A 308 Rivington',
#  377: '155 W Broadway',
#  378: '32 Orchard',
#  379: '465 Pearl',
#  380: '97 W 16th',
#  381: '20 Wooster',
#  382: '32 Goerck',
#  383: '16 Mercer',
#  384: '32 Goerck',
#  385: '403 Tenth',
#  386: '144 Front',
#  387: '58 Grove',
#  388: '267 Spring',
#  389: '305 Ninth',
#  390: '443 Broadway',
#  391: 'N Jersey',
#  392: '58 Lispenard',
#  393: '111 Hudson',
#  394: '141 Franklin',
#  395: 'Germany',
#  396: '57 Amos',
#  397: '145 Houston',
#  398: 'W 26th n Av 7',
#  399: '51 N Moore',
#  400: '89 Ludlow',
#  401: '41 Walker',
#  402: '133 Willett',
#  403: '228 W 24th',
#  404: '119 Delancey',
#  405: '65 W 27th',
#  406: '65 W 27th',
#  407: '98 Charles',
#  408: '89 Barrow',
#  409: '662 Water',
#  410: '25 Coll pl',
#  411: '147 Sullivan',
#  412: '205 Stanton',
#  413: '178 W 16',
#  414: '261 Elizbth',
#  415: '64 Cedar',
#  416: '18 Factory',
#  417: '55 Bayard',
#  418: '7 Morton',
#  419: '4 Vandam',
#  420: '145 Amos',
#  421: 'W 138th n Av 8',
#  422: '1554 Division',
#  423: '170 Houston',
#  424: '84 Walnut',
#  425: '64 Cedar',
#  426: '44 Sheriff',
#  427: '140 Franklin',
#  428: '170 E 27th',
#  429: '53 Bank',
#  430: 'Av 7 n W dist',
#  431: '678 Greenwich',
#  432: '133 Franklin',
#  433: '105 Brely',
#  434: '37 Renwick',
#  435: '118 Greenwich Av',
#  436: '714 Washington',
#  437: '5 Jones',
#  438: '5 Morton',
#  439: 'Av 7c W 20th',
#  440: '30 Charles',
#  441: '144 Amos',
#  442: '24 Rose',
#  443: '241 Av 8',
#  444: '150 W 17th',
#  445: '181 William',
#  446: '5 W Broadway pl',
#  447: '260',
#  448: '130 Hammond',
#  449: '86 W 16th',
#  450: '187 W 16th',
#  451: '646 Hudson',
#  452: '187 W 16th',
#  453: '186 E 11th',
#  454: '54 Sullivan',
#  455: '284 Hudson',
#  456: '372 Houston',
#  457: '140 Amity',
#  458: '78 Wail',
#  459: '94 Attorney',
#  460: '134 W 16th',
#  461: '160 Hammond',
#  462: 'W 29th n Av 19',
#  463: '164 Spring',
#  464: 'Hoyt n Atlantic Brooklyn',
#  465: '130 Troy and 170 Hammond',
#  466: '60 Broome',
#  467: '133 Franklin',
#  468: '92 Grove',
#  469: '42 Canal 12 W Broadway pl',
#  470: '55 Houston',
#  471: '175 Fourth',
#  472: '174 W 28th',
#  473: 'W 36th n Av 9',
#  474: 'W 30th Av 7',
#  475: 'W 22d n Av 7',
#  476: '18 Minetta la',
#  477: '43 Renwick',
#  478: 'Newark',
#  479: '173 W 22d',
#  480: '25 Bethune',
#  481: '372 Houston',
#  482: '103 Nassau',
#  483: '26034 Division',
#  484: '262 Stanton',
#  485: '4744 Frankfort',
#  486: '246 W 24th',
#  487: '150 W 20th',
#  488: '287 W 17th',
#  489: '697 Washington',
#  490: '161 Hammond',
#  491: '172 Amos',
#  492: '205 Sullivan',
#  493: '29 Jones',
#  494: '17 Broome',
#  495: '279 Av 3',
#  496: '162 W Broadway',
#  497: '161 Hammond',
#  498: '714 Washington',
#  499: '17 Broome',
#  500: '160 Grand',
#  501: '143 Duffield Brooklyn',
#  502: '607 Water',
#  503: '143 Duffield Brooklyn',
#  504: '140 Franklin',
#  505: '275 Mulberr',
#  506: '230 Canal',
#  507: '132 Sands Brklyn',
#  508: '93 Powers Brooklyn',
#  509: '224 Wooster',
#  510: 'W 18th n Ay 6',
#  511: '249 W 13th',
#  512: '48 Ludlow',
#  513: 'W 28th n Av 10',
#  514: '230 W 24th herry',
#  515: '190 C',
#  516: '124 Av 7',
#  517: '734 Trinity pl',
#  518: '97 Reade',
#  519: '61 First',
#  520: '19 Ann',
#  521: 'Brooklyn',
#  522: '266 Madison',
#  523: 'Boston',
#  524: '43 Forsyth',
#  525: 'W 35th n Broadway',
#  526: '148 Hammond',
#  527: '147 W 28th',
#  528: '34 Bank',
#  529: '646 Water',
#  530: '306 W 24th',
#  531: '91 Cannon',
#  532: '176 Hudson',
#  533: '176 Hudson',
#  534: '47 White',
#  535: '19 Stanton',
#  536: 'E 25th n Lexington Av',
#  537: '70044 Greenwich',
#  538: '13 Wall',
#  539: '9 Sheriff',
#  540: '16 Roosevelt',
#  541: '91 Cannon',
#  542: 'W 28th n Av 8',
#  543: '309 Pearl',
#  544: '41 Wall',
#  545: '75 Mott',
#  546: 'Degraw pl Brooklyn',
#  547: 'Brooklyn',
#  548: '241 Canal',
#  549: '117 Madison',
#  550: 'W 40th n Av 7',
#  551: '159 W 15th',
#  552: '64 Twelfth',
#  553: '164 W 18th',
#  554: '47 Amity',
#  555: '412 Greenwich',
#  556: '122 Warren',
#  557: '687 Greenwich',
#  558: '36 Scammel',
#  559: '38 Varick',
#  560: '124 Broad',
#  561: '36 Hubert',
#  562: '27 Horatio',
#  563: 'Barnum s hotel',
#  564: '47 Amity',
#  565: '87 Madison',
#  566: '180 Av C',
#  567: '75 E 15th',
#  568: '111 Suffolk',
#  569: '215 Walker',
#  570: '165 Maiden lane',
#  571: '252 W 16th',
#  572: 'W msburg',
#  573: '687 Greenwich',
#  574: '343 Av 4',
#  575: '59 Warren',
#  576: '2 W Broadway pl',
#  577: '296 Greenwich',
#  578: 'W 40th Av 7',
#  579: '55 Leonard',
#  580: '27 Horatio',
#  581: '97 Reade',
#  582: 'W 29th Av 9',
#  583: '145 Washington Dunning s hotel',
#  584: '307 Bleecker',
#  585: '114 Hudson',
#  586: '225 Av 8',
#  587: '6 Joralemon Brooklyn',
#  588: '51 E 16th',
#  589: '121 8 2d Williamsburgh',
#  590: '51 E 16th',
#  591: '216 Ay 6',
#  592: '298 Broadway',
#  593: '241 Bleecker',
#  594: '316 Gold Brklyn',
#  595: '71 Wall',
#  596: '385 Av 6',
#  597: '104 Bowery',
#  598: '126 Franklin',
#  599: '198 Chatham sq',
#  600: '51 South',
#  601: '199 Houston',
#  602: '178 Av 3',
#  603: '601 Houston',
#  604: '186 Church',
#  605: '28 Perry',
#  606: '193 Av 8',
#  607: '3 Anthony',
#  608: '422 Cherry',
#  609: '348 Bwry',
#  610: '244 Fulton',
#  611: '124 Nassau',
#  612: '260 South',
#  613: '87 Wall',
#  614: '145 Washington',
#  615: '16 Wall',
#  616: '75 Front',
#  617: '51 South',
#  618: '74 Front',
#  619: '18 South',
#  620: '148 Front',
#  621: '399 Fourth',
#  622: '94 Eldridge',
#  623: '6 Bowery',
#  624: '311 Broadway',
#  625: '188 W 25th',
#  626: '57 Av 6',
#  627: 'Av 7 W 27th',
#  628: '52 Av 3',
#  629: '266 Second',
#  630: '650 Hudson',
#  631: '275 Broadway',
#  632: '158 Henry',
#  633: 'Brooklyn',
#  634: 'W 30th c Av 6',
#  635: '389 B way',
#  636: '299 Broome',
#  637: '33 Lexington Av',
#  638: '150 W 16th',
#  639: '61 Suffolk',
#  640: '77 Pitt',
#  641: 'E 28th n Av 3',
#  642: '159 E 14th',
#  643: '85 Twelfth',
#  644: '191 Clinton',
#  645: '416 Av 3',
#  646: '248 Houston',
#  647: '303 Houston',
#  648: '84 Eldridge',
#  649: '76 Stanton',
#  650: '105 Mott',
#  651: '94 Warren',
#  652: '33 Henry',
#  653: '159 Pearl',
#  654: '109 Mercer',
#  655: 'Ay 10 c W 33d Av 10 c W 33d',
#  656: '73 Duane',
#  657: '40 E 28th',
#  658: '105 Henry',
#  659: '270 Division',
#  660: '216 Stanton',
#  661: '4 Wooster',
#  662: '282 Bowry',
#  663: '34 Allen',
#  664: '95 Canal',
#  665: '159 Second',
#  666: '252 Delancy',
#  667: '69 Ludlow',
#  668: '8 Clarkson',
#  669: '50 Bowery',
#  670: '423 Pearl',
#  671: '265 Broadway',
#  672: '300 Div sn',
#  673: '50 Downing',
#  674: '87 Barrow',
#  675: '48 Trinity pl',
#  676: 'Av 3 c',
#  677: '16 Varick pl',
#  678: '251 Tenth',
#  679: '10 Second',
#  680: '93 Pitt',
#  681: '566 Broadway',
#  682: '15 Forsyth',
#  683: '19 Av A',
#  684: 'N Y 66 Wall',
#  685: '72 Wall',
#  686: '106 Lewis',
#  687: '584 Water',
#  688: '98 Chmbrs',
#  689: 'up stairs',
#  690: '142 Lewis',
#  691: '265 Division',
#  692: '54 Brely',
#  693: '523 Washington',
#  694: '114 Bowery',
#  695: '383 Cherry',
#  696: '383 Cherry',
#  697: '99 Orange',
#  698: '27 Mulberry',
#  699: '26 Av B',
#  700: '31 EK 21st',
#  701: '246 W 20th',
#  702: '321 Fifth',
#  703: '33 Anthony',
#  704: '234 Clinton',
#  705: '245 Elizabeth',
#  706: '154 Greenwich',
#  707: '434 Tenth',
#  708: 'Av 8 c 48th',
#  709: '377 Ninth',
#  710: '224 E 13th',
#  711: '31 E 21st',
#  712: '230 Delne',
#  713: '13 Rutgers pl',
#  714: '25 Ninth',
#  715: '76 Broad',
#  716: '320 Monroe',
#  717: '320 Monroe',
#  718: '334 Eighth',
#  719: '364 Cherry',
#  720: '89 Market',
#  721: '430 Cherry',
#  722: '22 Prince',
#  723: '75 Frankfort',
#  724: '358 Cherry',
#  725: '196 Chambers',
#  726: 'Europe',
#  727: '272 Division',
#  728: '176 W 18th',
#  729: 'Brooklyn',
#  730: '483 Greenwich',
#  731: '148 Wooster',
#  732: '196 Cherry',
#  733: '324 Ann',
#  734: '106 Av C',
#  735: '240 William and 10 Duane 240 William',
#  736: '330 Av 3',
#  737: 'W 30th n Av 7 bh W 30th n Av 7',
#  738: '148 Wooster',
#  739: '665 Washington',
#  740: '59 King',
#  741: '475 Washington',
#  742: '92 Sherif',
#  743: '141 Pearl',
#  744: '171 Front Earle s hotel',
#  745: '7 Jackson sl',
#  746: '231 Tenth',
#  747: '187 Madison',
#  748: '29 Rutgers',
#  749: '124 Madison',
#  750: '42 McDougal',
#  751: '105 Monroe',
#  752: '124 Madison',
#  753: '89 Pine',
#  754: '237 Rivington',
#  755: 'Av 3 E 28th',
#  756: '73 Av 2',
#  757: '118 E 13th',
#  758: '48 Av 3',
#  759: 'Av 10',
#  760: '174 Hudson',
#  761: '93 Hester',
#  762: '26 Ludlow',
#  763: '121 Division',
#  764: '175 W 21st',
#  765: '6 Amity pl',
#  766: '252 W 16th',
#  767: '301 Sixth',
#  768: '22 Norfolk',
#  769: '22 Prince',
#  770: '423 Broadway 196 Prince',
#  771: 'Av 2c E 27th',
#  772: '298 Hudson',
#  773: '398 West',
#  774: '298 Hdsn',
#  775: '85 Hmnd',
#  776: '173 S th',
#  777: '298 Hudson',
#  778: '423 Broadway',
#  779: '40 Vandam',
#  780: '173 Av 6',
#  781: '278 Spring',
#  782: '329W 24th',
#  783: '6 Stanton',
#  784: '181 Av 6 181 Av 6',
#  785: '228 Av 8',
#  786: 'Williamsburg',
#  787: '119 Suffolk',
#  788: '17 Stntn',
#  789: '150 Bowery',
#  790: '425 Av 6',
#  791: '231 Second',
#  792: '75 Forsyth',
#  793: 'Sackett n Court Brooklyn',
#  794: '415 Greenwich',
#  795: '17 Perry',
#  796: '559 Fourth',
#  797: '21 Jacob 92 Gold',
#  798: '244 Fifth',
#  799: 'W 88th n Av 5',
#  800: '16 South',
#  801: '1243g Cannon',
#  802: '194 Houston',
#  803: '125 Orchrd',
#  804: '58 Market',
#  805: '663 Houston',
#  806: '26 West',
#  807: '884 Tenth',
#  808: '245 Fifth',
#  809: '173 ALA',
#  810: '197 Second',
#  811: '210 W 26th',
#  812: '152 Cherry',
#  813: '36934 Pearl',
#  814: '36932 Pearl',
#  815: '420 Tenth',
#  816: '159 Charles',
#  817: '745 Greenwich',
#  818: '',
#  819: '251 Division',
#  820: '63 Carmine',
#  821: '391 Pearl',
#  822: '14 Broome',
#  823: '431 Houston',
#  824: '431 Houston',
#  825: '29 Downing',
#  826: '200 Greene',
#  827: '105 Av 7',
#  828: '82 Av D',
#  829: '44 Wall',
#  830: '192 Delancy',
#  831: '79 Cannon',
#  832: '152 Fourth',
#  833: '260 Stntn',
#  834: '103 First',
#  835: '194 Houston',
#  836: '142 Grnd',
#  837: '92 Kin',
#  838: '101 Norfol',
#  839: '379 Bowery',
#  840: '389 Greenwich',
#  841: '167 Bow ry',
#  842: 'Elizabetht wn',
#  843: '153 Norfolk',
#  844: '167 Bowery',
#  845: '328 Bowry',
#  846: '455 Hudson',
#  847: '253 Bowery',
#  848: '156 Bowery and 256 Grand',
#  849: '72',
#  850: '141 Pearl',
#  851: 'Bleecker n Wooster',
#  852: '202 Greene',
#  853: '163 Barrow',
#  854: '194 Varick',
#  855: '44 Dey',
#  856: '77 Centre',
#  857: '72 Market',
#  858: '78 Chambers',
#  859: '30 Carmine',
#  860: '9 State',
#  861: '9 State',
#  862: '308 Hudson 140 Varick',
#  863: '51 Morton',
#  864: '276 W 29th',
#  865: 'Brooklyn',
#  866: '183 Chmbrs',
#  867: '112 West North rn Hotel',
#  868: '43 First',
#  869: 'Hurlgate',
#  870: '15 Goerck',
#  871: '49 E 16th',
#  872: '54 Horatio',
#  873: '295 Pearl',
#  874: '19 City Hall',
#  875: '142 Av 3',
#  876: '31 Cannon',
#  877: '22 City Hall pl',
#  878: '8 E 14th',
#  879: 'E 26th n Lex Ay',
#  880: '172 Av A',
#  881: '99 Prince',
#  882: '205 Stanton',
#  883: '67 Liberty',
#  884: '314 Rivington',
#  885: '260 E 25th',
#  886: '36 Bedford',
#  887: '00 W 20th',
#  888: '663 Houstn',
#  889: 'W 31st Av 9',
#  890: '74 Reade',
#  891: '19 Prince',
#  892: '188 Ludlow',
#  893: '87 Essex',
#  894: '229 Second',
#  895: '80 Nassau',
#  896: '299 Sixth',
#  897: '128',
#  898: '7 Spruce Prospect Brooklyn',
#  899: 'Hicks n Sackett Brooklyn',
#  900: '77 E 27th',
#  901: '422 Grand',
#  902: '25 Attorne',
#  903: '244 Secnd',
#  904: '503 Houston',
#  905: '164 Canal',
#  906: '6 W 27th',
#  907: '83 Hester',
#  908: '131 Goerck',
#  909: 'Brooklyn',
#  910: '350 Av 6',
#  911: '24 Rivington',
#  912: '378 Ninth',
#  913: '69 Cannon',
#  914: '5 Av 3',
#  915: '150 Lewis',
#  916: '380 Tenth',
#  917: '119 Third',
#  918: '32 Lewis',
#  919: '88 John',
#  920: '271 Monroe',
#  921: '91 Oliver',
#  922: '7 Anthony',
#  923: '122 W 19th',
#  924: '551 Broome',
#  925: '60 Henry',
#  926: '88 John',
#  927: '14 E 18th',
#  928: '5 Chambers',
#  929: '65 Fulton',
#  930: '104 Grnd',
#  931: '47 Ann 198 William',
#  932: '47 Ann',
#  933: '550 Grand 14 Cannon',
#  934: '174 Essex',
#  935: '21 Hammond',
#  936: '5 Platt',
#  937: '41 Allen',
#  938: '58 Stanton',
#  939: '94 W Broadway',
#  940: '127 Franklin',
#  941: 'Harsimus',
#  942: 'Jersey city',
#  943: '85 Dey',
#  944: '72 Pike',
#  945: '107 E 27th',
#  946: '10 Lewis',
#  947: '100 Oliver',
#  948: '29 Av A',
#  949: '341 Fourth',
#  950: '33 Canal',
#  951: '504 Hudson',
#  952: '248 Rivington',
#  953: '523 Hdsn 15 Morton',
#  954: '214 Broome',
#  955: '636 Greenwich',
#  956: 'Wmsburg',
#  957: '266 Monroe',
#  958: '10 Morton',
#  959: '169 Henry',
#  960: '164 Christopher',
#  961: '534 Hudson',
#  962: 'Wmsbg Cherry',
#  963: '203 W 24th',
#  964: '161 Mott',
#  965: '22 Morton',
#  966: '468 Houston',
#  967: '22 Morton',
#  968: '262 Seventh',
#  969: '61 Leroy',
#  970: '419 Broadway 93 Morton',
#  971: '44 Broome',
#  972: '149 Wooster',
#  973: 'Av 9 & W 37th',
#  974: '113 Cherry',
#  975: '17 Vandewater',
#  976: '53 Watts',
#  977: '226 Washgtn',
#  978: 'E 42d Av 3',
#  979: '152 Varick',
#  980: '37 Rose',
#  981: '27 Ridge',
#  982: 'Wyck ff Brklyn',
#  983: '70 G wich',
#  984: '18 White',
#  985: '24 Perry',
#  986: '341 Broadway',
#  987: '131 E 21st',
#  988: 'E 41st n Av 1',
#  989: 'Co 189 and 191 Water',
#  990: '44 Hubert',
#  991: '46 Hubert',
#  992: 'Av 8c W 29th',
#  993: '44 Sidney pl Brooklyn',
#  994: 'W 18th n Av 6',
#  995: 'W 37th n Av 9',
#  996: '267 Av 3',
#  997: '564 Grand',
#  998: '37 Bowery',
#  999: '267 Av 3',
#  ...}

# %%
#temp_replace_specials[497]

# %%
df['Full Address'] = new_full_address.values()

# %%
for a in range(0, len(df)):
    try:
        if len(part_after_and[a])>0:
            pass
    except:
        part_after_and[a] = ''

# %%
for a in range(0, len(df)):
    try:
        if len(part_before_h[a])>0:
            pass
    except:
        part_before_h[a] = ''

# %%
part_after_and_complete = collections.OrderedDict(sorted(part_after_and.items()))
part_before_h_complete = collections.OrderedDict(sorted(part_before_h.items()))

# %%
df['part after and'] = list(part_after_and_complete.values())
df['part before h'] = list(part_before_h_complete.values())

# %%
df.to_csv('/Users/prajwal/Desktop/Columbia/C4SR/tesseract lib/mn 1850/data/MN_1850 tesseract spl removed.csv')
