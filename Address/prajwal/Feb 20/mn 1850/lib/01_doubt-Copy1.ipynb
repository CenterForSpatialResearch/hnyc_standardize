# %%
import pandas as pd
import numpy as np

# %%
#df = pd.read_excel('/Users/prajwal/Desktop/Columbia/C4SR/mn_1880/not so confident.xlsx')

# %%
#df = pd.read_csv('/Users/prajwal/Desktop/Columbia/C4SR/tesseract output/MN_1880_final_output_tesseract.csv')
df = pd.read_csv('/Users/prajwal/Desktop/Columbia/C4SR/tesseract lib/mn 1850/data/MN_1850 tesseract spl removed.csv')

# %%
#df_slice1 = df.loc[df['filter1']==1]

# %%
df_slice1 = df

# %%
try:
    df_slice1 = df_slice1.rename({'clean address': 'clean_address'}, axis=1)
except:
    pass
try:
    df = df.rename({'clean address': 'clean_address'}, axis=1)
except:
    pass

# %%
#slice1_addresses = list(dict(df_slice1['clean_address']).values()) #was initially uncommented



#slice1_addresses = list(dict(df_slice1['clean address']).values())

# %%
slice1_addresses = list(dict(df_slice1['Full Address']).values())

# %%
modified_clean_address = df['Full Address'].str.replace('Ã¢Â\x80Â\x99',"'").str.replace('Ã¢ÂÂ',"'").str.replace("Ã¢Â\x80Â\x98","").str.replace("Ã¢Â\x80Â\x9c","").str.replace("Ã¢Â\x80Â\x9d","")


"""


#modified_clean_address = df['clean_address'].str.replace('Ã¢Â\x80Â\x99',"'").str.replace('Ã¢ÂÂ',"'").str.replace("Ã¢Â\x80Â\x98","").str.replace("Ã¢Â\x80Â\x9c","").str.replace("Ã¢Â\x80Â\x9d","")
modified_clean_address = modified_clean_address.str.replace("hN", "h N")
print(modified_clean_address[0])
modified_clean_address = modified_clean_address.str.replace(".5 ", " ")
print(modified_clean_address[0])
modified_clean_address = modified_clean_address.str.replace(",h ", ", h ")
print(modified_clean_address[0])
modified_clean_address = modified_clean_address.str.replace(",h", ", h ")
print(modified_clean_address[0])
modified_clean_address = modified_clean_address.str.replace(", h.", ", h. ")
print(modified_clean_address[0])
modified_clean_address = modified_clean_address.str.replace(", h .", ", h. ")
print(modified_clean_address[0])
modified_clean_address = modified_clean_address.str.replace("H udson", "Hudson")
modified_clean_address = modified_clean_address.str.replace("'wav", "'way")
modified_clean_address = modified_clean_address.str.replace("B'way", "Broadway")
modified_clean_address = modified_clean_address.str.replace("B way", "Broadway")
modified_clean_address = modified_clean_address.str.replace("B'kly n", "B'klyn")
modified_clean_address = modified_clean_address.str.replace(",n", " n")
modified_clean_address = modified_clean_address.str.replace("W.h", " Wh")
modified_clean_address = modified_clean_address.str.replace("h-", " h ")
modified_clean_address = modified_clean_address.str.replace("h-", " h ")
modified_clean_address = modified_clean_address.str.replace("-h.", "h.")
#modified_clean_address = modified_clean_address.str.replace("H()", "h.")
#modified_clean_address = modified_clean_address.str.replace("*", " ")
#modified_clean_address = modified_clean_address.str.replace("h r.", "h r")

#modified_clean_address = modified_clean_address.str.replace(".h", ", h.")

#modified_clean_address = modified_clean_address.str.replace("^h", "  h")
#modified_clean_address = modified_clean_address.str.replace("h*", "  h ")

#modified_clean_address = modified_clean_address.str.replace(". .", " ")
"""
# Out:
# '\n\n\n#modified_clean_address = df[\'clean_address\'].str.replace(\'Ã¢Â\x80Â\x99\',"\'").str.replace(\'Ã¢Â\x80Â\x99\',"\'").str.replace("Ã¢Â\x80Â\x98","").str.replace("Ã¢Â\x80Â\x9c","").str.replace("Ã¢Â\x80Â\x9d","")\nmodified_clean_address = modified_clean_address.str.replace("hN", "h N")\nprint(modified_clean_address[0])\nmodified_clean_address = modified_clean_address.str.replace(".5 ", " ")\nprint(modified_clean_address[0])\nmodified_clean_address = modified_clean_address.str.replace(",h ", ", h ")\nprint(modified_clean_address[0])\nmodified_clean_address = modified_clean_address.str.replace(",h", ", h ")\nprint(modified_clean_address[0])\nmodified_clean_address = modified_clean_address.str.replace(", h.", ", h. ")\nprint(modified_clean_address[0])\nmodified_clean_address = modified_clean_address.str.replace(", h .", ", h. ")\nprint(modified_clean_address[0])\nmodified_clean_address = modified_clean_address.str.replace("H udson", "Hudson")\nmodified_clean_address = modified_clean_address.str.replace("\'wav", "\'way")\nmodified_clean_address = modified_clean_address.str.replace("B\'way", "Broadway")\nmodified_clean_address = modified_clean_address.str.replace("B way", "Broadway")\nmodified_clean_address = modified_clean_address.str.replace("B\'kly n", "B\'klyn")\nmodified_clean_address = modified_clean_address.str.replace(",n", " n")\nmodified_clean_address = modified_clean_address.str.replace("W.h", " Wh")\nmodified_clean_address = modified_clean_address.str.replace("h-", " h ")\nmodified_clean_address = modified_clean_address.str.replace("h-", " h ")\nmodified_clean_address = modified_clean_address.str.replace("-h.", "h.")\n#modified_clean_address = modified_clean_address.str.replace("H()", "h.")\n#modified_clean_address = modified_clean_address.str.replace("*", " ")\n#modified_clean_address = modified_clean_address.str.replace("h r.", "h r")\n\n#modified_clean_address = modified_clean_address.str.replace(".h", ", h.")\n\n#modified_clean_address = modified_clean_address.str.replace("^h", "  h")\n#modified_clean_address = modified_clean_address.str.replace("h*", "  h ")\n\n#modified_clean_address = modified_clean_address.str.replace(". .", " ")\n'

# %%
for i in range(0,len(modified_clean_address)):
    if str(modified_clean_address[i]) == 'nan':
        print(i, modified_clean_address[i])
        modified_clean_address[i] = ''
# Out:
# 340 nan
# 818 nan
# 1163 nan
# 1175 nan
# 1547 nan
# 1564 nan
# 2241 nan
# 2767 nan
# 2985 nan
# 3033 nan
# 3102 nan
# 3561 nan
# 4886 nan
# 6605 nan
# 6826 nan
# 7404 nan
# 7421 nan
# 7755 nan
# 7776 nan
# 7794 nan
# 8237 nan
# 8526 nan
# 8917 nan
# 9106 nan
# 9159 nan
# 9190 nan
# 9286 nan
# 9632 nan
# 10217 nan
# 10279 nan
# 10465 nan
# 10487 nan
# 10771 nan
# 10791 nan
# 11049 nan
# 11066 nan
# 11098 nan
# 11340 nan
# 11360 nan
# 11396 nan
# 11415 nan
# 11499 nan
# 11949 nan
# 12068 nan
# 12124 nan
# 12135 nan
# 12137 nan
# 12190 nan
# 12370 nan
# 12515 nan
# 12668 nan
# 12772 nan
# 13155 nan
# 13256 nan
# 13369 nan
# 13470 nan
# 13493 nan
# 13579 nan
# 13587 nan
# 13614 nan
# 13615 nan
# 13733 nan
# 13756 nan
# 80023 nan
# 80024 nan
# 80030 nan
# 80033 nan
# 80047 nan
# 80050 nan
# 80053 nan
# 80055 nan
# 80065 nan
# 80075 nan
# 80086 nan
# 80089 nan
# 80096 nan
# 80099 nan
# 80100 nan
# 80101 nan
# 80103 nan
# 80104 nan
# 80105 nan
# 80106 nan
# 80107 nan
# 80111 nan
# 80114 nan
# 80115 nan
# 80116 nan
# 80125 nan
# 80128 nan
# 80129 nan
# 80134 nan
# 80138 nan
# 80141 nan
# 80144 nan
# 80148 nan
# 80153 nan
# 80161 nan
# 80167 nan
# 80175 nan
# 80177 nan
# 80183 nan
# 80186 nan
# 80205 nan
# 80207 nan
# 80209 nan
# 80217 nan
# 80225 nan
# 80226 nan
# 80249 nan
# 80255 nan
# 80270 nan
# 80279 nan
# 80280 nan
# 80299 nan
# 80305 nan
# 80335 nan
# 80340 nan
# 80347 nan
# 80350 nan
# 80356 nan
# 80359 nan
# 80360 nan
# 80364 nan
# 80369 nan
# 80378 nan
# 80385 nan
# 80386 nan
# 80391 nan
# 80398 nan
# 80399 nan
# 80403 nan
# 80407 nan
# 80412 nan
# 80414 nan
# 80416 nan
# 80421 nan
# 80425 nan
# 80426 nan
# 80435 nan
# 80441 nan
# 80443 nan
# 80445 nan
# 80450 nan
# 80451 nan
# 80468 nan
# 80470 nan
# 80472 nan
# 80480 nan
# 80487 nan
# 80491 nan
# 80494 nan
# 80502 nan
# 80504 nan
# 80512 nan
# 80517 nan
# 80518 nan
# 80526 nan
# 80531 nan
# 80534 nan
# 80536 nan
# 80540 nan
# 80547 nan
# 80553 nan
# 80554 nan
# 80556 nan
# 80557 nan

# %%
for i in range(0,len(modified_clean_address)):
        if modified_clean_address[i].find("E.") >= 0:
            modified_clean_address[i] = modified_clean_address[i].replace('E.','E ').replace('  ', ' ')

# %%
for i in range(0,len(modified_clean_address)):
    if modified_clean_address[i].find("W.") >= 0:
        modified_clean_address[i] = modified_clean_address[i].replace('W.','W ').replace('  ', ' ')

# %%
for i in range(0,len(modified_clean_address)):
    if modified_clean_address[i].find(".h") >= 0:
        modified_clean_address[i] = modified_clean_address[i].replace('.h',', h. ').replace(',,',',').replace('  ',' ')

# %%
for i in range(0,len(modified_clean_address)):
    if modified_clean_address[i].find(",c") >= 0:
        modified_clean_address[i] = modified_clean_address[i].replace(',c',' c')

# %%
for i in range(0,len(modified_clean_address)):
    if modified_clean_address[i].find(" c. ") >= 0:
        modified_clean_address[i] = modified_clean_address[i].replace('c.','c')

# %%
for i in range(0,len(modified_clean_address)):
    if modified_clean_address[i].find(" n. ") >= 0:
        modified_clean_address[i] = modified_clean_address[i].replace(' n. ',' n ')

# %%
for i in range(0,len(modified_clean_address)):
    if modified_clean_address[i].find("h r ") >=0:
        modified_clean_address[i] = modified_clean_address[i].replace('h r','h. rear').replace('rear.','rear ')

# %%
for i in range(0,len(modified_clean_address)):
    if modified_clean_address[i].find("h. r ") >=0:
        modified_clean_address[i] = modified_clean_address[i].replace('h. r','h. rear').replace('rear.','rear ')

# %%
for i in range(0,len(modified_clean_address)):
    if modified_clean_address[i][0:2].find("h'") >=0:
        modified_clean_address[i] = modified_clean_address[i].replace("h'","h. ")

# %%
for i in range(0,len(modified_clean_address)):
    if modified_clean_address[i][0:2].find("th") >=0:
        modified_clean_address[i] = modified_clean_address[i].replace("th","h")

# %%
modified_clean_address[0]
# Out:
# '39 Pearl'

# %%
#re.findall(r'. 1', '.1')

# %%
import re

modified_clean_address4 = []
intersections_n_1 = []
intersections_n_2 = []

intersections_c_1 = []
intersections_c_2 = []

for i in range(0,len(modified_clean_address)):
    temp = modified_clean_address[i]
    
    
    
    
    """
    string_with_th = re.findall(r'[0-9]+th', temp)
    for j in range (0, len(string_with_th)):
        temp = temp.replace(string_with_th[j], string_with_th[j].replace('th',''))
    
    string_with_d = re.findall(r'[0-9]+d', temp)
    for j in range (0, len(string_with_d)):
        temp = temp.replace(string_with_d[j], string_with_d[j].replace('d',''))
    
    string_with_rd = re.findall(r'[0-9]+rd', temp)
    for j in range (0, len(string_with_rd)):
        temp = temp.replace(string_with_rd[j], string_with_rd[j].replace('rd',''))
    
    string_with_st = re.findall(r'[0-9]+st', temp)
    for j in range (0, len(string_with_st)):
        temp = temp.replace(string_with_st[j], string_with_st[j].replace('st',''))
    
    string_with_h_dot = re.findall(r'h.+[0-9]', temp)
    for j in range (0, len(string_with_h_dot)):
        temp = temp.replace(string_with_h_dot[j], string_with_h_dot[j].replace('h.','h. ').replace('  ',' '))
    
    string_with_h = re.findall(r'h+[0-9]', temp)
    for j in range (0, len(string_with_h)):
        temp = temp.replace(string_with_h[j], string_with_h[j].replace('h','h ').replace('  ',' '))
        
    string_with_fullstop = re.findall(r'. +[0-9]', temp)
    for j in range (0, len(string_with_fullstop)):
        temp = temp.replace(string_with_fullstop[j], string_with_fullstop[j].replace('.','. h ').replace('  ',' '))
    
    string_with_comma = re.findall(r', +[0-9]', temp)
    for j in range (0, len(string_with_comma)):
        temp = temp.replace(string_with_comma[j], string_with_comma[j].replace(',',', h ').replace('  ',' '))
    
    string_with_bracket = re.findall(r'\) +[0-9]', temp)
    for j in range (0, len(string_with_bracket)):
        temp = temp.replace(string_with_bracket[j], string_with_bracket[j].replace(')',') h ').replace('  ',' '))
    
    string_with_dash = re.findall(r'-+[0-9]', temp)
    for j in range (0, len(string_with_dash)):
        temp = temp.replace(string_with_dash[j], string_with_dash[j].replace('-','').replace('  ',' '))
    
    string_with_fullstop_number = re.findall(r'.+[0-9]', temp)
    for j in range (0, len(string_with_fullstop_number)):
        temp = temp.replace(string_with_fullstop_number[j], string_with_fullstop_number[j].replace('.','').replace('  ',' '))
    
    
    string_with_S_1 = re.findall(r'[0-9]+S', temp)
    string_with_S_2 = re.findall(r'S+[0-9]', temp)
    string_with_S = string_with_S_1 + string_with_S_2
    for j in range (0, len(string_with_S)):
        #print(i,string_with_S)
        temp = temp.replace(string_with_S[j], string_with_S[j].replace('S','5'))
        #print(temp)
    
    
    """
    
    
    
    try:
        location_of_h_1 = temp.split().index('h.')
    except:
        location_of_h_1 = -1
    try:
        location_of_h_2 = temp.split().index('h')
    except:
        location_of_h_2 = -1
    #print(location_of_h_1, location_of_h_2)

    location_of_h = max(location_of_h_1, location_of_h_2)
    """
    if location_of_h_1>0:
        if location_of_h_2<0:
            location_of_h = location_of_h_1
        else:
            #print(i,'in exception1')
            #print(location_of_h_1, location_of_h_2)
            location_of_h = max(location_of_h_1, location_of_h_2)
    
    else:
        if location_of_h_2 > 0:
            location_of_h = location_of_h_2
        else:
            print(i,'in exception2')
            print(location_of_h_1, location_of_h_2)
            location_of_h = -1
    """
    temp = temp.replace('^','')
    
    
    
    """
    temp = temp.replace('ft.','')
    temp = temp.replace('ft','')
    temp = temp.replace('Ft.','')
    """
    
    undesired_starts = ['.',' .',',',' ,','-',' -','- ',', ','. ',"'","' "," '","''",'&','*','& ','* ',
                       ' &',' *']
    for i in range(0,len(undesired_starts)):
        if temp[0:2].find(undesired_starts[i])>=0:
            temp = temp[0:2].replace(undesired_starts[i],'') + temp[2:]
    
    words_after_h = temp.split()[location_of_h+1:]
    try:
        location_of_n = words_after_h.index('n')
        intersection_n_street1 = ' '.join(words_after_h[0:location_of_n])
        intersection_n_street2 = ' '.join(words_after_h[location_of_n+1:])

        intersections_n_1.append(intersection_n_street1)
        intersections_n_2.append(intersection_n_street2)
    except:
        intersections_n_1.append('')
        intersections_n_2.append('')
    
    try:
        location_of_c = words_after_h.index('c')
        intersection_c_street1 = ' '.join(words_after_h[0:location_of_c])
        intersection_c_street2 = ' '.join(words_after_h[location_of_c+1:])

        intersections_c_1.append(intersection_c_street1)
        intersections_c_2.append(intersection_c_street2)
    except:
        intersections_c_1.append('')
        intersections_c_2.append('')
    
    modified_clean_address4.append(temp)

# %%
#for i in range(0,len(intersections_c_1)):
    #print(i, intersections_c_1[i] + ' and ' + intersections_c_2[i])

# %%
for i in range(0,len(modified_clean_address4)):
    if modified_clean_address4[i].find(".h") >= 0:
        print(i, modified_clean_address4[i])

# %%
#for i in range(0,len(modified_clean_address)):
    #if modified_clean_address[i].find(" n ") >0:
        #print(i, modified_clean_address[i])

# %%
df['modified_clean_address'] = modified_clean_address4

# %%
df['n_street1'] = intersections_n_1
df['n_street2'] = intersections_n_2
df['c_street1'] = intersections_c_1
df['c_street2'] = intersections_c_2

# %%
#df.head()

# %%
#df.to_excel('doubt/not so confident2.xlsx')

# %%
df_modified_addresses = pd.DataFrame(modified_clean_address4, columns=['clean_address'])

# %%
#pd.DataFrame(modified_clean_address2).to_csv('doubt/doubt2.txt', header=None,  sep=' ', mode='a')

# %%
temp_addr = []
for i in range(0,len(df_modified_addresses)):
    temp_addr.append(str(i)+" "+df_modified_addresses['clean_address'][i])
#np.savetxt('doubt/not so confident addr.txt', temp_addr, fmt='%s')

# %%
#np.savetxt('doubt/not so confident addr.txt', temp_addr, fmt='%s')

# %%
#df.head()

# %%
#df.columns

# %%
#df.head()

# %%
df['n_street1'] = df['n_street1'].replace('',np.nan)
df['n_street2'] = df['n_street2'].replace('',np.nan)
df['c_street1'] = df['c_street1'].replace('',np.nan)
df['c_street2'] = df['c_street2'].replace('',np.nan)

# %%
#df['filter11'] = np.where(df['n_street1'].isna() & df['n_street2'].isna() & df['c_street1'].isna() & df['c_street2'].isna() & df['new h house number'].isna() & df['new h street name'].isna(), 1, 0)
#was initially uncommented

df['filter11'] = np.where(df['n_street1'].isna() & df['n_street2'].isna() & df['c_street1'].isna() & df['c_street2'].isna(), 1, 0)

# %%
df_filter11 = df.loc[df['filter11'] == 1]
df_filter11 = df_filter11.reset_index()

# %%
#df_filter11['modified_clean_address']

# %%
modified_clean_address5 = []
for i in range(0,len(df_filter11)):
    temp = df_filter11['modified_clean_address'][i]
    
    string_with_S = re.findall(r'[0-9]+S', temp)
    for i in range (0, len(string_with_S)):
        temp = temp.replace(string_with_S[i], string_with_S[i].replace('S','5'))
    modified_clean_address5.append(temp)

# %%
#for i in range(0,len(modified_clean_address5)):
    #print(i, modified_clean_address5[i])

# %%
#for i in range(0,len(modified_clean_address5)):
    #if modified_clean_address5[i].find("h. ") <0:
        #print(i, modified_clean_address5[i])

# %%
df['modified_clean_address'][10:16]
# Out:
# 10      175 Canal
# 11    137 Norfolk
# 12        53 Av D
# 13       5 Ludlow
# 14         1 Av D
# 15     Morrisania
# Name: modified_clean_address, dtype: object

# %%
df['modified_clean_address'] = df['modified_clean_address'].str.replace('rearear','rear')
df['modified_clean_address'] = df['modified_clean_address'].str.replace('rearefused','refused')
df['modified_clean_address'] = df['modified_clean_address'].str.replace('h. r ','h. rear ')

# %%
df
# Out:
#        Unnamed: 0  Unnamed: 0.1                        Full Name   First Name  \
# 0               0             0                   Ackley Addison      Addison
# 1               1             1                    Adams William      William
# 2               2             2                    Aitkin Thomas       Thomas
# 3               3             3                   Albro Benjamin     Benjamin
# 4               4             4                      Allen E . W            E
# 5               5             5             Anderson Frederick R    Frederick
# 6               6             6                  Anderson John R         John
# 7               7             7                     Anthes Peter        Peter
# 8               8             8                 Anthes & Eckardt            &
# 9               9             9                      Appell John         John
# 10             10            10               Arcularius Jacob S        Jacob
# 11             11            11                  Arenfred George       George
# 12             12            12                 Armstrong George       George
# 13             13            13                 Armstrong John D         John
# 14             14            14                     Arnold Henry        Henry
# 15             15            15                    Ash William A      William
# 16             16            16               Auchincloss John T         John
# 17             17            17             Auchincloss & Croxon            &
# 18             18            18                   Bagley William      William
# 19             19            19                   BAIN ALEXANDER    ALEXANDER
# 20             20            20                  Baldwin Ezekiel      Ezekiel
# 21             21            21                       Ball Isaac        Isaac
# 22             22            22                   Bannon Michael      Michael
# 23             23            23              Barmore Christopher  Christopher
# 24             24            24                   Barratt Thomas       Thomas
# 25             25            25           Barrowclough James , E        James
# 26             26            26                      Barry James        James
# 27             27            27                       Barry John         John
# 28             28            28                     Bates John C         John
# 29             29            29                     Beach John T         John
# ...           ...           ...                              ...          ...
# 80539       80539        112934                              NaN          NaN
# 80540       80540        112937                            ott -            -
# 80541       80541        112940                              NaN          NaN
# 80542       80542        112955                                i          NaN
# 80543       80543        112961                              NaN          NaN
# 80544       80544        112973                              NaN          NaN
# 80545       80545        112981                              NaN          NaN
# 80546       80546        112993                              NaN          NaN
# 80547       80547        113004                        Charles .            .
# 80548       80548        113007                    Dedion â€”â€”       â€”â€”
# 80549       80549        113015                              NaN          NaN
# 80550       80550        113028                 Deferusae â€”â€”       â€”â€”
# 80551       80551        113089                              NaN          NaN
# 80552       80552        113217                              NaN          NaN
# 80553       80553        113224              DELAVAN CHRISTIAN S    CHRISTIAN
# 80554       80554        113234  DELAWARE & HUDSON CANAL COMPANY            &
# 80555       80555        113239                              NaN          NaN
# 80556       80556        113244                      Greenwich .            .
# 80557       80557        113247                       Bleecker |            |
# 80558       80558        113256                              NaN          NaN
# 80559       80559        113261                              NaN          NaN
# 80560       80560        113268                              NaN          NaN
# 80561       80561        113286                              NaN          NaN
# 80562       80562        113291                              NaN          NaN
# 80563       80563        113309                              NaN          NaN
# 80564       80564        113314                              NaN          NaN
# 80565       80565        113320                              NaN          NaN
# 80566       80566        113321                              NaN          NaN
# 80567       80567        113401                              NaN          NaN
# 80568       80568        113429                              NaN          NaN
#
#           Last Name Middle Name  Widow-flag Widow Of  Title  \
# 0            Ackley         NaN       False      NaN    NaN
# 1             Adams         NaN       False      NaN    NaN
# 2            Aitkin         NaN       False      NaN    NaN
# 3             Albro         NaN       False      NaN    NaN
# 4             Allen           .       False      NaN    NaN
# 5          Anderson           R       False      NaN    NaN
# 6          Anderson           R       False      NaN    NaN
# 7            Anthes         NaN       False      NaN    NaN
# 8            Anthes     Eckardt       False      NaN    NaN
# 9            Appell         NaN       False      NaN    NaN
# 10       Arcularius           S       False      NaN    NaN
# 11         Arenfred         NaN       False      NaN    NaN
# 12        Armstrong         NaN       False      NaN    NaN
# 13        Armstrong           D       False      NaN    NaN
# 14           Arnold         NaN       False      NaN    NaN
# 15              Ash           A       False      NaN    NaN
# 16      Auchincloss           T       False      NaN    NaN
# 17      Auchincloss      Croxon       False      NaN    NaN
# 18           Bagley         NaN       False      NaN    NaN
# 19             BAIN         NaN       False      NaN    NaN
# 20          Baldwin         NaN       False      NaN    NaN
# 21             Ball         NaN       False      NaN    NaN
# 22           Bannon         NaN       False      NaN    NaN
# 23          Barmore         NaN       False      NaN    NaN
# 24          Barratt         NaN       False      NaN    NaN
# 25     Barrowclough           ,       False      NaN    NaN
# 26            Barry         NaN       False      NaN    NaN
# 27            Barry         NaN       False      NaN    NaN
# 28            Bates           C       False      NaN    NaN
# 29            Beach           T       False      NaN    NaN
# ...             ...         ...         ...      ...    ...
# 80539           NaN         NaN       False      NaN    NaN
# 80540           ott         NaN       False      NaN    NaN
# 80541           NaN         NaN       False      NaN    NaN
# 80542           NaN         NaN       False      NaN    NaN
# 80543           NaN         NaN       False      NaN    NaN
# 80544           NaN         NaN       False      NaN    NaN
# 80545           NaN         NaN       False      NaN    NaN
# 80546           NaN         NaN       False      NaN    NaN
# 80547       Charles         NaN       False      NaN    NaN
# 80548        Dedion         NaN       False      NaN    NaN
# 80549           NaN         NaN       False      NaN    NaN
# 80550     Deferusae         NaN       False      NaN    NaN
# 80551           NaN         NaN       False      NaN    NaN
# 80552           NaN         NaN       False      NaN    NaN
# 80553       DELAVAN           S       False      NaN    NaN
# 80554      DELAWARE      HUDSON       False      NaN    NaN
# 80555           NaN         NaN       False      NaN    NaN
# 80556     Greenwich         NaN       False      NaN    NaN
# 80557      Bleecker         NaN       False      NaN    NaN
# 80558           NaN         NaN       False      NaN    NaN
# 80559           NaN         NaN       False      NaN    NaN
# 80560           NaN         NaN       False      NaN    NaN
# 80561           NaN         NaN       False      NaN    NaN
# 80562           NaN         NaN       False      NaN    NaN
# 80563           NaN         NaN       False      NaN    NaN
# 80564           NaN         NaN       False      NaN    NaN
# 80565           NaN         NaN       False      NaN    NaN
# 80566           NaN         NaN       False      NaN    NaN
# 80567           NaN         NaN       False      NaN    NaN
# 80568           NaN         NaN       False      NaN    NaN
#
#                 Occupation  ... Address 2 City          Full Address  \
# 0                    clerk  ...            NaN              39 Pearl
# 1                  weigher  ...            NaN  170 Clinton Brooklyn
# 2              stonecutter  ...            NaN        601 Washington
# 3                      sen  ...            NaN            328 Bowery
# 4                publisher  ...            NaN             42 Orange
# 5                      mer  ...            NaN             77 Barrow
# 6                   seaman  ...            NaN             586 E 4th
# 7                      NaN  ...            NaN               34 Av C
# 8                  barbers  ...            NaN               34 Av C
# 9                   tailor  ...            NaN               40 Av C
# 10                     NaN  ...            NaN             175 Canal
# 11                     NaN  ...            NaN           137 Norfolk
# 12               shoemaker  ...            NaN               53 Av D
# 13              coachmaker  ...            NaN              5 Ludlow
# 14                drygoods  ...            NaN                1 Av D
# 15                     way  ...            NaN            Morrisania
# 16                     mer  ...            NaN              7 Murray
# 17                    mers  ...            NaN            192 Fulton
# 18                    bank  ...            NaN     91 Henry Brooklyn
# 19                     NaN  ...            NaN          181 inventor
# 20               shoemaker  ...            NaN               79 Av B
# 21                  pedler  ...            NaN             66 Mangin
# 22                  cooper  ...            NaN             304 Ninth
# 23                   shoes  ...            NaN         E 18th n Av A
# 24                  carman  ...            NaN            605 Fourth
# 25                     NaN  ...            NaN           24th c Av 3
# 26          marblepolisher  ...            NaN          294 Eleventh
# 27               carpenter  ...            NaN               60 Av C
# 28            sarsaparilla  ...            NaN              Brooklyn
# 29                   paper  ...            NaN              22 Vesey
# ...                    ...  ...            ...                   ...
# 80539                  NaN  ...            NaN            Montgomery
# 80540                  NaN  ...            NaN                   NaN
# 80541                  NaN  ...            NaN                Broome
# 80542                  NaN  ...            NaN                   25t
# 80543                  NaN  ...            NaN              Broadway
# 80544                  NaN  ...            NaN              Dominick
# 80545                  NaN  ...            NaN                  Av 1
# 80546                  NaN  ...            NaN          Williamsburg
# 80547                  NaN  ...            NaN                   NaN
# 80548                  NaN  ...            NaN           4 Depau row
# 80549                  NaN  ...            NaN                   DEG
# 80550                  NaN  ...            NaN           69 Union pl
# 80551                  NaN  ...            NaN                   DEL
# 80552                  NaN  ...            NaN        6 St Mark s pl
# 80553  commission merchant  ...            NaN                   NaN
# 80554                  NaN  ...            NaN                   NaN
# 80555                  NaN  ...            NaN                 rsley
# 80556                  NaN  ...            NaN                   NaN
# 80557                  NaN  ...            NaN                   NaN
# 80558                  NaN  ...            NaN              Brooklyn
# 80559                  NaN  ...            NaN          and 250 Av 4
# 80560       liam and hotel  ...            NaN           25 Broadway
# 80561       picture frames  ...            NaN           Bway n W 28
# 80562                  NaN  ...            NaN          Washington a
# 80563                  NaN  ...            NaN         Washington pl
# 80564                  NaN  ...            NaN             liamsburg
# 80565                  NaN  ...            NaN                   Wil
# 80566                  NaN  ...            NaN                   DEM
# 80567                  NaN  ...            NaN                   DEN
# 80568                  NaN  ...            NaN           34th n Av 9
#
#       part after and       part before h modified_clean_address n_street1  \
# 0                NaN                  47               39 Pearl       NaN
# 1                NaN  20 Washington & 13   170 Clinton Brooklyn       NaN
# 2                NaN                 NaN         601 Washington       NaN
# 3                NaN                 NaN             328 Bowery       NaN
# 4                NaN                 NaN              42 Orange       NaN
# 5                NaN                  13              77 Barrow       NaN
# 6                NaN                 NaN              586 E 4th       NaN
# 7                NaN                 NaN                34 Av C       NaN
# 8                NaN                 NaN                34 Av C       NaN
# 9                NaN                 NaN                40 Av C       NaN
# 10               NaN               h 175              175 Canal       NaN
# 11               NaN                 NaN            137 Norfolk       NaN
# 12               NaN                 NaN                53 Av D       NaN
# 13               NaN                 NaN               5 Ludlow       NaN
# 14               NaN                1 Av                 1 Av D       NaN
# 15               NaN                 413             Morrisania       NaN
# 16               NaN                 192               7 Murray       NaN
# 17               NaN                 NaN             192 Fulton       NaN
# 18               NaN                  50      91 Henry Brooklyn       NaN
# 19               NaN                 NaN           181 inventor       NaN
# 20               NaN                 NaN                79 Av B       NaN
# 21               NaN                 NaN              66 Mangin       NaN
# 22               NaN                 NaN              304 Ninth       NaN
# 23               NaN                 NaN          E 18th n Av A    E 18th
# 24               NaN                 NaN             605 Fourth       NaN
# 25               NaN                 NaN            24th c Av 3       NaN
# 26               NaN                 NaN           294 Eleventh       NaN
# 27               NaN                 NaN                60 Av C       NaN
# 28               NaN                  82               Brooklyn       NaN
# 29               NaN                  43               22 Vesey       NaN
# ...              ...                 ...                    ...       ...
# 80539            NaN                 NaN             Montgomery       NaN
# 80540            NaN                 NaN                              NaN
# 80541            NaN                 NaN                 Broome       NaN
# 80542            NaN                 NaN                    25t       NaN
# 80543            NaN                 NaN               Broadway       NaN
# 80544            NaN                 NaN               Dominick       NaN
# 80545            & 2                 NaN                   Av 1       NaN
# 80546            NaN                 NaN           Williamsburg       NaN
# 80547            NaN                 NaN                              NaN
# 80548            NaN                 NaN            4 Depau row       NaN
# 80549            NaN                 NaN                    DEG       NaN
# 80550            NaN                 NaN            69 Union pl       NaN
# 80551            NaN                 NaN                    DEL       NaN
# 80552            NaN                 NaN         6 St Mark s pl       NaN
# 80553            NaN                 NaN                              NaN
# 80554            NaN                 NaN                              NaN
# 80555            NaN                 NaN                  rsley       NaN
# 80556            NaN                 NaN                              NaN
# 80557            NaN                 NaN                              NaN
# 80558            NaN                 NaN               Brooklyn       NaN
# 80559            NaN                 NaN           and 250 Av 4       NaN
# 80560            NaN                 NaN            25 Broadway       NaN
# 80561            NaN                 495            Bway n W 28      Bway
# 80562            NaN                 NaN           Washington a       NaN
# 80563            NaN                 NaN          Washington pl       NaN
# 80564            NaN                 NaN              liamsburg       NaN
# 80565            NaN                 NaN                    Wil       NaN
# 80566            NaN                 NaN                    DEM       NaN
# 80567            NaN                 NaN                    DEN       NaN
# 80568            NaN                 NaN            34th n Av 9      34th
#
#       n_street2  c_street1 c_street2 filter11
# 0           NaN        NaN       NaN        1
# 1           NaN        NaN       NaN        1
# 2           NaN        NaN       NaN        1
# 3           NaN        NaN       NaN        1
# 4           NaN        NaN       NaN        1
# 5           NaN        NaN       NaN        1
# 6           NaN        NaN       NaN        1
# 7           NaN        NaN       NaN        1
# 8           NaN        NaN       NaN        1
# 9           NaN        NaN       NaN        1
# 10          NaN        NaN       NaN        1
# 11          NaN        NaN       NaN        1
# 12          NaN        NaN       NaN        1
# 13          NaN        NaN       NaN        1
# 14          NaN        NaN       NaN        1
# 15          NaN        NaN       NaN        1
# 16          NaN        NaN       NaN        1
# 17          NaN        NaN       NaN        1
# 18          NaN        NaN       NaN        1
# 19          NaN        NaN       NaN        1
# 20          NaN        NaN       NaN        1
# 21          NaN        NaN       NaN        1
# 22          NaN        NaN       NaN        1
# 23         Av A        NaN       NaN        0
# 24          NaN        NaN       NaN        1
# 25          NaN       24th      Av 3        0
# 26          NaN        NaN       NaN        1
# 27          NaN        NaN       NaN        1
# 28          NaN        NaN       NaN        1
# 29          NaN        NaN       NaN        1
# ...         ...        ...       ...      ...
# 80539       NaN        NaN       NaN        1
# 80540       NaN        NaN       NaN        1
# 80541       NaN        NaN       NaN        1
# 80542       NaN        NaN       NaN        1
# 80543       NaN        NaN       NaN        1
# 80544       NaN        NaN       NaN        1
# 80545       NaN        NaN       NaN        1
# 80546       NaN        NaN       NaN        1
# 80547       NaN        NaN       NaN        1
# 80548       NaN        NaN       NaN        1
# 80549       NaN        NaN       NaN        1
# 80550       NaN        NaN       NaN        1
# 80551       NaN        NaN       NaN        1
# 80552       NaN        NaN       NaN        1
# 80553       NaN        NaN       NaN        1
# 80554       NaN        NaN       NaN        1
# 80555       NaN        NaN       NaN        1
# 80556       NaN        NaN       NaN        1
# 80557       NaN        NaN       NaN        1
# 80558       NaN        NaN       NaN        1
# 80559       NaN        NaN       NaN        1
# 80560       NaN        NaN       NaN        1
# 80561      W 28        NaN       NaN        0
# 80562       NaN        NaN       NaN        1
# 80563       NaN        NaN       NaN        1
# 80564       NaN        NaN       NaN        1
# 80565       NaN        NaN       NaN        1
# 80566       NaN        NaN       NaN        1
# 80567       NaN        NaN       NaN        1
# 80568      Av 9        NaN       NaN        0
#
# [80569 rows x 29 columns]

# %%
#df.to_excel('/Users/prajwal/Desktop/Columbia/C4SR/mn_1880/not so confident-mn1880-v7.xlsx')

# %%
df.to_excel('/Users/prajwal/Desktop/Columbia/C4SR/tesseract lib/mn 1850/data/mn-1850-2.xlsx')
