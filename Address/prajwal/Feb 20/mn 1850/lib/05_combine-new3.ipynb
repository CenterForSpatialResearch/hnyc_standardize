# %%
import pandas as pd
#from fuzzywuzzy import fuzz
import pickle

# %%
#mn_or_bk = 'mn' #bk or mn
#year = str(1850) #1850, 1880
#doubttype = 'doubt' #doubt or not so confident

# %%
#df1 = pd.read_csv(mn_or_bk + '_' + year + '/S/' + doubttype + '-' + mn_or_bk + year + '-v7-s.csv')
#df1 = pd.read_csv('/Users/prajwal/Desktop/Columbia/C4SR/tesseract output/run1/mn-1880-3-s.csv')
df1 = pd.read_csv('/Users/prajwal/Desktop/Columbia/C4SR/tesseract lib/mn 1850/data/mn-1850-3-s.csv')

# %%
df1.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Address 2  Address 2 City  \
# 0           0             0        NaN             NaN
# 1           1             1        NaN             NaN
# 2           2             2        NaN             NaN
# 3           3             3        NaN             NaN
# 4           4             4        NaN             NaN
#
#    Address 2 House Number  Address 2 Street Name First Name  \
# 0                     NaN                    NaN        NaN
# 1                     NaN                    NaN        NaN
# 2                     NaN                    NaN        NaN
# 3                     NaN                    NaN        NaN
# 4                     NaN                    NaN        NaN
#
#            Full Address Full Name             H Address  ...  \
# 0              39 Pearl       NaN              39 PEARL  ...
# 1  170 Clinton Brooklyn       NaN  170 CLINTON BROOKLYN  ...
# 2        601 Washington       NaN        601 WASHINGTON  ...
# 3            328 Bowery       NaN            328 BOWERY  ...
# 4             42 Orange       NaN             42 ORANGE  ...
#
#   h house number modifier  new address2 house number new address2 street name  \
# 0                     NaN                        NaN                      NaN
# 1                     NaN                        NaN                      NaN
# 2                     NaN                        NaN                      NaN
# 3                     NaN                        NaN                      NaN
# 4                     NaN                        NaN                      NaN
#
#   new address2 street 1 new address2 street 2 new address2 street type  \
# 0                   NaN                   NaN                      NaN
# 1                   NaN                   NaN                      NaN
# 2                   NaN                   NaN                      NaN
# 3                   NaN                   NaN                      NaN
# 4                   NaN                   NaN                      NaN
#
#   new address2 city  new address2 county  unidentified address2 info  \
# 0               NaN                  NaN                         NaN
# 1               NaN                  NaN                         NaN
# 2               NaN                  NaN                         NaN
# 3               NaN                  NaN                         NaN
# 4               NaN                  NaN                         NaN
#
#    address2 house number modifier
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
#
# [5 rows x 39 columns]

# %%
#with open('/Users/prajwal/Desktop/Columbia/C4SR/' + mn_or_bk + '_' + year + '/' + doubttype + '-' + mn_or_bk + year + '-v7.pkl', 'rb') as f:
  #d = pickle.load(f)
with open('/Users/prajwal/Desktop/Columbia/C4SR/tesseract lib/mn 1850/data/mn-1850-3.pkl', 'rb') as f:
    d = pickle.load(f)

# %%
#df1_original = pd.read_excel(mn_or_bk + '_' + year + '/' + doubttype + '-' + mn_or_bk + year + '-v7.xlsx')



df1_original = pd.read_excel('/Users/prajwal/Desktop/Columbia/C4SR/tesseract lib/mn 1850/data/mn-1850-2.xlsx')

# %%
len(df1)-len(df1_original)
# Out:
# 0

# %%
#df1_final_1 = df1_original.loc[df1_original['filter11']==0][['n_street1','n_street2','c_street1','c_street2']]
df1_final_1 = df1_original[['n_street1','n_street2','c_street1','c_street2']]

# %%
len(df1_final_1)
# Out:
# 80569

# %%
#df1_original

# %%
#df1_final_1

# %%
#df1

# %%
df1.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'Address 2', 'Address 2 City',
#        'Address 2 House Number', 'Address 2 Street Name', 'First Name',
#        'Full Address', 'Full Name', 'H Address', 'H City', 'H House Number',
#        'H Status-flag', 'H Street Name', 'Last Name', 'Middle Name',
#        'Occupation', 'Title', 'Widow Of', 'Widow-flag', 'new h address-flag',
#        'new h house number', 'new h street name', 'new h street 1',
#        'new h street 2', 'new h street type', 'new h city', 'new h county',
#        'unidentified h info', 'h house number modifier',
#        'new address2 house number', 'new address2 street name',
#        'new address2 street 1', 'new address2 street 2',
#        'new address2 street type', 'new address2 city', 'new address2 county',
#        'unidentified address2 info', 'address2 house number modifier'],
#       dtype='object')

# %%
df1_final_1['Full Address'] = df1['Full Address']



df1_final_1['H Address'] = df1['H Address']




df1_final_1['H House Number'] = df1['H House Number']
df1_final_1['H Street Name'] = df1['H Street Name']
#df1_final_1['new h house number'] = df1['new h house number']
#df1_final_1['new h street name'] = df1['new h street name']
#df1_final_1['new h city'] = df1['new h city']



df1_final_1['H City'] = df1['H City']
df1_final_1['Address 2'] = df1['Address 2']
df1_final_1['Address 2 House Number'] = df1['Address 2 House Number']
df1_final_1['Address 2 Street Name'] = df1['Address 2 Street Name']
df1_final_1['Address 2 City'] = df1['Address 2 City']



#df1_final_1['unidentified h info'] = df1['unidentified h info']
# Out:
# /Users/prajwal/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /Users/prajwal/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /Users/prajwal/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# /Users/prajwal/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# /Users/prajwal/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/prajwal/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/prajwal/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/prajwal/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/prajwal/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df1_final_1
# Out:
#       n_street1 n_street2 c_street1 c_street2          Full Address  \
# 0           NaN       NaN       NaN       NaN              39 Pearl
# 1           NaN       NaN       NaN       NaN  170 Clinton Brooklyn
# 2           NaN       NaN       NaN       NaN        601 Washington
# 3           NaN       NaN       NaN       NaN            328 Bowery
# 4           NaN       NaN       NaN       NaN             42 Orange
# 5           NaN       NaN       NaN       NaN             77 Barrow
# 6           NaN       NaN       NaN       NaN             586 E 4th
# 7           NaN       NaN       NaN       NaN               34 Av C
# 8           NaN       NaN       NaN       NaN               34 Av C
# 9           NaN       NaN       NaN       NaN               40 Av C
# 10          NaN       NaN       NaN       NaN             175 Canal
# 11          NaN       NaN       NaN       NaN           137 Norfolk
# 12          NaN       NaN       NaN       NaN               53 Av D
# 13          NaN       NaN       NaN       NaN              5 Ludlow
# 14          NaN       NaN       NaN       NaN                1 Av D
# 15          NaN       NaN       NaN       NaN            Morrisania
# 16          NaN       NaN       NaN       NaN              7 Murray
# 17          NaN       NaN       NaN       NaN            192 Fulton
# 18          NaN       NaN       NaN       NaN     91 Henry Brooklyn
# 19          NaN       NaN       NaN       NaN          181 inventor
# 20          NaN       NaN       NaN       NaN               79 Av B
# 21          NaN       NaN       NaN       NaN             66 Mangin
# 22          NaN       NaN       NaN       NaN             304 Ninth
# 23       E 18th      Av A       NaN       NaN         E 18th n Av A
# 24          NaN       NaN       NaN       NaN            605 Fourth
# 25          NaN       NaN      24th      Av 3           24th c Av 3
# 26          NaN       NaN       NaN       NaN          294 Eleventh
# 27          NaN       NaN       NaN       NaN               60 Av C
# 28          NaN       NaN       NaN       NaN              Brooklyn
# 29          NaN       NaN       NaN       NaN              22 Vesey
# ...         ...       ...       ...       ...                   ...
# 80539       NaN       NaN       NaN       NaN            Montgomery
# 80540       NaN       NaN       NaN       NaN                   NaN
# 80541       NaN       NaN       NaN       NaN                Broome
# 80542       NaN       NaN       NaN       NaN                   25t
# 80543       NaN       NaN       NaN       NaN              Broadway
# 80544       NaN       NaN       NaN       NaN              Dominick
# 80545       NaN       NaN       NaN       NaN                  Av 1
# 80546       NaN       NaN       NaN       NaN          Williamsburg
# 80547       NaN       NaN       NaN       NaN                   NaN
# 80548       NaN       NaN       NaN       NaN           4 Depau row
# 80549       NaN       NaN       NaN       NaN                   DEG
# 80550       NaN       NaN       NaN       NaN           69 Union pl
# 80551       NaN       NaN       NaN       NaN                   DEL
# 80552       NaN       NaN       NaN       NaN        6 St Mark s pl
# 80553       NaN       NaN       NaN       NaN                   NaN
# 80554       NaN       NaN       NaN       NaN                   NaN
# 80555       NaN       NaN       NaN       NaN                 rsley
# 80556       NaN       NaN       NaN       NaN                   NaN
# 80557       NaN       NaN       NaN       NaN                   NaN
# 80558       NaN       NaN       NaN       NaN              Brooklyn
# 80559       NaN       NaN       NaN       NaN          and 250 Av 4
# 80560       NaN       NaN       NaN       NaN           25 Broadway
# 80561      Bway      W 28       NaN       NaN           Bway n W 28
# 80562       NaN       NaN       NaN       NaN          Washington a
# 80563       NaN       NaN       NaN       NaN         Washington pl
# 80564       NaN       NaN       NaN       NaN             liamsburg
# 80565       NaN       NaN       NaN       NaN                   Wil
# 80566       NaN       NaN       NaN       NaN                   DEM
# 80567       NaN       NaN       NaN       NaN                   DEN
# 80568      34th      Av 9       NaN       NaN           34th n Av 9
#
#                   H Address  H House Number H Street Name         H City  \
# 0                  39 PEARL            39.0         PEARL            NaN
# 1      170 CLINTON BROOKLYN           170.0       CLINTON       BROOKLYN
# 2            601 WASHINGTON           601.0    WASHINGTON            NaN
# 3                328 BOWERY           328.0        BOWERY            NaN
# 4                 42 ORANGE            42.0        ORANGE            NaN
# 5                 77 BARROW            77.0        BARROW            NaN
# 6                 586 E 4TH           586.0         E 4TH            NaN
# 7                   34 AV C            34.0          AV C            NaN
# 8                   34 AV C            34.0          AV C            NaN
# 9                   40 AV C            40.0          AV C            NaN
# 10                175 CANAL           175.0         CANAL            NaN
# 11              137 NORFOLK           137.0       NORFOLK            NaN
# 12                  53 AV D            53.0          AV D            NaN
# 13                 5 LUDLOW             5.0        LUDLOW            NaN
# 14                   1 AV D             1.0          AV D            NaN
# 15               MORRISANIA             NaN           NaN            NaN
# 16                 7 MURRAY             7.0        MURRAY            NaN
# 17               192 FULTON           192.0        FULTON            NaN
# 18        91 HENRY BROOKLYN            91.0         HENRY       BROOKLYN
# 19             181 INVENTOR           181.0      INVENTOR            NaN
# 20                  79 AV B            79.0          AV B            NaN
# 21                66 MANGIN            66.0        MANGIN            NaN
# 22                  304 9TH           304.0         NINTH            NaN
# 23            E 18TH N AV A             NaN           NaN  E 18TH N AV A
# 24                  605 4TH           605.0        FOURTH            NaN
# 25              24TH C AV 3             NaN           NaN    24TH C AV 3
# 26                 294 11TH           294.0      ELEVENTH            NaN
# 27                  60 AV C            60.0          AV C            NaN
# 28                 BROOKLYN             NaN           NaN            NaN
# 29                 22 VESEY            22.0         VESEY            NaN
# ...                     ...             ...           ...            ...
# 80539            MONTGOMERY             NaN           NaN            NaN
# 80540                   NaN             NaN           NaN            NaN
# 80541                BROOME             NaN           NaN            NaN
# 80542                   25T             NaN           NaN            NaN
# 80543              BROADWAY             NaN           NaN            NaN
# 80544              DOMINICK             NaN           NaN            NaN
# 80545                  AV 1             1.0           NaN            NaN
# 80546          WILLIAMSBURG             NaN           NaN            NaN
# 80547                   NaN             NaN           NaN            NaN
# 80548           4 DEPAU ROW             4.0     DEPAU ROW            NaN
# 80549                   DEG             NaN           NaN            NaN
# 80550           69 UNION PL            69.0      UNION PL            NaN
# 80551                   DEL             NaN           NaN            NaN
# 80552        6 ST MARK S PL             6.0  ST MARK S PL            NaN
# 80553                   NaN             NaN           NaN            NaN
# 80554                   NaN             NaN           NaN            NaN
# 80555                 RSLEY             NaN           NaN            NaN
# 80556                   NaN             NaN           NaN            NaN
# 80557                   NaN             NaN           NaN            NaN
# 80558              BROOKLYN             NaN           NaN            NaN
# 80559          AND 250 AV 4           250.0          AV 4            NaN
# 80560           25 BROADWAY            25.0      BROADWAY            NaN
# 80561           BWAY N W 28             NaN           NaN    BWAY N W 28
# 80562          WASHINGTON A             NaN           NaN   WASHINGTON A
# 80563         WASHINGTON PL             NaN           NaN  WASHINGTON PL
# 80564             LIAMSBURG             NaN           NaN            NaN
# 80565                   WIL             NaN           NaN            NaN
# 80566                   DEM             NaN           NaN            NaN
# 80567                   DEN             NaN           NaN            NaN
# 80568           34TH N AV 9             NaN           NaN    34TH N AV 9
#
#        Address 2  Address 2 House Number  Address 2 Street Name  \
# 0            NaN                     NaN                    NaN
# 1            NaN                     NaN                    NaN
# 2            NaN                     NaN                    NaN
# 3            NaN                     NaN                    NaN
# 4            NaN                     NaN                    NaN
# 5            NaN                     NaN                    NaN
# 6            NaN                     NaN                    NaN
# 7            NaN                     NaN                    NaN
# 8            NaN                     NaN                    NaN
# 9            NaN                     NaN                    NaN
# 10           NaN                     NaN                    NaN
# 11           NaN                     NaN                    NaN
# 12           NaN                     NaN                    NaN
# 13           NaN                     NaN                    NaN
# 14           NaN                     NaN                    NaN
# 15           NaN                     NaN                    NaN
# 16           NaN                     NaN                    NaN
# 17           NaN                     NaN                    NaN
# 18           NaN                     NaN                    NaN
# 19           NaN                     NaN                    NaN
# 20           NaN                     NaN                    NaN
# 21           NaN                     NaN                    NaN
# 22           NaN                     NaN                    NaN
# 23           NaN                     NaN                    NaN
# 24           NaN                     NaN                    NaN
# 25           NaN                     NaN                    NaN
# 26           NaN                     NaN                    NaN
# 27           NaN                     NaN                    NaN
# 28           NaN                     NaN                    NaN
# 29           NaN                     NaN                    NaN
# ...          ...                     ...                    ...
# 80539        NaN                     NaN                    NaN
# 80540        NaN                     NaN                    NaN
# 80541        NaN                     NaN                    NaN
# 80542        NaN                     NaN                    NaN
# 80543        NaN                     NaN                    NaN
# 80544        NaN                     NaN                    NaN
# 80545        NaN                     NaN                    NaN
# 80546        NaN                     NaN                    NaN
# 80547        NaN                     NaN                    NaN
# 80548        NaN                     NaN                    NaN
# 80549        NaN                     NaN                    NaN
# 80550        NaN                     NaN                    NaN
# 80551        NaN                     NaN                    NaN
# 80552        NaN                     NaN                    NaN
# 80553        NaN                     NaN                    NaN
# 80554        NaN                     NaN                    NaN
# 80555        NaN                     NaN                    NaN
# 80556        NaN                     NaN                    NaN
# 80557        NaN                     NaN                    NaN
# 80558        NaN                     NaN                    NaN
# 80559        NaN                     NaN                    NaN
# 80560        NaN                     NaN                    NaN
# 80561        NaN                     NaN                    NaN
# 80562        NaN                     NaN                    NaN
# 80563        NaN                     NaN                    NaN
# 80564        NaN                     NaN                    NaN
# 80565        NaN                     NaN                    NaN
# 80566        NaN                     NaN                    NaN
# 80567        NaN                     NaN                    NaN
# 80568        NaN                     NaN                    NaN
#
#        Address 2 City
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5                 NaN
# 6                 NaN
# 7                 NaN
# 8                 NaN
# 9                 NaN
# 10                NaN
# 11                NaN
# 12                NaN
# 13                NaN
# 14                NaN
# 15                NaN
# 16                NaN
# 17                NaN
# 18                NaN
# 19                NaN
# 20                NaN
# 21                NaN
# 22                NaN
# 23                NaN
# 24                NaN
# 25                NaN
# 26                NaN
# 27                NaN
# 28                NaN
# 29                NaN
# ...               ...
# 80539             NaN
# 80540             NaN
# 80541             NaN
# 80542             NaN
# 80543             NaN
# 80544             NaN
# 80545             NaN
# 80546             NaN
# 80547             NaN
# 80548             NaN
# 80549             NaN
# 80550             NaN
# 80551             NaN
# 80552             NaN
# 80553             NaN
# 80554             NaN
# 80555             NaN
# 80556             NaN
# 80557             NaN
# 80558             NaN
# 80559             NaN
# 80560             NaN
# 80561             NaN
# 80562             NaN
# 80563             NaN
# 80564             NaN
# 80565             NaN
# 80566             NaN
# 80567             NaN
# 80568             NaN
#
# [80569 rows x 13 columns]

# %%
#df1_original[['Full Address','H House Number','H Street Name','new h house number','new h street name','new h city']]
#df1[['unidentified h info']]

# %%
df1_final_1.columns
# Out:
# Index(['n_street1', 'n_street2', 'c_street1', 'c_street2', 'Full Address',
#        'H Address', 'H House Number', 'H Street Name', 'H City', 'Address 2',
#        'Address 2 House Number', 'Address 2 Street Name', 'Address 2 City'],
#       dtype='object')

# %%
#df1_final_1.to_csv(mn_or_bk + '_' + year + '/' + mn_or_bk + '_' + year + '_combine-' + doubttype + '4.csv')
df1_final_1.to_csv('/Users/prajwal/Desktop/Columbia/C4SR/tesseract lib/mn 1850/data/mn-1850-3-s-combine.csv')

# %% [markdown]
# ## Column descriptions:
#
# #### Full Address
# contains the cleaned entry for the address from the input file
# #### H House Number
# contains the house number if present in Full Address
# #### H Street Name
# contains the street name if present in Full Address
# #### c_street1
# contains the first street name in case the address was located at a corner
# #### c_street2
# contains the second street name in case the address was located at a corner
# #### n_street1
# contains the first street name in case the address was located near another street
# #### n_street2
# contains the second street name in case the address was located near another street
# #### new h city
# contains the city name (if present) in Full Address
# #### new h house number
# contains the house number if present in Full Address for some additional entries that are not in 'H House Number'
# #### new h street name
# contains the street name if present in Full Address for some additional entries that are not in 'H Street Name'
