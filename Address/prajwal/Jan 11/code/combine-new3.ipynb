# %%
import pandas as pd
#from fuzzywuzzy import fuzz
import pickle

# %%
#mn_or_bk = 'mn' #bk or mn
#year = str(1850) #1850, 1880
#doubttype = 'doubt' #doubt or not so confident

# %%
#df1 = pd.read_csv(mn_or_bk + '_' + year + '/S/' + doubttype + '-' + mn_or_bk + year + '-v7-s.csv')
df1 = pd.read_csv('/Users/prajwal/Desktop/Columbia/C4SR/tesseract output/run1/mn-1880-3-s.csv')

# %%
df1.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1 Address 2 Address 2 City  Address 2 House Number  \
# 0           0             0       NaN            NaN                     NaN
# 1           1             1       NaN            NaN                     NaN
# 2           2             2       NaN            NaN                     NaN
# 3           3             3       NaN            NaN                     NaN
# 4           4             4       NaN            NaN                     NaN
#
#   Address 2 Street Name First Name   Full Address   Full Name      H Address  \
# 0                   NaN        NaN  h 11 Eldridge         NaN  H 11 ELDRIDGE
# 1                   NaN    William     h. 66 Ft .  97 William     H. 66 FT .
# 2                   NaN        NaN       Bâ€™klyn         NaN       BÂ€™KLYN
# 3                   NaN        NaN    184 Forsyth         NaN    184 FORSYTH
# 4                   NaN        NaN    60 Eldridge         NaN    60 ELDRIDGE
#
#    ... h house number modifier  new address2 house number  \
# 0  ...                     NaN                        NaN
# 1  ...                     NaN                        NaN
# 2  ...                     NaN                        NaN
# 3  ...                     NaN                        NaN
# 4  ...                     NaN                        NaN
#
#   new address2 street name new address2 street 1 new address2 street 2  \
# 0                      NaN                   NaN                   NaN
# 1                      NaN                   NaN                   NaN
# 2                      NaN                   NaN                   NaN
# 3                      NaN                   NaN                   NaN
# 4                      NaN                   NaN                   NaN
#
#   new address2 street type new address2 city  new address2 county  \
# 0                      NaN               NaN                  NaN
# 1                      NaN               NaN                  NaN
# 2                      NaN               NaN                  NaN
# 3                      NaN               NaN                  NaN
# 4                      NaN               NaN                  NaN
#
#   unidentified address2 info address2 house number modifier
# 0                        NaN                            NaN
# 1                        NaN                            NaN
# 2                        NaN                            NaN
# 3                        NaN                            NaN
# 4                        NaN                            NaN
#
# [5 rows x 39 columns]

# %%
#with open('/Users/prajwal/Desktop/Columbia/C4SR/' + mn_or_bk + '_' + year + '/' + doubttype + '-' + mn_or_bk + year + '-v7.pkl', 'rb') as f:
  #d = pickle.load(f)
with open('/Users/prajwal/Desktop/Columbia/C4SR/tesseract output/run1/mn-1880-3.pkl', 'rb') as f:
    d = pickle.load(f)

# %%
#df1_original = pd.read_excel(mn_or_bk + '_' + year + '/' + doubttype + '-' + mn_or_bk + year + '-v7.xlsx')



df1_original = pd.read_excel('/Users/prajwal/Desktop/Columbia/C4SR/tesseract output/run1/mn-1880-2.xlsx')

# %%
len(df1)-len(df1_original)
# Out:
# 0

# %%
#df1_final_1 = df1_original.loc[df1_original['filter11']==0][['n_street1','n_street2','c_street1','c_street2']]
df1_final_1 = df1_original[['n_street1','n_street2','c_street1','c_street2']]

# %%
len(df1_final_1)
# Out:
# 289991

# %%
#df1_original

# %%
#df1_final_1

# %%
#df1

# %%
df1.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'Address 2', 'Address 2 City',
#        'Address 2 House Number', 'Address 2 Street Name', 'First Name',
#        'Full Address', 'Full Name', 'H Address', 'H City', 'H House Number',
#        'H Status-flag', 'H Street Name', 'Last Name', 'Middle Name',
#        'Occupation', 'Title', 'Widow Of', 'Widow-flag', 'new h address-flag',
#        'new h house number', 'new h street name', 'new h street 1',
#        'new h street 2', 'new h street type', 'new h city', 'new h county',
#        'unidentified h info', 'h house number modifier',
#        'new address2 house number', 'new address2 street name',
#        'new address2 street 1', 'new address2 street 2',
#        'new address2 street type', 'new address2 city', 'new address2 county',
#        'unidentified address2 info', 'address2 house number modifier'],
#       dtype='object')

# %%
df1_final_1['Full Address'] = df1['Full Address']



df1_final_1['H Address'] = df1['H Address']




df1_final_1['H House Number'] = df1['H House Number']
df1_final_1['H Street Name'] = df1['H Street Name']
#df1_final_1['new h house number'] = df1['new h house number']
#df1_final_1['new h street name'] = df1['new h street name']
#df1_final_1['new h city'] = df1['new h city']



df1_final_1['H City'] = df1['H City']
df1_final_1['Address 2'] = df1['Address 2']
df1_final_1['Address 2 House Number'] = df1['Address 2 House Number']
df1_final_1['Address 2 Street Name'] = df1['Address 2 Street Name']
df1_final_1['Address 2 City'] = df1['Address 2 City']



#df1_final_1['unidentified h info'] = df1['unidentified h info']
# Out:
# /Users/prajwal/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /Users/prajwal/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /Users/prajwal/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# /Users/prajwal/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# /Users/prajwal/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/prajwal/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/prajwal/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/prajwal/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/prajwal/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df1_final_1
# Out:
#        n_street1 n_street2 c_street1 c_street2  \
# 0            NaN       NaN       NaN       NaN
# 1            NaN       NaN       NaN       NaN
# 2            NaN       NaN       NaN       NaN
# 3            NaN       NaN       NaN       NaN
# 4            NaN       NaN       NaN       NaN
# 5            NaN       NaN       NaN       NaN
# 6            NaN       NaN       NaN       NaN
# 7            NaN       NaN       NaN       NaN
# 8            NaN       NaN       NaN       NaN
# 9            NaN       NaN       NaN       NaN
# 10           NaN       NaN       NaN       NaN
# 11           NaN       NaN       NaN       NaN
# 12           NaN       NaN       NaN       NaN
# 13           NaN       NaN       NaN       NaN
# 14           NaN       NaN       NaN       NaN
# 15           NaN       NaN       NaN       NaN
# 16           NaN       NaN       NaN       NaN
# 17           NaN       NaN       NaN       NaN
# 18           NaN       NaN       NaN       NaN
# 19           NaN       NaN       NaN       NaN
# 20           NaN       NaN       NaN       NaN
# 21           NaN       NaN       NaN       NaN
# 22           NaN       NaN       NaN       NaN
# 23           NaN       NaN       NaN       NaN
# 24           NaN       NaN       NaN       NaN
# 25           NaN       NaN       NaN       NaN
# 26           NaN       NaN       NaN       NaN
# 27           NaN       NaN       NaN       NaN
# 28           NaN       NaN       NaN       NaN
# 29           NaN       NaN       NaN       NaN
# ...          ...       ...       ...       ...
# 289961       NaN       NaN       NaN       NaN
# 289962       NaN       NaN       NaN       NaN
# 289963       NaN       NaN       NaN       NaN
# 289964       NaN       NaN       NaN       NaN
# 289965       NaN       NaN       NaN       NaN
# 289966       NaN       NaN       NaN       NaN
# 289967       NaN       NaN       NaN       NaN
# 289968       NaN       NaN       NaN       NaN
# 289969       NaN       NaN       NaN       NaN
# 289970       NaN       NaN       NaN       NaN
# 289971       NaN       NaN       NaN       NaN
# 289972       NaN       NaN       NaN       NaN
# 289973       NaN       NaN       NaN       NaN
# 289974       NaN       NaN       NaN       NaN
# 289975       NaN       NaN       NaN       NaN
# 289976       NaN       NaN       NaN       NaN
# 289977       NaN       NaN       NaN       NaN
# 289978       NaN       NaN       NaN       NaN
# 289979       NaN       NaN       NaN       NaN
# 289980       NaN       NaN       NaN       NaN
# 289981       NaN       NaN       NaN       NaN
# 289982       NaN       NaN       NaN       NaN
# 289983       NaN       NaN       NaN       NaN
# 289984       NaN       NaN       NaN       NaN
# 289985       NaN       NaN       NaN       NaN
# 289986       NaN       NaN       NaN       NaN
# 289987       NaN       NaN       NaN       NaN
# 289988       NaN       NaN       NaN       NaN
# 289989       NaN       NaN       NaN       NaN
# 289990       NaN       NaN       NaN       NaN
#
#                                    Full Address  \
# 0                                 h 11 Eldridge
# 1                                    h. 66 Ft .
# 2                                      Bâ€™klyn
# 3                                   184 Forsyth
# 4                                   60 Eldridge
# 5                                h 214 E . 13th
# 6                                h. 70 W . 48th
# 7                                h 171 Attorney
# 8                                     197 Grand
# 9                                 h. 109 Hester
# 10                             h 352 Third av .
# 11                               h 121 Columbia
# 12                108 Vesey,h. 200 E  , Houston
# 13                            h. 352 Third av .
# 14                               h 108 Chrystie
# 15                               h 208 E . 49th
# 16                                  811 E . 43d
# 17                                h 132 Orchard
# 18                                   hS2 Av . B
# 19                                h 59 Attorney
# 20                             h 139 Third av .
# 21                              h 311 EB  , 43a
# 22                                 h 363 Eighth
# 23             801 Eighth av.,h. %9 Eighth av .
# 24                                h 305 E . 73d
# 25                              h. 305 E  , 73d
# 26                                 238 Bleecker
# 27                                 h 64 Willett
# 28                                    53 Walker
# 29                                    45 Walker
# ...                                         ...
# 289961               190 South,h 127 Second av.
# 289962                        h rear 446 W 41st
# 289963                    190 South & 365 Water
# 289964  94 Grand,h 117 Schermerhorn  , B‚Äôklyn
# 289965                            779 Tenth av.
# 289966                           2190 Third av.
# 289967                            28 S. William
# 289968                          h 202 E Houston
# 289969                               h 22 E 43d
# 289970               514 First av. h 308 E 74th
# 289971              2 City Hall,h 960 Sixth av.
# 289972                              h 229 E 82d
# 289973                             h 337 E 80th
# 289974               161 E Houston,h 33 Seventh
# 289975                     28 Cliff,h 10 W 38th
# 289976                            h 11 Eldridge
# 289977                            h 132 Orchard
# 289978                             h 363 Eighth
# 289979                            h 128 Orchard
# 289980                             h 246 E 44th
# 289981                              h 139 W 22d
# 289982                               h 32E 20th
# 289983               282 Fourth av. h 32 E 20th
# 289984                              h 32 E 20th
# 289985                                 h 19 Jay
# 289986                  128 B‚Äôway,h 52 W 24th
# 289987                                331 Pearl
# 289988                                  94 Wall
# 289989               r 84 R,idge,h 252 Delancey
# 289990                              189 B‚Äôway
#
#                                       H Address  H House Number  \
# 0                                 H 11 ELDRIDGE            11.0
# 1                                    H. 66 FT .            66.0
# 2                                      BÂ€™KLYN             NaN
# 3                                   184 FORSYTH           184.0
# 4                                   60 ELDRIDGE            60.0
# 5                                H 214 E . 13TH           214.0
# 6                                H. 70 W . 48TH            70.0
# 7                                H 171 ATTORNEY           171.0
# 8                                     197 GRAND           197.0
# 9                                 H. 109 HESTER           109.0
# 10                               H 352 3RD AV .           352.0
# 11                               H 121 COLUMBIA           121.0
# 12                          H. 200 E  , HOUSTON           200.0
# 13                              H. 352 3RD AV .           352.0
# 14                               H 108 CHRYSTIE           108.0
# 15                               H 208 E . 49TH           208.0
# 16                                  811 E . 43D           811.0
# 17                                H 132 ORCHARD           132.0
# 18                                   HS2 AV . B             NaN
# 19                                H 59 ATTORNEY            59.0
# 20                               H 139 3RD AV .           139.0
# 21                              H 311 EB  , 43A           311.0
# 22                                    H 363 8TH           363.0
# 23                               H. %9 8TH AV .             NaN
# 24                                H 305 E . 73D           305.0
# 25                              H. 305 E  , 73D           305.0
# 26                                 238 BLEECKER           238.0
# 27                                 H 64 WILLETT            64.0
# 28                                    53 WALKER            53.0
# 29                                    45 WALKER            45.0
# ...                                         ...             ...
# 289961                  190 SOUTH,H 127 2ND AV.           190.0
# 289962                        H REAR 446 W 41ST           446.0
# 289963                    190 SOUTH & 365 WATER           190.0
# 289964  94 GRAND,H 117 SCHERMERHORN  , B‚ÄÔKLYN            94.0
# 289965                             779 10TH AV.           779.0
# 289966                             2190 3RD AV.          2190.0
# 289967                            28 S. WILLIAM            28.0
# 289968                          H 202 E HOUSTON           202.0
# 289969                               H 22 E 43D            22.0
# 289970                 514 1ST AV. H 308 E 74TH           514.0
# 289971                2 CITY HALL,H 960 6TH AV.             2.0
# 289972                              H 229 E 82D           229.0
# 289973                             H 337 E 80TH           337.0
# 289974                   161 E HOUSTON,H 33 7TH           161.0
# 289975                     28 CLIFF,H 10 W 38TH            28.0
# 289976                            H 11 ELDRIDGE            11.0
# 289977                            H 132 ORCHARD           132.0
# 289978                                H 363 8TH           363.0
# 289979                            H 128 ORCHARD           128.0
# 289980                             H 246 E 44TH           246.0
# 289981                              H 139 W 22D           139.0
# 289982                               H 32E 20TH             NaN
# 289983                  282 4TH AV. H 32 E 20TH           282.0
# 289984                              H 32 E 20TH            32.0
# 289985                                 H 19 JAY            19.0
# 289986                  128 B‚ÄÔWAY,H 52 W 24TH           128.0
# 289987                                331 PEARL           331.0
# 289988                                  94 WALL            94.0
# 289989               R 84 R,IDGE,H 252 DELANCEY            84.0
# 289990                              189 B‚ÄÔWAY           189.0
#
#                      H Street Name          H City       Address 2  \
# 0                         ELDRIDGE             NaN             NaN
# 1                             FT .             NaN             NaN
# 2                              NaN             NaN             NaN
# 3                          FORSYTH             NaN             NaN
# 4                         ELDRIDGE             NaN             NaN
# 5                         E . 13TH             NaN             NaN
# 6                         W . 48TH             NaN             NaN
# 7                         ATTORNEY             NaN             NaN
# 8                            GRAND             NaN             NaN
# 9                           HESTER             NaN             NaN
# 10                      THIRD AV .             NaN             NaN
# 11                        COLUMBIA             NaN             NaN
# 12                     E , HOUSTON             NaN       108 Vesey
# 13                      THIRD AV .             NaN             NaN
# 14                        CHRYSTIE             NaN             NaN
# 15                        E . 49TH             NaN             NaN
# 16                         E . 43D             NaN             NaN
# 17                         ORCHARD             NaN             NaN
# 18                             NaN      HS2 AV . B             NaN
# 19                        ATTORNEY             NaN             NaN
# 20                      THIRD AV .             NaN             NaN
# 21                        EB , 43A             NaN             NaN
# 22                          EIGHTH             NaN             NaN
# 23                             NaN  %9 EIGHTH AV .  801 Eighth av.
# 24                         E . 73D             NaN             NaN
# 25                         E , 73D             NaN             NaN
# 26                        BLEECKER             NaN             NaN
# 27                         WILLETT             NaN             NaN
# 28                          WALKER             NaN             NaN
# 29                          WALKER             NaN             NaN
# ...                            ...             ...             ...
# 289961      SOUTH,H 127 SECOND AV.             NaN             NaN
# 289962                      W 41ST             NaN             NaN
# 289963           SOUTH & 365 WATER             NaN             NaN
# 289964  GRAND,H 117 SCHERMERHORN ,        B‚ÄÔKLYN             NaN
# 289965                   TENTH AV.             NaN             NaN
# 289966                   THIRD AV.             NaN             NaN
# 289967                  S. WILLIAM             NaN             NaN
# 289968                   E HOUSTON             NaN             NaN
# 289969                       E 43D             NaN             NaN
# 289970      FIRST AV. H 308 E 74TH             NaN             NaN
# 289971   CITY HALL,H 960 SIXTH AV.             NaN             NaN
# 289972                       E 82D             NaN             NaN
# 289973                      E 80TH             NaN             NaN
# 289974      E HOUSTON,H 33 SEVENTH             NaN             NaN
# 289975           CLIFF,H 10 W 38TH             NaN             NaN
# 289976                    ELDRIDGE             NaN             NaN
# 289977                     ORCHARD             NaN             NaN
# 289978                      EIGHTH             NaN             NaN
# 289979                     ORCHARD             NaN             NaN
# 289980                      E 44TH             NaN             NaN
# 289981                       W 22D             NaN             NaN
# 289982                         NaN        32E 20TH             NaN
# 289983      FOURTH AV. H 32 E 20TH             NaN             NaN
# 289984                      E 20TH             NaN             NaN
# 289985                         JAY             NaN             NaN
# 289986         B‚ÄÔWAY,H 52 W 24TH             NaN             NaN
# 289987                       PEARL             NaN             NaN
# 289988                        WALL             NaN             NaN
# 289989       R,IDGE,H 252 DELANCEY             NaN             NaN
# 289990                     B‚ÄÔWAY             NaN             NaN
#
#         Address 2 House Number Address 2 Street Name Address 2 City
# 0                          NaN                   NaN            NaN
# 1                          NaN                   NaN            NaN
# 2                          NaN                   NaN            NaN
# 3                          NaN                   NaN            NaN
# 4                          NaN                   NaN            NaN
# 5                          NaN                   NaN            NaN
# 6                          NaN                   NaN            NaN
# 7                          NaN                   NaN            NaN
# 8                          NaN                   NaN            NaN
# 9                          NaN                   NaN            NaN
# 10                         NaN                   NaN            NaN
# 11                         NaN                   NaN            NaN
# 12                       108.0                 Vesey            NaN
# 13                         NaN                   NaN            NaN
# 14                         NaN                   NaN            NaN
# 15                         NaN                   NaN            NaN
# 16                         NaN                   NaN            NaN
# 17                         NaN                   NaN            NaN
# 18                         NaN                   NaN            NaN
# 19                         NaN                   NaN            NaN
# 20                         NaN                   NaN            NaN
# 21                         NaN                   NaN            NaN
# 22                         NaN                   NaN            NaN
# 23                       801.0            Eighth av.            NaN
# 24                         NaN                   NaN            NaN
# 25                         NaN                   NaN            NaN
# 26                         NaN                   NaN            NaN
# 27                         NaN                   NaN            NaN
# 28                         NaN                   NaN            NaN
# 29                         NaN                   NaN            NaN
# ...                        ...                   ...            ...
# 289961                     NaN                   NaN            NaN
# 289962                     NaN                   NaN            NaN
# 289963                     NaN                   NaN            NaN
# 289964                     NaN                   NaN            NaN
# 289965                     NaN                   NaN            NaN
# 289966                     NaN                   NaN            NaN
# 289967                     NaN                   NaN            NaN
# 289968                     NaN                   NaN            NaN
# 289969                     NaN                   NaN            NaN
# 289970                     NaN                   NaN            NaN
# 289971                     NaN                   NaN            NaN
# 289972                     NaN                   NaN            NaN
# 289973                     NaN                   NaN            NaN
# 289974                     NaN                   NaN            NaN
# 289975                     NaN                   NaN            NaN
# 289976                     NaN                   NaN            NaN
# 289977                     NaN                   NaN            NaN
# 289978                     NaN                   NaN            NaN
# 289979                     NaN                   NaN            NaN
# 289980                     NaN                   NaN            NaN
# 289981                     NaN                   NaN            NaN
# 289982                     NaN                   NaN            NaN
# 289983                     NaN                   NaN            NaN
# 289984                     NaN                   NaN            NaN
# 289985                     NaN                   NaN            NaN
# 289986                     NaN                   NaN            NaN
# 289987                     NaN                   NaN            NaN
# 289988                     NaN                   NaN            NaN
# 289989                     NaN                   NaN            NaN
# 289990                     NaN                   NaN            NaN
#
# [289991 rows x 13 columns]

# %%
#df1_original[['Full Address','H House Number','H Street Name','new h house number','new h street name','new h city']]
#df1[['unidentified h info']]

# %%
df1_final_1.columns
# Out:
# Index(['n_street1', 'n_street2', 'c_street1', 'c_street2', 'Full Address',
#        'H Address', 'H House Number', 'H Street Name', 'H City', 'Address 2',
#        'Address 2 House Number', 'Address 2 Street Name', 'Address 2 City'],
#       dtype='object')

# %%
#df1_final_1.to_csv(mn_or_bk + '_' + year + '/' + mn_or_bk + '_' + year + '_combine-' + doubttype + '4.csv')
df1_final_1.to_csv('/Users/prajwal/Desktop/Columbia/C4SR/tesseract output/run1/mn-1880-3-s-combine.csv')

# %% [markdown]
# ## Column descriptions:
#
# #### Full Address
# contains the cleaned entry for the address from the input file
# #### H House Number
# contains the house number if present in Full Address
# #### H Street Name
# contains the street name if present in Full Address
# #### c_street1
# contains the first street name in case the address was located at a corner
# #### c_street2
# contains the second street name in case the address was located at a corner
# #### n_street1
# contains the first street name in case the address was located near another street
# #### n_street2
# contains the second street name in case the address was located near another street
# #### new h city
# contains the city name (if present) in Full Address
# #### new h house number
# contains the house number if present in Full Address for some additional entries that are not in 'H House Number'
# #### new h street name
# contains the street name if present in Full Address for some additional entries that are not in 'H Street Name'
