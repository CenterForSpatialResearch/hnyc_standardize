# %%
import pandas as pd
import numpy as np

# %%
#df = pd.read_excel('/Users/prajwal/Desktop/Columbia/C4SR/mn_1880/not so confident.xlsx')

# %%
df = pd.read_csv('/Users/prajwal/Desktop/Columbia/C4SR/tesseract output/MN_1880_final_output_tesseract.csv')
# Out:
# /Users/prajwal/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (20) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#df_slice1 = df.loc[df['filter1']==1]

# %%
df_slice1 = df

# %%
try:
    df_slice1 = df_slice1.rename({'clean address': 'clean_address'}, axis=1)
except:
    pass
try:
    df = df.rename({'clean address': 'clean_address'}, axis=1)
except:
    pass

# %%
#slice1_addresses = list(dict(df_slice1['clean_address']).values()) #was initially uncommented



#slice1_addresses = list(dict(df_slice1['clean address']).values())

# %%
slice1_addresses = list(dict(df_slice1['Full Address']).values())

# %%
modified_clean_address = df['Full Address'].str.replace('Ã¢Â\x80Â\x99',"'").str.replace('Ã¢ÂÂ',"'").str.replace("Ã¢Â\x80Â\x98","").str.replace("Ã¢Â\x80Â\x9c","").str.replace("Ã¢Â\x80Â\x9d","")


"""


#modified_clean_address = df['clean_address'].str.replace('Ã¢Â\x80Â\x99',"'").str.replace('Ã¢ÂÂ',"'").str.replace("Ã¢Â\x80Â\x98","").str.replace("Ã¢Â\x80Â\x9c","").str.replace("Ã¢Â\x80Â\x9d","")
modified_clean_address = modified_clean_address.str.replace("hN", "h N")
print(modified_clean_address[0])
modified_clean_address = modified_clean_address.str.replace(".5 ", " ")
print(modified_clean_address[0])
modified_clean_address = modified_clean_address.str.replace(",h ", ", h ")
print(modified_clean_address[0])
modified_clean_address = modified_clean_address.str.replace(",h", ", h ")
print(modified_clean_address[0])
modified_clean_address = modified_clean_address.str.replace(", h.", ", h. ")
print(modified_clean_address[0])
modified_clean_address = modified_clean_address.str.replace(", h .", ", h. ")
print(modified_clean_address[0])
modified_clean_address = modified_clean_address.str.replace("H udson", "Hudson")
modified_clean_address = modified_clean_address.str.replace("'wav", "'way")
modified_clean_address = modified_clean_address.str.replace("B'way", "Broadway")
modified_clean_address = modified_clean_address.str.replace("B way", "Broadway")
modified_clean_address = modified_clean_address.str.replace("B'kly n", "B'klyn")
modified_clean_address = modified_clean_address.str.replace(",n", " n")
modified_clean_address = modified_clean_address.str.replace("W.h", " Wh")
modified_clean_address = modified_clean_address.str.replace("h-", " h ")
modified_clean_address = modified_clean_address.str.replace("h-", " h ")
modified_clean_address = modified_clean_address.str.replace("-h.", "h.")
#modified_clean_address = modified_clean_address.str.replace("H()", "h.")
#modified_clean_address = modified_clean_address.str.replace("*", " ")
#modified_clean_address = modified_clean_address.str.replace("h r.", "h r")

#modified_clean_address = modified_clean_address.str.replace(".h", ", h.")

#modified_clean_address = modified_clean_address.str.replace("^h", "  h")
#modified_clean_address = modified_clean_address.str.replace("h*", "  h ")

#modified_clean_address = modified_clean_address.str.replace(". .", " ")
"""
# Out:
# '\n\n\n#modified_clean_address = df[\'clean_address\'].str.replace(\'Ã¢Â\x80Â\x99\',"\'").str.replace(\'Ã¢Â\x80Â\x99\',"\'").str.replace("Ã¢Â\x80Â\x98","").str.replace("Ã¢Â\x80Â\x9c","").str.replace("Ã¢Â\x80Â\x9d","")\nmodified_clean_address = modified_clean_address.str.replace("hN", "h N")\nprint(modified_clean_address[0])\nmodified_clean_address = modified_clean_address.str.replace(".5 ", " ")\nprint(modified_clean_address[0])\nmodified_clean_address = modified_clean_address.str.replace(",h ", ", h ")\nprint(modified_clean_address[0])\nmodified_clean_address = modified_clean_address.str.replace(",h", ", h ")\nprint(modified_clean_address[0])\nmodified_clean_address = modified_clean_address.str.replace(", h.", ", h. ")\nprint(modified_clean_address[0])\nmodified_clean_address = modified_clean_address.str.replace(", h .", ", h. ")\nprint(modified_clean_address[0])\nmodified_clean_address = modified_clean_address.str.replace("H udson", "Hudson")\nmodified_clean_address = modified_clean_address.str.replace("\'wav", "\'way")\nmodified_clean_address = modified_clean_address.str.replace("B\'way", "Broadway")\nmodified_clean_address = modified_clean_address.str.replace("B way", "Broadway")\nmodified_clean_address = modified_clean_address.str.replace("B\'kly n", "B\'klyn")\nmodified_clean_address = modified_clean_address.str.replace(",n", " n")\nmodified_clean_address = modified_clean_address.str.replace("W.h", " Wh")\nmodified_clean_address = modified_clean_address.str.replace("h-", " h ")\nmodified_clean_address = modified_clean_address.str.replace("h-", " h ")\nmodified_clean_address = modified_clean_address.str.replace("-h.", "h.")\n#modified_clean_address = modified_clean_address.str.replace("H()", "h.")\n#modified_clean_address = modified_clean_address.str.replace("*", " ")\n#modified_clean_address = modified_clean_address.str.replace("h r.", "h r")\n\n#modified_clean_address = modified_clean_address.str.replace(".h", ", h.")\n\n#modified_clean_address = modified_clean_address.str.replace("^h", "  h")\n#modified_clean_address = modified_clean_address.str.replace("h*", "  h ")\n\n#modified_clean_address = modified_clean_address.str.replace(". .", " ")\n'

# %%
for i in range(0,len(modified_clean_address)):
    if str(modified_clean_address[i]) == 'nan':
        print(i, modified_clean_address[i])
        modified_clean_address[i] = ''
# Out:
# 98501 nan
# 102680 nan
# 105736 nan
# 110739 nan
# 111389 nan
# 111722 nan
# 111975 nan
# 113237 nan
# 113240 nan
# 113494 nan
# 117618 nan
# 117801 nan
# 118149 nan
# 122033 nan
# 124147 nan
# 124325 nan
# 125279 nan
# 126985 nan
# 127333 nan
# 128137 nan
# 130091 nan
# 131962 nan
# 132077 nan
# 133870 nan
# 134003 nan
# 136609 nan
# 140009 nan
# 140023 nan
# 140289 nan
# 141345 nan
# 142821 nan
# 147118 nan
# 148218 nan
# 149715 nan
# 152755 nan
# 162894 nan
# 163100 nan
# 163429 nan
# 165105 nan
# 166960 nan
# 167760 nan
# 170112 nan
# 171026 nan
# 171489 nan
# 172259 nan
# 172357 nan
# 176891 nan
# 177611 nan
# 177908 nan
# 178456 nan
# 178581 nan
# 178743 nan
# 180490 nan
# 180585 nan
# 180683 nan
# 181070 nan
# 182962 nan
# 189395 nan
# 193735 nan
# 195360 nan
# 201182 nan
# 205490 nan
# 210888 nan
# 217022 nan
# 218440 nan
# 220650 nan
# 222980 nan
# 226658 nan
# 230284 nan
# 233956 nan
# 245647 nan
# 246872 nan
# 247189 nan
# 249395 nan
# 250116 nan
# 251519 nan
# 255854 nan
# 258061 nan
# 259882 nan
# 260854 nan
# 263778 nan
# 264267 nan
# 264850 nan
# 265280 nan
# 268792 nan
# 269117 nan
# 269859 nan
# 270799 nan
# 271377 nan
# 271818 nan
# 273010 nan
# 273251 nan
# 273951 nan
# 274067 nan
# 274959 nan
# 274960 nan
# 274961 nan
# 274962 nan
# 274963 nan
# 274964 nan
# 274965 nan
# 274966 nan
# 274967 nan
# 274968 nan
# 274969 nan
# 274970 nan
# 275315 nan
# 275342 nan
# 276457 nan
# 276629 nan
# 276630 nan
# 276631 nan
# 277577 nan
# 278166 nan
# 278410 nan
# 278578 nan
# 278603 nan
# 278783 nan
# 280348 nan
# 281476 nan
# 281835 nan
# 281881 nan
# 282259 nan
# 282666 nan
# 282727 nan
# 286465 nan
# 286617 nan
# 287408 nan
# 287719 nan
# 287878 nan
# 287889 nan
# 289320 nan

# %%
for i in range(0,len(modified_clean_address)):
        if modified_clean_address[i].find("E.") >= 0:
            modified_clean_address[i] = modified_clean_address[i].replace('E.','E ').replace('  ', ' ')

# %%
for i in range(0,len(modified_clean_address)):
    if modified_clean_address[i].find("W.") >= 0:
        modified_clean_address[i] = modified_clean_address[i].replace('W.','W ').replace('  ', ' ')

# %%
for i in range(0,len(modified_clean_address)):
    if modified_clean_address[i].find(".h") >= 0:
        modified_clean_address[i] = modified_clean_address[i].replace('.h',', h. ').replace(',,',',').replace('  ',' ')

# %%
for i in range(0,len(modified_clean_address)):
    if modified_clean_address[i].find(",c") >= 0:
        modified_clean_address[i] = modified_clean_address[i].replace(',c',' c')

# %%
for i in range(0,len(modified_clean_address)):
    if modified_clean_address[i].find(" c. ") >= 0:
        modified_clean_address[i] = modified_clean_address[i].replace('c.','c')

# %%
for i in range(0,len(modified_clean_address)):
    if modified_clean_address[i].find(" n. ") >= 0:
        modified_clean_address[i] = modified_clean_address[i].replace(' n. ',' n ')

# %%
for i in range(0,len(modified_clean_address)):
    if modified_clean_address[i].find("h r ") >=0:
        modified_clean_address[i] = modified_clean_address[i].replace('h r','h. rear').replace('rear.','rear ')

# %%
for i in range(0,len(modified_clean_address)):
    if modified_clean_address[i].find("h. r ") >=0:
        modified_clean_address[i] = modified_clean_address[i].replace('h. r','h. rear').replace('rear.','rear ')

# %%
for i in range(0,len(modified_clean_address)):
    if modified_clean_address[i][0:2].find("h'") >=0:
        modified_clean_address[i] = modified_clean_address[i].replace("h'","h. ")

# %%
for i in range(0,len(modified_clean_address)):
    if modified_clean_address[i][0:2].find("th") >=0:
        modified_clean_address[i] = modified_clean_address[i].replace("th","h")

# %%
modified_clean_address[0]
# Out:
# 'h. 11 Eldridge'

# %%
#re.findall(r'. 1', '.1')

# %%
import re

modified_clean_address4 = []
intersections_n_1 = []
intersections_n_2 = []

intersections_c_1 = []
intersections_c_2 = []

for i in range(0,len(modified_clean_address)):
    temp = modified_clean_address[i]
    
    
    
    
    """
    string_with_th = re.findall(r'[0-9]+th', temp)
    for j in range (0, len(string_with_th)):
        temp = temp.replace(string_with_th[j], string_with_th[j].replace('th',''))
    
    string_with_d = re.findall(r'[0-9]+d', temp)
    for j in range (0, len(string_with_d)):
        temp = temp.replace(string_with_d[j], string_with_d[j].replace('d',''))
    
    string_with_rd = re.findall(r'[0-9]+rd', temp)
    for j in range (0, len(string_with_rd)):
        temp = temp.replace(string_with_rd[j], string_with_rd[j].replace('rd',''))
    
    string_with_st = re.findall(r'[0-9]+st', temp)
    for j in range (0, len(string_with_st)):
        temp = temp.replace(string_with_st[j], string_with_st[j].replace('st',''))
    
    string_with_h_dot = re.findall(r'h.+[0-9]', temp)
    for j in range (0, len(string_with_h_dot)):
        temp = temp.replace(string_with_h_dot[j], string_with_h_dot[j].replace('h.','h. ').replace('  ',' '))
    
    string_with_h = re.findall(r'h+[0-9]', temp)
    for j in range (0, len(string_with_h)):
        temp = temp.replace(string_with_h[j], string_with_h[j].replace('h','h ').replace('  ',' '))
        
    string_with_fullstop = re.findall(r'. +[0-9]', temp)
    for j in range (0, len(string_with_fullstop)):
        temp = temp.replace(string_with_fullstop[j], string_with_fullstop[j].replace('.','. h ').replace('  ',' '))
    
    string_with_comma = re.findall(r', +[0-9]', temp)
    for j in range (0, len(string_with_comma)):
        temp = temp.replace(string_with_comma[j], string_with_comma[j].replace(',',', h ').replace('  ',' '))
    
    string_with_bracket = re.findall(r'\) +[0-9]', temp)
    for j in range (0, len(string_with_bracket)):
        temp = temp.replace(string_with_bracket[j], string_with_bracket[j].replace(')',') h ').replace('  ',' '))
    
    string_with_dash = re.findall(r'-+[0-9]', temp)
    for j in range (0, len(string_with_dash)):
        temp = temp.replace(string_with_dash[j], string_with_dash[j].replace('-','').replace('  ',' '))
    
    string_with_fullstop_number = re.findall(r'.+[0-9]', temp)
    for j in range (0, len(string_with_fullstop_number)):
        temp = temp.replace(string_with_fullstop_number[j], string_with_fullstop_number[j].replace('.','').replace('  ',' '))
    
    
    string_with_S_1 = re.findall(r'[0-9]+S', temp)
    string_with_S_2 = re.findall(r'S+[0-9]', temp)
    string_with_S = string_with_S_1 + string_with_S_2
    for j in range (0, len(string_with_S)):
        #print(i,string_with_S)
        temp = temp.replace(string_with_S[j], string_with_S[j].replace('S','5'))
        #print(temp)
    
    
    """
    
    
    
    try:
        location_of_h_1 = temp.split().index('h.')
    except:
        location_of_h_1 = -1
    try:
        location_of_h_2 = temp.split().index('h')
    except:
        location_of_h_2 = -1
    #print(location_of_h_1, location_of_h_2)

    location_of_h = max(location_of_h_1, location_of_h_2)
    """
    if location_of_h_1>0:
        if location_of_h_2<0:
            location_of_h = location_of_h_1
        else:
            #print(i,'in exception1')
            #print(location_of_h_1, location_of_h_2)
            location_of_h = max(location_of_h_1, location_of_h_2)
    
    else:
        if location_of_h_2 > 0:
            location_of_h = location_of_h_2
        else:
            print(i,'in exception2')
            print(location_of_h_1, location_of_h_2)
            location_of_h = -1
    """
    temp = temp.replace('^','')
    
    
    
    """
    temp = temp.replace('ft.','')
    temp = temp.replace('ft','')
    temp = temp.replace('Ft.','')
    """
    
    undesired_starts = ['.',' .',',',' ,','-',' -','- ',', ','. ',"'","' "," '","''",'&','*','& ','* ',
                       ' &',' *']
    for i in range(0,len(undesired_starts)):
        if temp[0:2].find(undesired_starts[i])>=0:
            temp = temp[0:2].replace(undesired_starts[i],'') + temp[2:]
    
    words_after_h = temp.split()[location_of_h+1:]
    try:
        location_of_n = words_after_h.index('n')
        intersection_n_street1 = ' '.join(words_after_h[0:location_of_n])
        intersection_n_street2 = ' '.join(words_after_h[location_of_n+1:])

        intersections_n_1.append(intersection_n_street1)
        intersections_n_2.append(intersection_n_street2)
    except:
        intersections_n_1.append('')
        intersections_n_2.append('')
    
    try:
        location_of_c = words_after_h.index('c')
        intersection_c_street1 = ' '.join(words_after_h[0:location_of_c])
        intersection_c_street2 = ' '.join(words_after_h[location_of_c+1:])

        intersections_c_1.append(intersection_c_street1)
        intersections_c_2.append(intersection_c_street2)
    except:
        intersections_c_1.append('')
        intersections_c_2.append('')
    
    modified_clean_address4.append(temp)

# %%
#for i in range(0,len(intersections_c_1)):
    #print(i, intersections_c_1[i] + ' and ' + intersections_c_2[i])

# %%
for i in range(0,len(modified_clean_address4)):
    if modified_clean_address4[i].find(".h") >= 0:
        print(i, modified_clean_address4[i])

# %%
#for i in range(0,len(modified_clean_address)):
    #if modified_clean_address[i].find(" n ") >0:
        #print(i, modified_clean_address[i])

# %%
df['modified_clean_address'] = modified_clean_address4

# %%
df['n_street1'] = intersections_n_1
df['n_street2'] = intersections_n_2
df['c_street1'] = intersections_c_1
df['c_street2'] = intersections_c_2

# %%
#df.head()

# %%
#df.to_excel('doubt/not so confident2.xlsx')

# %%
df_modified_addresses = pd.DataFrame(modified_clean_address4, columns=['clean_address'])

# %%
#pd.DataFrame(modified_clean_address2).to_csv('doubt/doubt2.txt', header=None,  sep=' ', mode='a')

# %%
temp_addr = []
for i in range(0,len(df_modified_addresses)):
    temp_addr.append(str(i)+" "+df_modified_addresses['clean_address'][i])
#np.savetxt('doubt/not so confident addr.txt', temp_addr, fmt='%s')

# %%
#np.savetxt('doubt/not so confident addr.txt', temp_addr, fmt='%s')

# %%
#df.head()

# %%
#df.columns

# %%
#df.head()

# %%
df['n_street1'] = df['n_street1'].replace('',np.nan)
df['n_street2'] = df['n_street2'].replace('',np.nan)
df['c_street1'] = df['c_street1'].replace('',np.nan)
df['c_street2'] = df['c_street2'].replace('',np.nan)

# %%
#df['filter11'] = np.where(df['n_street1'].isna() & df['n_street2'].isna() & df['c_street1'].isna() & df['c_street2'].isna() & df['new h house number'].isna() & df['new h street name'].isna(), 1, 0)
#was initially uncommented

df['filter11'] = np.where(df['n_street1'].isna() & df['n_street2'].isna() & df['c_street1'].isna() & df['c_street2'].isna(), 1, 0)

# %%
df_filter11 = df.loc[df['filter11'] == 1]
df_filter11 = df_filter11.reset_index()

# %%
#df_filter11['modified_clean_address']

# %%
modified_clean_address5 = []
for i in range(0,len(df_filter11)):
    temp = df_filter11['modified_clean_address'][i]
    
    string_with_S = re.findall(r'[0-9]+S', temp)
    for i in range (0, len(string_with_S)):
        temp = temp.replace(string_with_S[i], string_with_S[i].replace('S','5'))
    modified_clean_address5.append(temp)

# %%
#for i in range(0,len(modified_clean_address5)):
    #print(i, modified_clean_address5[i])

# %%
#for i in range(0,len(modified_clean_address5)):
    #if modified_clean_address5[i].find("h. ") <0:
        #print(i, modified_clean_address5[i])

# %%
df['modified_clean_address'][10:16]
# Out:
# 10                     h 352 Third av .
# 11                       h 121 Columbia
# 12        108 Vesey, h. 200 E , Houston
# 13    367 Third av ., h. 352 Third av .
# 14                       h 108 Chrystie
# 15                       h 208 E . 49th
# Name: modified_clean_address, dtype: object

# %%
df['modified_clean_address'] = df['modified_clean_address'].str.replace('rearear','rear')
df['modified_clean_address'] = df['modified_clean_address'].str.replace('rearefused','refused')
df['modified_clean_address'] = df['modified_clean_address'].str.replace('h. r ','h. rear ')

# %%
df
# Out:
#         Unnamed: 0                        Full Name First Name    Last Name  \
# 0                0                       Aab Rosina     Rosina          Aab
# 1                1                 Aalholm Matthias   Matthias      Aalholm
# 2                2                        Greene pl         pl       Greene
# 3                3                     Aaron Edward     Edward        Aaron
# 4                4                      Aaron Elias      Elias        Aaron
# 5                5                    Aaron Ellis E      Ellis        Aaron
# 6                6                       Aaron Emil       Emil        Aaron
# 7                7                     Aaron Gerson     Gerson        Aaron
# 8                8                    Aaron: Isidor     Isidor       Aaron:
# 9                9                     Aaron Isidor     Isidor        Aaron
# 10              10                    Aaron Joachim    Joachim        Aaron
# 11              11                    Aaron Joachim    Joachim        Aaron
# 12              12                       Aaron John       John        Aaron
# 13              13                        Aaron Jos        Jos        Aaron
# 14              14                     Aaron Julius     Julius        Aaron
# 15              15                     Aaron Julius     Julius        Aaron
# 16              16                       Aaron Levi       Levi        Aaron
# 17              17                      Aaron Louis      Louis        Aaron
# 18              18                    Aaron Michael    Michael        Aaron
# 19              19                     Aaron Morris     Morris        Aaron
# 20              20                       Aaron Otto       Otto        Aaron
# 21              21                    Aaron Pauline    Pauline        Aaron
# 22              22                    Aaron-Peter M          M  Aaron-Peter
# 23              23                     Aaron Philip     Philip        Aaron
# 24              24                     Aaron Samuel     Samuel        Aaron
# 25              25                          Aaron T          T        Aaron
# 26              26                       Aaron Wolf       Wolf        Aaron
# 27              27                       Aaron Wolf       Wolf        Aaron
# 28              28                Aaron & Alexander          &        Aaron
# 29              29                Aaron & Schlosser          &        Aaron
# ...            ...                              ...        ...          ...
# 289961      272949                    Abeel Fred. H      Fred.        Abeel
# 289962      272954                   Abeel Thomas J     Thomas        Abeel
# 289963      272955                   Abeel Brothers   Brothers        Abeel
# 289964      272956                      Abegg Henry      Henry        Abegg
# 289965      272957                        Abel Adam       Adam         Abel
# 289966      272959           Abel Anna M. wid. John        NaN          NaN
# 289967      272993                  Abel C. C. & Co        NaN          NaN
# 289968      272995                     Abcle John J       John        Abcle
# 289969      273001                   Abell Augustus   Augustus        Abell
# 289970      273002                   Abell Augustus   Augustus        Abell
# 289971      273005                 Abell Rich. P. H        NaN          NaN
# 289972      273006                   Abell Samuel S     Samuel        Abell
# 289973      273007               Abell William H. H        NaN          NaN
# 289974      273011                        Abels H’y        H’y        Abels
# 289975      273016              Abendroth A. Howard         A.    Abendroth
# 289976      273019           Aab Rosina. wid. Louis        NaN          NaN
# 289977      273035                     Aaron Loui.s     Loui.s        Aaron
# 289978      273040                    Aaron Peter M      Peter        Aaron
# 289979      273052                      Aarons Emil       Emil       Aarons
# 289980      273063                Abarbanell Henry'     Henry'   Abarbanell
# 289981      273068    Abbatt Caroline A. wid. Isaac        NaN          NaN
# 289982      273070  Abbe Charlotte C. wid. George W        NaN          NaN
# 289983      273071                       Abbe Rob't      Rob't         Abbe
# 289984      273072                      Abbe Walter     Walter         Abbe
# 289985      273077                  Abbots Theodore   Theodore       Abbots
# 289986      273078                   Abbett Edwin L      Edwin       Abbett
# 289987      273083                       Abbey E. A         E.        Abbey
# 289988      273085                       Aborn C. B         C.        Aborn
# 289989      273087                 Altman Sigismund  Sigismund       Altman
# 289990      273088                        Ames E. F         E.         Ames
#
#        Middle Name  Widow-flag Widow Of  Title   Occupation  \
# 0              NaN        True      Aab    NaN          NaN
# 1              NaN       False      NaN    NaN     sundries
# 2              NaN       False      NaN    NaN          NaN
# 3              NaN       False      NaN    NaN         beer
# 4              NaN       False      NaN    NaN      carpets
# 5                E       False      NaN    NaN          NaN
# 6              NaN       False      NaN    NaN          imp
# 7              NaN       False      NaN    NaN      teacher
# 8              NaN       False      NaN    NaN   pawnbroker
# 9              NaN       False      NaN    NaN       tidies
# 10             NaN       False      NaN    NaN          NaN
# 11             NaN       False      NaN    NaN       pedlar
# 12             NaN       False      NaN    NaN       provns
# 13             NaN       False      NaN    NaN       broker
# 14             NaN       False      NaN    NaN        clerk
# 15             NaN       False      NaN    NaN        clerk
# 16             NaN       False      NaN    NaN  real estate
# 17             NaN       False      NaN    NaN       tailor
# 18             NaN       False      NaN    NaN       porter
# 19             NaN       False      NaN    NaN       cutter
# 20             NaN       False      NaN    NaN        clerk
# 21             NaN        True    Aaron    NaN          NaN
# 22             NaN       False      NaN    NaN       porter
# 23             NaN       False      NaN    NaN     clothier
# 24             NaN       False      NaN    NaN          NaN
# 25             NaN       False      NaN    NaN         ties
# 26             NaN       False      NaN    NaN       tailor
# 27             NaN       False      NaN    NaN       weaver
# 28       Alexander       False      NaN    NaN         imps
# 29       Schlosser       False      NaN    NaN         ties
# ...            ...         ...      ...    ...          ...
# 289961           H       False      NaN    NaN         iron
# 289962           J       False      NaN    NaN      laborer
# 289963         NaN       False      NaN    NaN         iron
# 289964         NaN       False      NaN    NaN          imp
# 289965         NaN       False      NaN    NaN         meat
# 289966         NaN       False      NaN    NaN          NaN
# 289967         NaN       False      NaN    NaN         mers
# 289968           J       False      NaN    NaN       tailor
# 289969         NaN       False      NaN    NaN          NaN
# 289970         NaN       False      NaN    NaN       turner
# 289971         NaN       False      NaN    NaN        clerk
# 289972           S       False      NaN    NaN      printer
# 289973         NaN       False      NaN    NaN        clerk
# 289974         NaN       False      NaN    NaN     crockery
# 289975      Howard       False      NaN    NaN          sec
# 289976         NaN       False      NaN    NaN          NaN
# 289977         NaN       False      NaN    NaN       tailor
# 289978           M       False      NaN    NaN       porter
# 289979         NaN       False      NaN    NaN       cutter
# 289980         NaN       False      NaN    NaN      teacher
# 289981         NaN       False      NaN    NaN          NaN
# 289982         NaN       False      NaN    NaN          NaN
# 289983         NaN       False      NaN    NaN    physician
# 289984         NaN       False      NaN    NaN        clerk
# 289985         NaN       False      NaN    NaN      weigher
# 289986           L       False      NaN    NaN       lawyer
# 289987           A       False      NaN    NaN       artist
# 289988           B       False      NaN    NaN          mer
# 289989         NaN       False      NaN    NaN       tailor
# 289990           F       False      NaN    NaN       covers
#
#                                 Full Address  ... Address 2 Street Name  \
# 0                             h. 11 Eldridge  ...                   NaN
# 1                     97 William, h. 66 Ft .  ...            97 William
# 2                                 . Bâ€™klyn  ...                   NaN
# 3                                184 Forsyth  ...                   NaN
# 4                                60 Eldridge  ...                   NaN
# 5                            h. 214 E . 13th  ...                   NaN
# 6                  53 Walker, h. 70 W . 48th  ...             53 Walker
# 7                            h. 171 Attorney  ...                   NaN
# 8                                  197 Grand  ...                   NaN
# 9                  42 Clinton, h. 109 Hester  ...            42 Clinton
# 10                         h. 352 Third av .  ...                   NaN
# 11                           h. 121 Columbia  ...                   NaN
# 12             108 Vesey, h. 200 E , Houston  ...             108 Vesey
# 13         367 Third av ., h. 352 Third av .  ...        367 Third av .
# 14                           h. 108 Chrystie  ...                   NaN
# 15                           h. 208 E . 49th  ...                   NaN
# 16                               811 E . 43d  ...                   NaN
# 17                            h. 132 Orchard  ...                   NaN
# 18                                hS2 Av . B  ...                   NaN
# 19                            h. 59 Attorney  ...                   NaN
# 20                         h. 139 Third av .  ...                   NaN
# 21                           h. 311 EB , 43a  ...                   NaN
# 22                             h. 363 Eighth  ...                   NaN
# 23        801 Eighth av ., h. %9 Eighth av .  ...       801 Eighth av .
# 24                            h. 305 E . 73d  ...                   NaN
# 25                 45 Walker, h. 305 E , 73d  ...             45 Walker
# 26                              238 Bleecker  ...                   NaN
# 27                             h. 64 Willett  ...                   NaN
# 28                                 53 Walker  ...                   NaN
# 29                                 45 Walker  ...                   NaN
# ...                                      ...  ...                   ...
# 289961            190 South,h 127 Second av.  ...                 South
# 289962                       h r 446 W. 41st  ...                   NaN
# 289963                 190 South & 365 Water  ...                   NaN
# 289964  94 Grand,h 117 Schermerhorn , B’klyn  ...                 Grand
# 289965                         779 Tenth av.  ...                   NaN
# 289966                        2190 Third av.  ...                   NaN
# 289967                         28 S. William  ...                   NaN
# 289968                      h 202 E. Houston  ...                   NaN
# 289969                           h 22 E. 43d  ...                   NaN
# 289970           514 First av. h 308 E. 74th  ...                   NaN
# 289971           2 City Hall,h 960 Sixth av.  ...             City Hall
# 289972                          h 229 E. 82d  ...                   NaN
# 289973                         h 337 E. 80th  ...                   NaN
# 289974           161 E. Houston,h 33 Seventh  ...            E. Houston
# 289975                 28 Cliff,h 10 W. 38th  ...                 Cliff
# 289976                         h 11 Eldridge  ...                   NaN
# 289977                         h 132 Orchard  ...                   NaN
# 289978                          h 363 Eighth  ...                   NaN
# 289979                         h 128 Orchard  ...                   NaN
# 289980                         h 246 E. 44th  ...                   NaN
# 289981                          h 139 W. 22d  ...                   NaN
# 289982                           h 32E. 20th  ...                   NaN
# 289983           282 Fourth av. h 32 E. 20th  ...                   NaN
# 289984                          h 32 E. 20th  ...                   NaN
# 289985                              h 19 Jay  ...                   NaN
# 289986                128 B’way,h 52 W. 24th  ...                 B’way
# 289987                             331 Pearl  ...                   NaN
# 289988                               94 Wall  ...                   NaN
# 289989            r 84 R,idge,h 252 Delancey  ...                R,idge
# 289990                             189 B’way  ...                   NaN
#
#        Address 2 City     Index  \
# 0                 NaN       NaN
# 1                 NaN       NaN
# 2                 NaN       NaN
# 3                 NaN       NaN
# 4                 NaN       NaN
# 5                 NaN       NaN
# 6                 NaN       NaN
# 7                 NaN       NaN
# 8                 NaN       NaN
# 9                 NaN       NaN
# 10                NaN       NaN
# 11                NaN       NaN
# 12                NaN       NaN
# 13                NaN       NaN
# 14                NaN       NaN
# 15                NaN       NaN
# 16                NaN       NaN
# 17                NaN       NaN
# 18                NaN       NaN
# 19                NaN       NaN
# 20                NaN       NaN
# 21                NaN       NaN
# 22                NaN       NaN
# 23                NaN       NaN
# 24                NaN       NaN
# 25                NaN       NaN
# 26                NaN       NaN
# 27                NaN       NaN
# 28                NaN       NaN
# 29                NaN       NaN
# ...               ...       ...
# 289961            NaN  272949.0
# 289962            NaN  272954.0
# 289963            NaN  272955.0
# 289964            NaN  272956.0
# 289965            NaN  272957.0
# 289966            NaN  272959.0
# 289967            NaN  272993.0
# 289968            NaN  272995.0
# 289969            NaN  273001.0
# 289970            NaN  273002.0
# 289971            NaN  273005.0
# 289972            NaN  273006.0
# 289973            NaN  273007.0
# 289974            NaN  273011.0
# 289975            NaN  273016.0
# 289976            NaN  273019.0
# 289977            NaN  273035.0
# 289978            NaN  273040.0
# 289979            NaN  273052.0
# 289980            NaN  273063.0
# 289981            NaN  273068.0
# 289982            NaN  273070.0
# 289983            NaN  273071.0
# 289984            NaN  273072.0
# 289985            NaN  273077.0
# 289986            NaN  273078.0
# 289987            NaN  273083.0
# 289988            NaN  273085.0
# 289989            NaN  273087.0
# 289990            NaN  273088.0
#
#                                                Full Entry  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# 5                                                     NaN
# 6                                                     NaN
# 7                                                     NaN
# 8                                                     NaN
# 9                                                     NaN
# 10                                                    NaN
# 11                                                    NaN
# 12                                                    NaN
# 13                                                    NaN
# 14                                                    NaN
# 15                                                    NaN
# 16                                                    NaN
# 17                                                    NaN
# 18                                                    NaN
# 19                                                    NaN
# 20                                                    NaN
# 21                                                    NaN
# 22                                                    NaN
# 23                                                    NaN
# 24                                                    NaN
# 25                                                    NaN
# 26                                                    NaN
# 27                                                    NaN
# 28                                                    NaN
# 29                                                    NaN
# ...                                                   ...
# 289961   Abeel Fred. H. iron, 190 South, h 127 Second av.
# 289962           Abeel Thomas J. laborer, h r 446 W. 41st
# 289963        Abeel Brothers, iron, 190 South & 365 Water
# 289964  Abegg Henry, imp. 94 Grand, h 117 Schermerhorn...
# 289965                     Abel Adam, meat, 779 Tenth av.
# 289966             Abel Anna M. wid. John, 2190 Third av.
# 289967               Abel C. C. & Co. mers. 28 S. William
# 289968             Abcle John J. tailor, h 202 E. Houston
# 289969                        Abell Augustus, h 22 E. 43d
# 289970  Abell Augustus, turner, 514 First av. h 308 E....
# 289971  Abell Rich. P. H. clerk. 2 City Hall, h 960 Si...
# 289972              Abell Samuel S. printer, h 229 E. 82d
# 289973           Abell William H. H. clerk, h 337 E. 80th
# 289974  Abels H’y, crockery, 161 E. Houston, h 33 Seventh
# 289975   Abendroth A. Howard, sec. 28 Cliff, h 10 W. 38th
# 289976              Aab Rosina. wid. Louis, h 11 Eldridge
# 289977                Aaron Loui.s, tailor, h 132 Orchard
# 289978                Aaron Peter M. porter, h 363 Eighth
# 289979                 Aarons Emil, cutter, h 128 Orchard
# 289980          Abarbanell Henry', teacher, h 246 E. 44th
# 289981        Abbatt Caroline A. wid. Isaac, h 139 W. 22d
# 289982       Abbe Charlotte C. wid. George W. h 32E. 20th
# 289983  Abbe Rob't, physician, 282 Fourth av. h 32 E. ...
# 289984                   Abbe Walter, clerk, h 32 E. 20th
# 289985                 Abbots Theodore, weigher, h 19 Jay
# 289986    Abbett Edwin L. lawyer, 128 B’way, h 52 W. 24th
# 289987                      Abbey E. A. artist, 331 Pearl
# 289988                           Aborn C. B. mer. 94 Wall
# 289989  Altman Sigismund, tailor, r 84 R,idge, h 252 D...
# 289990                       Ames E. F. covers, 189 B’way
#
#                       modified_clean_address n_street1  n_street2 c_street1  \
# 0                              h 11 Eldridge       NaN        NaN       NaN
# 1                     97 William, h. 66 Ft .       NaN        NaN       NaN
# 2                                   Bâ€™klyn       NaN        NaN       NaN
# 3                                184 Forsyth       NaN        NaN       NaN
# 4                                60 Eldridge       NaN        NaN       NaN
# 5                             h 214 E . 13th       NaN        NaN       NaN
# 6                  53 Walker, h. 70 W . 48th       NaN        NaN       NaN
# 7                             h 171 Attorney       NaN        NaN       NaN
# 8                                  197 Grand       NaN        NaN       NaN
# 9                  42 Clinton, h. 109 Hester       NaN        NaN       NaN
# 10                          h 352 Third av .       NaN        NaN       NaN
# 11                            h 121 Columbia       NaN        NaN       NaN
# 12             108 Vesey, h. 200 E , Houston       NaN        NaN       NaN
# 13         367 Third av ., h. 352 Third av .       NaN        NaN       NaN
# 14                            h 108 Chrystie       NaN        NaN       NaN
# 15                            h 208 E . 49th       NaN        NaN       NaN
# 16                               811 E . 43d       NaN        NaN       NaN
# 17                             h 132 Orchard       NaN        NaN       NaN
# 18                                hS2 Av . B       NaN        NaN       NaN
# 19                             h 59 Attorney       NaN        NaN       NaN
# 20                          h 139 Third av .       NaN        NaN       NaN
# 21                            h 311 EB , 43a       NaN        NaN       NaN
# 22                              h 363 Eighth       NaN        NaN       NaN
# 23        801 Eighth av ., h. %9 Eighth av .       NaN        NaN       NaN
# 24                             h 305 E . 73d       NaN        NaN       NaN
# 25                 45 Walker, h. 305 E , 73d       NaN        NaN       NaN
# 26                              238 Bleecker       NaN        NaN       NaN
# 27                              h 64 Willett       NaN        NaN       NaN
# 28                                 53 Walker       NaN        NaN       NaN
# 29                                 45 Walker       NaN        NaN       NaN
# ...                                      ...       ...        ...       ...
# 289961            190 South,h 127 Second av.       NaN        NaN       NaN
# 289962                     h rear 446 W 41st       NaN        NaN       NaN
# 289963                 190 South & 365 Water       NaN        NaN       NaN
# 289964  94 Grand,h 117 Schermerhorn , B’klyn       NaN        NaN       NaN
# 289965                         779 Tenth av.       NaN        NaN       NaN
# 289966                        2190 Third av.       NaN        NaN       NaN
# 289967                         28 S. William       NaN        NaN       NaN
# 289968                       h 202 E Houston       NaN        NaN       NaN
# 289969                            h 22 E 43d       NaN        NaN       NaN
# 289970            514 First av. h 308 E 74th       NaN        NaN       NaN
# 289971           2 City Hall,h 960 Sixth av.       NaN        NaN       NaN
# 289972                           h 229 E 82d       NaN        NaN       NaN
# 289973                          h 337 E 80th       NaN        NaN       NaN
# 289974            161 E Houston,h 33 Seventh       NaN        NaN       NaN
# 289975                  28 Cliff,h 10 W 38th       NaN        NaN       NaN
# 289976                         h 11 Eldridge       NaN        NaN       NaN
# 289977                         h 132 Orchard       NaN        NaN       NaN
# 289978                          h 363 Eighth       NaN        NaN       NaN
# 289979                         h 128 Orchard       NaN        NaN       NaN
# 289980                          h 246 E 44th       NaN        NaN       NaN
# 289981                           h 139 W 22d       NaN        NaN       NaN
# 289982                            h 32E 20th       NaN        NaN       NaN
# 289983            282 Fourth av. h 32 E 20th       NaN        NaN       NaN
# 289984                           h 32 E 20th       NaN        NaN       NaN
# 289985                              h 19 Jay       NaN        NaN       NaN
# 289986                 128 B’way,h 52 W 24th       NaN        NaN       NaN
# 289987                             331 Pearl       NaN        NaN       NaN
# 289988                               94 Wall       NaN        NaN       NaN
# 289989            r 84 R,idge,h 252 Delancey       NaN        NaN       NaN
# 289990                             189 B’way       NaN        NaN       NaN
#
#        c_street2  filter11
# 0            NaN         1
# 1            NaN         1
# 2            NaN         1
# 3            NaN         1
# 4            NaN         1
# 5            NaN         1
# 6            NaN         1
# 7            NaN         1
# 8            NaN         1
# 9            NaN         1
# 10           NaN         1
# 11           NaN         1
# 12           NaN         1
# 13           NaN         1
# 14           NaN         1
# 15           NaN         1
# 16           NaN         1
# 17           NaN         1
# 18           NaN         1
# 19           NaN         1
# 20           NaN         1
# 21           NaN         1
# 22           NaN         1
# 23           NaN         1
# 24           NaN         1
# 25           NaN         1
# 26           NaN         1
# 27           NaN         1
# 28           NaN         1
# 29           NaN         1
# ...          ...       ...
# 289961       NaN         1
# 289962       NaN         1
# 289963       NaN         1
# 289964       NaN         1
# 289965       NaN         1
# 289966       NaN         1
# 289967       NaN         1
# 289968       NaN         1
# 289969       NaN         1
# 289970       NaN         1
# 289971       NaN         1
# 289972       NaN         1
# 289973       NaN         1
# 289974       NaN         1
# 289975       NaN         1
# 289976       NaN         1
# 289977       NaN         1
# 289978       NaN         1
# 289979       NaN         1
# 289980       NaN         1
# 289981       NaN         1
# 289982       NaN         1
# 289983       NaN         1
# 289984       NaN         1
# 289985       NaN         1
# 289986       NaN         1
# 289987       NaN         1
# 289988       NaN         1
# 289989       NaN         1
# 289990       NaN         1
#
# [289991 rows x 27 columns]

# %%
#df.to_excel('/Users/prajwal/Desktop/Columbia/C4SR/mn_1880/not so confident-mn1880-v7.xlsx')

# %%
df.to_excel('/Users/prajwal/Desktop/Columbia/C4SR/tesseract output/run1/mn-1880-2.xlsx')
